# %%
from    typing              import  *
from    typing_extensions   import  Self

from    tqdm.notebook       import  tqdm

import  numpy               as  np
import  matplotlib.pyplot   as  plt

import  torch
from    torch.utils.data    import  Dataset, DataLoader


from    pathlib             import  Path
root_dir    = r"/media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE"
path_root   = Path(root_dir)
path_lib    = path_root / "python_deep_numerical"
path_data   = path_root / "datasets_short" / "Boltzmann_2D" / "various" / "coeff1.59e-01"

import  sys
sys.path.append( str(path_lib) )
from    pytorch.layers  import  FourierBoltzmannLayer
from    pytorch         import  utils
from    pytorch.utils   import  initialize_weights


dtype               = torch.float32
dtype_complex       = utils.dtype_real_to_complex(dtype)
device              = torch.device('cuda:2')
dtype_and_device    = {'dtype': dtype, 'device': device}
print(f"Device for computation\n>>> {device}")
# Out:
# Device for computation
# >>> cuda:2

# %%
DIMENSION:  int     = 2
RESOLUTION: int     = 64
VHS_ALPHA:  float   = 0.0

_file = path_data / "res064__alpha0.0e+00__part1.pth"
_file = r"/media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE/datasets_short/Boltzmann_2D/various/coeff1.59e-01/res064__alpha0.0e+00__part01.pth"
file = torch.load(_file, weights_only=False)

V_MAX:      float   = float(file['v_max'])
DELTA_V:    float   = (2*V_MAX) / RESOLUTION
FFT_NORM:   str     = 'forward'

VHS_COEFF:  float   = file['vhs_coeff']

# %%
class CustomDataset(Dataset):
    def __init__(
            self,
            distr:      torch.Tensor,
            q_gain:     torch.Tensor,
            q_loss:     torch.Tensor,
            vhs_alpha:  Optional[torch.Tensor]  = None,
            dim:        Optional[int]           = None,
            squeeze_space: bool = False,
        ) -> Self:
        self.dim:       int                         = dim
        self.distr:     torch.Tensor                = distr
        self.q_gain:    torch.Tensor                = q_gain
        self.q_loss:    torch.Tensor                = q_loss
        self.vhs_alpha: Optional[torch.Tensor]      = vhs_alpha
        self.__fft_dim: tuple[int] = tuple(range(1+dim, 1+2*dim))
        
        if squeeze_space:
            self.distr      = self.distr.reshape(-1, *distr.shape[-1-dim:])
            self.q_gain   = self.q_gain.reshape(-1, *q_gain.shape[-1-dim:])
            self.q_loss   = self.q_loss.reshape(-1, *q_loss.shape[-1-dim:])
            self.__fft_dim  = tuple(range(1, 1+dim))
            
        return
    
    
    def __getitem__(self, index: int) -> tuple[torch.Tensor]:
        if self.vhs_alpha:
            return self.distr[index], self.q_gain[index], self.q_loss[index], self.vhs_alpha[index]
        else:
            return self.distr[index], self.q_gain[index], self.q_loss[index]
    
    def __len__(self) -> int:
        return self.distr.size(0)
    
    
    @property
    def fft_dim(self) -> tuple[int]:
        return self.__fft_dim

# %%
dataset  = CustomDataset(
    file['input_distribution'].reshape(-1, 1, 1, RESOLUTION, RESOLUTION, 1),
    file['collision_gain'].reshape(-1, 1, 1, RESOLUTION, RESOLUTION, 1) / VHS_COEFF,
    file['collision_loss'].reshape(-1, 1, 1, RESOLUTION, RESOLUTION, 1) / VHS_COEFF,
    dim=DIMENSION,
    squeeze_space=False,
)
dataloader  = DataLoader(dataset, batch_size=256, shuffle=True)
FFT_DIM = dataset.fft_dim
print(FFT_DIM)
# Out:
# (3, 4)

# %%
specnet     = FourierBoltzmannLayer(DIMENSION, 8, n_channels=1, n_weights=2).to(device)
initialize_weights(specnet, 'xavier normal')
optimizer   = torch.optim.Adam(specnet.parameters(), lr=1e-2)

print(specnet)
# Out:
# ==============================< FourierBoltzmannLayer >==============================
# [ Subnetworks ]
#
# -------------------------------------------------------------------------------------
# [ Parameters ]
# ( params_alpha )
# - Shape:       [16, 16, 1, 2]
# - Data type:   torch.complex64
# ( params_beta )
# - Shape:       [16, 16, 1, 2]
# - Data type:   torch.complex64
# ( params_gamma )
# - Shape:       [16, 16, 1, 2]
# - Data type:   torch.complex64
# ( params_diag )
# - Shape:       [16, 16, 1]
# - Data type:   torch.complex64
# -------------------------------------------------------------------------------------
# Number of parameters: 3584
# =====================================================================================

# %%
# test_q_gain = specnet.compute_gain_fft(dataset[[0]][0])
dataset[:10][0].shape
# Out:
# torch.Size([10, 1, 1, 64, 64, 1])

# %%
NUM_EPOCHS: int = 10000
dv = DELTA_V**DIMENSION
specnet.train()

data:   torch.Tensor
q_gain: torch.Tensor
q_loss: torch.Tensor

for epoch in tqdm(range(1, 1+NUM_EPOCHS)):
    rel_error_g:    float = 0.0
    rel_error_l:    float = 0.0    
    rel_error_q:    float = 0.0
    for data, q_gain, q_loss in dataloader:
        data    = data.to(device)
        q_gain  = q_gain.to(device)
        q_loss  = q_loss.to(device)
        data_fft:   torch.Tensor = torch.fft.fftn(data, dim=FFT_DIM, norm=FFT_NORM)
        
        pred_gain_fft:  torch.Tensor = specnet.compute_gain_fft(data_fft)
        pred_loss_fft:  torch.Tensor = specnet.compute_loss_fft(data_fft)
        pred_gain:    torch.Tensor = torch.fft.ifftn(pred_gain_fft, dim=FFT_DIM, norm=FFT_NORM).real
        pred_loss:    torch.Tensor = torch.fft.ifftn(pred_loss_fft, dim=FFT_DIM, norm=FFT_NORM).real

        _rel_error_g = utils.relative_error(pred_gain, q_gain).sum()
        _rel_error_l = utils.relative_error(pred_loss, q_loss).sum()
        _rel_error_q = utils.relative_error(pred_gain-pred_loss, q_gain-q_loss).sum()
        rel_error_g += _rel_error_g.item()
        rel_error_l += _rel_error_l.item()
        rel_error_q += _rel_error_q.item()
        loss_tensor = _rel_error_g + _rel_error_l
        
        optimizer.zero_grad()
        loss_tensor.backward()
        optimizer.step()
        
    rel_error_g /= len(dataset)
    rel_error_l /= len(dataset)
    rel_error_q /= len(dataset)
    if epoch%10==0 or epoch==1:
        print(f"[ Epoch {str(epoch).zfill(len(str(NUM_EPOCHS)))} ]")
        print(f"* Relative error (gain):        {rel_error_g:.4e}")
        print(f"* Relative error (loss):        {rel_error_l:.4e}")
        print(f"* Relative error (collision):   {rel_error_q:.4e}")
        print('-'*50)

specnet.eval()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# [ Epoch 00001 ]
# * Relative error (gain):        9.9996e-01
# * Relative error (loss):        9.9860e-01
# * Relative error (collision):   8.3640e+02
# --------------------------------------------------
# [ Epoch 00010 ]
# * Relative error (gain):        7.1736e-01
# * Relative error (loss):        9.7544e-01
# * Relative error (collision):   1.5697e+05
# --------------------------------------------------
# [ Epoch 00020 ]
# * Relative error (gain):        1.5991e-01
# * Relative error (loss):        9.4986e-01
# * Relative error (collision):   4.7160e+05
# --------------------------------------------------
# [ Epoch 00030 ]
# * Relative error (gain):        4.9774e-02
# * Relative error (loss):        9.2446e-01
# * Relative error (collision):   4.3531e+05
# --------------------------------------------------
# [ Epoch 00040 ]
# * Relative error (gain):        3.4625e-02
# * Relative error (loss):        8.9927e-01
# * Relative error (collision):   4.1899e+05
# --------------------------------------------------
# [ Epoch 00050 ]
# * Relative error (gain):        2.7876e-02
# * Relative error (loss):        8.7433e-01
# * Relative error (collision):   4.0370e+05
# --------------------------------------------------
# [ Epoch 00060 ]
# * Relative error (gain):        2.2611e-02
# * Relative error (loss):        8.4967e-01
# * Relative error (collision):   3.8909e+05
# --------------------------------------------------
# [ Epoch 00070 ]
# * Relative error (gain):        1.9081e-02
# * Relative error (loss):        8.2532e-01
# * Relative error (collision):   3.7522e+05
# --------------------------------------------------
# [ Epoch 00080 ]
# * Relative error (gain):        1.7166e-02
# * Relative error (loss):        8.0136e-01
# * Relative error (collision):   3.6166e+05
# --------------------------------------------------
# [ Epoch 00090 ]
# * Relative error (gain):        1.5913e-02
# * Relative error (loss):        7.7783e-01
# * Relative error (collision):   3.4851e+05
# --------------------------------------------------
# [ Epoch 00100 ]
# * Relative error (gain):        1.4980e-02
# * Relative error (loss):        7.5482e-01
# * Relative error (collision):   3.3569e+05
# --------------------------------------------------
# [ Epoch 00110 ]
# * Relative error (gain):        1.4256e-02
# * Relative error (loss):        7.3240e-01
# * Relative error (collision):   3.2317e+05
# --------------------------------------------------
# [ Epoch 00120 ]
# * Relative error (gain):        1.3603e-02
# * Relative error (loss):        7.1070e-01
# * Relative error (collision):   3.1123e+05
# --------------------------------------------------
# [ Epoch 00130 ]
# * Relative error (gain):        1.3112e-02
# * Relative error (loss):        6.8981e-01
# * Relative error (collision):   2.9970e+05
# --------------------------------------------------
# [ Epoch 00140 ]
# * Relative error (gain):        1.2589e-02
# * Relative error (loss):        6.6982e-01
# * Relative error (collision):   2.8872e+05
# --------------------------------------------------
# [ Epoch 00150 ]
# * Relative error (gain):        1.2105e-02
# * Relative error (loss):        6.5084e-01
# * Relative error (collision):   2.7839e+05
# --------------------------------------------------
# [ Epoch 00160 ]
# * Relative error (gain):        1.1705e-02
# * Relative error (loss):        6.3289e-01
# * Relative error (collision):   2.6857e+05
# --------------------------------------------------
# [ Epoch 00170 ]
# * Relative error (gain):        1.1308e-02
# * Relative error (loss):        6.1598e-01
# * Relative error (collision):   2.5938e+05
# --------------------------------------------------
# [ Epoch 00180 ]
# * Relative error (gain):        1.1010e-02
# * Relative error (loss):        6.0005e-01
# * Relative error (collision):   2.5078e+05
# --------------------------------------------------
# [ Epoch 00190 ]
# * Relative error (gain):        1.0650e-02
# * Relative error (loss):        5.8504e-01
# * Relative error (collision):   2.4266e+05
# --------------------------------------------------
# [ Epoch 00200 ]
# * Relative error (gain):        1.0386e-02
# * Relative error (loss):        5.7083e-01
# * Relative error (collision):   2.3507e+05
# --------------------------------------------------
# [ Epoch 00210 ]
# * Relative error (gain):        1.0090e-02
# * Relative error (loss):        5.5734e-01
# * Relative error (collision):   2.2785e+05
# --------------------------------------------------
# [ Epoch 00220 ]
# * Relative error (gain):        9.8519e-03
# * Relative error (loss):        5.4447e-01
# * Relative error (collision):   2.2101e+05
# --------------------------------------------------
# [ Epoch 00230 ]
# * Relative error (gain):        9.6875e-03
# * Relative error (loss):        5.3214e-01
# * Relative error (collision):   2.1446e+05
# --------------------------------------------------
# [ Epoch 00240 ]
# * Relative error (gain):        9.4111e-03
# * Relative error (loss):        5.2026e-01
# * Relative error (collision):   2.0817e+05
# --------------------------------------------------
# [ Epoch 00250 ]
# * Relative error (gain):        9.2126e-03
# * Relative error (loss):        5.0879e-01
# * Relative error (collision):   2.0216e+05
# --------------------------------------------------
# [ Epoch 00260 ]
# * Relative error (gain):        9.0097e-03
# * Relative error (loss):        4.9766e-01
# * Relative error (collision):   1.9633e+05
# --------------------------------------------------
# [ Epoch 00270 ]
# * Relative error (gain):        8.8564e-03
# * Relative error (loss):        4.8682e-01
# * Relative error (collision):   1.9063e+05
# --------------------------------------------------
# [ Epoch 00280 ]
# * Relative error (gain):        8.7322e-03
# * Relative error (loss):        4.7625e-01
# * Relative error (collision):   1.8514e+05
# --------------------------------------------------
# [ Epoch 00290 ]
# * Relative error (gain):        8.5363e-03
# * Relative error (loss):        4.6590e-01
# * Relative error (collision):   1.7978e+05
# --------------------------------------------------
# [ Epoch 00300 ]
# * Relative error (gain):        8.4148e-03
# * Relative error (loss):        4.5575e-01
# * Relative error (collision):   1.7453e+05
# --------------------------------------------------
# [ Epoch 00310 ]
# * Relative error (gain):        8.2972e-03
# * Relative error (loss):        4.4578e-01
# * Relative error (collision):   1.6940e+05
# --------------------------------------------------
# [ Epoch 00320 ]
# * Relative error (gain):        8.1871e-03
# * Relative error (loss):        4.3597e-01
# * Relative error (collision):   1.6435e+05
# --------------------------------------------------
# [ Epoch 00330 ]
# * Relative error (gain):        8.1110e-03
# * Relative error (loss):        4.2631e-01
# * Relative error (collision):   1.5937e+05
# --------------------------------------------------
# [ Epoch 00340 ]
# * Relative error (gain):        7.9544e-03
# * Relative error (loss):        4.1680e-01
# * Relative error (collision):   1.5455e+05
# --------------------------------------------------
# [ Epoch 00350 ]
# * Relative error (gain):        7.8797e-03
# * Relative error (loss):        4.0741e-01
# * Relative error (collision):   1.4978e+05
# --------------------------------------------------
# [ Epoch 00360 ]
# * Relative error (gain):        7.7847e-03
# * Relative error (loss):        3.9817e-01
# * Relative error (collision):   1.4509e+05
# --------------------------------------------------
# [ Epoch 00370 ]
# * Relative error (gain):        7.7551e-03
# * Relative error (loss):        3.8906e-01
# * Relative error (collision):   1.4044e+05
# --------------------------------------------------
# [ Epoch 00380 ]
# * Relative error (gain):        7.6665e-03
# * Relative error (loss):        3.8010e-01
# * Relative error (collision):   1.3594e+05
# --------------------------------------------------
# [ Epoch 00390 ]
# * Relative error (gain):        7.6194e-03
# * Relative error (loss):        3.7130e-01
# * Relative error (collision):   1.3148e+05
# --------------------------------------------------
# [ Epoch 00400 ]
# * Relative error (gain):        7.5611e-03
# * Relative error (loss):        3.6271e-01
# * Relative error (collision):   1.2715e+05
# --------------------------------------------------
# [ Epoch 00410 ]
# * Relative error (gain):        7.4980e-03
# * Relative error (loss):        3.5434e-01
# * Relative error (collision):   1.2294e+05
# --------------------------------------------------
# [ Epoch 00420 ]
# * Relative error (gain):        7.4494e-03
# * Relative error (loss):        3.4624e-01
# * Relative error (collision):   1.1886e+05
# --------------------------------------------------
# [ Epoch 00430 ]
# * Relative error (gain):        7.3847e-03
# * Relative error (loss):        3.3844e-01
# * Relative error (collision):   1.1497e+05
# --------------------------------------------------
# [ Epoch 00440 ]
# * Relative error (gain):        7.3394e-03
# * Relative error (loss):        3.3096e-01
# * Relative error (collision):   1.1125e+05
# --------------------------------------------------
# [ Epoch 00450 ]
# * Relative error (gain):        7.2797e-03
# * Relative error (loss):        3.2382e-01
# * Relative error (collision):   1.0772e+05
# --------------------------------------------------
# [ Epoch 00460 ]
# * Relative error (gain):        7.2375e-03
# * Relative error (loss):        3.1699e-01
# * Relative error (collision):   1.0442e+05
# --------------------------------------------------
# [ Epoch 00470 ]
# * Relative error (gain):        7.2051e-03
# * Relative error (loss):        3.1047e-01
# * Relative error (collision):   1.0130e+05
# --------------------------------------------------
# [ Epoch 00480 ]
# * Relative error (gain):        7.1594e-03
# * Relative error (loss):        3.0423e-01
# * Relative error (collision):   9.8347e+04
# --------------------------------------------------
# [ Epoch 00490 ]
# * Relative error (gain):        7.1553e-03
# * Relative error (loss):        2.9826e-01
# * Relative error (collision):   9.5551e+04
# --------------------------------------------------
# [ Epoch 00500 ]
# * Relative error (gain):        7.0922e-03
# * Relative error (loss):        2.9252e-01
# * Relative error (collision):   9.2924e+04
# --------------------------------------------------
# [ Epoch 00510 ]
# * Relative error (gain):        7.0758e-03
# * Relative error (loss):        2.8699e-01
# * Relative error (collision):   9.0425e+04
# --------------------------------------------------
# [ Epoch 00520 ]
# * Relative error (gain):        7.0568e-03
# * Relative error (loss):        2.8167e-01
# * Relative error (collision):   8.8052e+04
# --------------------------------------------------
# [ Epoch 00530 ]
# * Relative error (gain):        7.0211e-03
# * Relative error (loss):        2.7652e-01
# * Relative error (collision):   8.5785e+04
# --------------------------------------------------
# [ Epoch 00540 ]
# * Relative error (gain):        7.0025e-03
# * Relative error (loss):        2.7152e-01
# * Relative error (collision):   8.3624e+04
# --------------------------------------------------
# [ Epoch 00550 ]
# * Relative error (gain):        6.9485e-03
# * Relative error (loss):        2.6667e-01
# * Relative error (collision):   8.1533e+04
# --------------------------------------------------
# [ Epoch 00560 ]
# * Relative error (gain):        6.9366e-03
# * Relative error (loss):        2.6194e-01
# * Relative error (collision):   7.9529e+04
# --------------------------------------------------
# [ Epoch 00570 ]
# * Relative error (gain):        6.9218e-03
# * Relative error (loss):        2.5733e-01
# * Relative error (collision):   7.7587e+04
# --------------------------------------------------
# [ Epoch 00580 ]
# * Relative error (gain):        6.8837e-03
# * Relative error (loss):        2.5282e-01
# * Relative error (collision):   7.5715e+04
# --------------------------------------------------
# [ Epoch 00590 ]
# * Relative error (gain):        6.8769e-03
# * Relative error (loss):        2.4839e-01
# * Relative error (collision):   7.3892e+04
# --------------------------------------------------
# [ Epoch 00600 ]
# * Relative error (gain):        6.8350e-03
# * Relative error (loss):        2.4404e-01
# * Relative error (collision):   7.2126e+04
# --------------------------------------------------
# [ Epoch 00610 ]
# * Relative error (gain):        6.8734e-03
# * Relative error (loss):        2.3976e-01
# * Relative error (collision):   7.0390e+04
# --------------------------------------------------
# [ Epoch 00620 ]
# * Relative error (gain):        6.8276e-03
# * Relative error (loss):        2.3554e-01
# * Relative error (collision):   6.8693e+04
# --------------------------------------------------
# [ Epoch 00630 ]
# * Relative error (gain):        6.8039e-03
# * Relative error (loss):        2.3138e-01
# * Relative error (collision):   6.7024e+04
# --------------------------------------------------
# [ Epoch 00640 ]
# * Relative error (gain):        6.7665e-03
# * Relative error (loss):        2.2725e-01
# * Relative error (collision):   6.5394e+04
# --------------------------------------------------
# [ Epoch 00650 ]
# * Relative error (gain):        6.7762e-03
# * Relative error (loss):        2.2318e-01
# * Relative error (collision):   6.3797e+04
# --------------------------------------------------
# [ Epoch 00660 ]
# * Relative error (gain):        6.7456e-03
# * Relative error (loss):        2.1913e-01
# * Relative error (collision):   6.2206e+04
# --------------------------------------------------
# [ Epoch 00670 ]
# * Relative error (gain):        6.7448e-03
# * Relative error (loss):        2.1513e-01
# * Relative error (collision):   6.0648e+04
# --------------------------------------------------
# [ Epoch 00680 ]
# * Relative error (gain):        6.7213e-03
# * Relative error (loss):        2.1115e-01
# * Relative error (collision):   5.9094e+04
# --------------------------------------------------
# [ Epoch 00690 ]
# * Relative error (gain):        6.7123e-03
# * Relative error (loss):        2.0720e-01
# * Relative error (collision):   5.7563e+04
# --------------------------------------------------
# [ Epoch 00700 ]
# * Relative error (gain):        6.7099e-03
# * Relative error (loss):        2.0328e-01
# * Relative error (collision):   5.6053e+04
# --------------------------------------------------
# [ Epoch 00710 ]
# * Relative error (gain):        6.6907e-03
# * Relative error (loss):        1.9938e-01
# * Relative error (collision):   5.4560e+04
# --------------------------------------------------
# [ Epoch 00720 ]
# * Relative error (gain):        6.6203e-03
# * Relative error (loss):        1.9551e-01
# * Relative error (collision):   5.3071e+04
# --------------------------------------------------
# [ Epoch 00730 ]
# * Relative error (gain):        6.6464e-03
# * Relative error (loss):        1.9166e-01
# * Relative error (collision):   5.1593e+04
# --------------------------------------------------
# [ Epoch 00740 ]
# * Relative error (gain):        6.6426e-03
# * Relative error (loss):        1.8783e-01
# * Relative error (collision):   5.0146e+04
# --------------------------------------------------
# [ Epoch 00750 ]
# * Relative error (gain):        6.5985e-03
# * Relative error (loss):        1.8404e-01
# * Relative error (collision):   4.8691e+04
# --------------------------------------------------
# [ Epoch 00760 ]
# * Relative error (gain):        6.5924e-03
# * Relative error (loss):        1.8026e-01
# * Relative error (collision):   4.7280e+04
# --------------------------------------------------
# [ Epoch 00770 ]
# * Relative error (gain):        6.5659e-03
# * Relative error (loss):        1.7652e-01
# * Relative error (collision):   4.5853e+04
# --------------------------------------------------
# [ Epoch 00780 ]
# * Relative error (gain):        6.6212e-03
# * Relative error (loss):        1.7281e-01
# * Relative error (collision):   4.4469e+04
# --------------------------------------------------
# [ Epoch 00790 ]
# * Relative error (gain):        6.5798e-03
# * Relative error (loss):        1.6913e-01
# * Relative error (collision):   4.3109e+04
# --------------------------------------------------
# [ Epoch 00800 ]
# * Relative error (gain):        6.5452e-03
# * Relative error (loss):        1.6549e-01
# * Relative error (collision):   4.1763e+04
# --------------------------------------------------
# [ Epoch 00810 ]
# * Relative error (gain):        6.5563e-03
# * Relative error (loss):        1.6188e-01
# * Relative error (collision):   4.0440e+04
# --------------------------------------------------
# [ Epoch 00820 ]
# * Relative error (gain):        6.5461e-03
# * Relative error (loss):        1.5831e-01
# * Relative error (collision):   3.9143e+04
# --------------------------------------------------
# [ Epoch 00830 ]
# * Relative error (gain):        6.5288e-03
# * Relative error (loss):        1.5480e-01
# * Relative error (collision):   3.7893e+04
# --------------------------------------------------
# [ Epoch 00840 ]
# * Relative error (gain):        6.5388e-03
# * Relative error (loss):        1.5133e-01
# * Relative error (collision):   3.6679e+04
# --------------------------------------------------
# [ Epoch 00850 ]
# * Relative error (gain):        6.5574e-03
# * Relative error (loss):        1.4793e-01
# * Relative error (collision):   3.5512e+04
# --------------------------------------------------
# [ Epoch 00860 ]
# * Relative error (gain):        6.4895e-03
# * Relative error (loss):        1.4461e-01
# * Relative error (collision):   3.4391e+04
# --------------------------------------------------
# [ Epoch 00870 ]
# * Relative error (gain):        6.4779e-03
# * Relative error (loss):        1.4139e-01
# * Relative error (collision):   3.3342e+04
# --------------------------------------------------
# [ Epoch 00880 ]
# * Relative error (gain):        6.4893e-03
# * Relative error (loss):        1.3827e-01
# * Relative error (collision):   3.2358e+04
# --------------------------------------------------
# [ Epoch 00890 ]
# * Relative error (gain):        6.4632e-03
# * Relative error (loss):        1.3529e-01
# * Relative error (collision):   3.1454e+04
# --------------------------------------------------
# [ Epoch 00900 ]
# * Relative error (gain):        6.5173e-03
# * Relative error (loss):        1.3246e-01
# * Relative error (collision):   3.0599e+04
# --------------------------------------------------
# [ Epoch 00910 ]
# * Relative error (gain):        6.4362e-03
# * Relative error (loss):        1.2976e-01
# * Relative error (collision):   2.9826e+04
# --------------------------------------------------
# [ Epoch 00920 ]
# * Relative error (gain):        6.4670e-03
# * Relative error (loss):        1.2720e-01
# * Relative error (collision):   2.9106e+04
# --------------------------------------------------
# [ Epoch 00930 ]
# * Relative error (gain):        6.4747e-03
# * Relative error (loss):        1.2475e-01
# * Relative error (collision):   2.8447e+04
# --------------------------------------------------
# [ Epoch 00940 ]
# * Relative error (gain):        6.4541e-03
# * Relative error (loss):        1.2242e-01
# * Relative error (collision):   2.7831e+04
# --------------------------------------------------
# [ Epoch 00950 ]
# * Relative error (gain):        6.4265e-03
# * Relative error (loss):        1.2019e-01
# * Relative error (collision):   2.7265e+04
# --------------------------------------------------
# [ Epoch 00960 ]
# * Relative error (gain):        6.4202e-03
# * Relative error (loss):        1.1804e-01
# * Relative error (collision):   2.6725e+04
# --------------------------------------------------
# [ Epoch 00970 ]
# * Relative error (gain):        6.4177e-03
# * Relative error (loss):        1.1599e-01
# * Relative error (collision):   2.6249e+04
# --------------------------------------------------
# [ Epoch 00980 ]
# * Relative error (gain):        6.4141e-03
# * Relative error (loss):        1.1400e-01
# * Relative error (collision):   2.5765e+04
# --------------------------------------------------
# [ Epoch 00990 ]
# * Relative error (gain):        6.3909e-03
# * Relative error (loss):        1.1209e-01
# * Relative error (collision):   2.5336e+04
# --------------------------------------------------
# [ Epoch 01000 ]
# * Relative error (gain):        6.3782e-03
# * Relative error (loss):        1.1024e-01
# * Relative error (collision):   2.4913e+04
# --------------------------------------------------
# [ Epoch 01010 ]
# * Relative error (gain):        6.3959e-03
# * Relative error (loss):        1.0844e-01
# * Relative error (collision):   2.4517e+04
# --------------------------------------------------
# [ Epoch 01020 ]
# * Relative error (gain):        6.3917e-03
# * Relative error (loss):        1.0669e-01
# * Relative error (collision):   2.4126e+04
# --------------------------------------------------
# [ Epoch 01030 ]
# * Relative error (gain):        6.3673e-03
# * Relative error (loss):        1.0499e-01
# * Relative error (collision):   2.3763e+04
# --------------------------------------------------
# [ Epoch 01040 ]
# * Relative error (gain):        6.3486e-03
# * Relative error (loss):        1.0333e-01
# * Relative error (collision):   2.3405e+04
# --------------------------------------------------
# [ Epoch 01050 ]
# * Relative error (gain):        6.3690e-03
# * Relative error (loss):        1.0171e-01
# * Relative error (collision):   2.3065e+04
# --------------------------------------------------
# [ Epoch 01060 ]
# * Relative error (gain):        6.3529e-03
# * Relative error (loss):        1.0012e-01
# * Relative error (collision):   2.2716e+04
# --------------------------------------------------
# [ Epoch 01070 ]
# * Relative error (gain):        6.3416e-03
# * Relative error (loss):        9.8558e-02
# * Relative error (collision):   2.2371e+04
# --------------------------------------------------
# [ Epoch 01080 ]
# * Relative error (gain):        6.3417e-03
# * Relative error (loss):        9.7024e-02
# * Relative error (collision):   2.2056e+04
# --------------------------------------------------
# [ Epoch 01090 ]
# * Relative error (gain):        6.3384e-03
# * Relative error (loss):        9.5516e-02
# * Relative error (collision):   2.1728e+04
# --------------------------------------------------
# [ Epoch 01100 ]
# * Relative error (gain):        6.3312e-03
# * Relative error (loss):        9.4030e-02
# * Relative error (collision):   2.1399e+04
# --------------------------------------------------
# [ Epoch 01110 ]
# * Relative error (gain):        6.3263e-03
# * Relative error (loss):        9.2564e-02
# * Relative error (collision):   2.1080e+04
# --------------------------------------------------
# [ Epoch 01120 ]
# * Relative error (gain):        6.3182e-03
# * Relative error (loss):        9.1114e-02
# * Relative error (collision):   2.0753e+04
# --------------------------------------------------
# [ Epoch 01130 ]
# * Relative error (gain):        6.3078e-03
# * Relative error (loss):        8.9680e-02
# * Relative error (collision):   2.0428e+04
# --------------------------------------------------
# [ Epoch 01140 ]
# * Relative error (gain):        6.3213e-03
# * Relative error (loss):        8.8262e-02
# * Relative error (collision):   2.0107e+04
# --------------------------------------------------
# [ Epoch 01150 ]
# * Relative error (gain):        6.3588e-03
# * Relative error (loss):        8.6855e-02
# * Relative error (collision):   1.9775e+04
# --------------------------------------------------
# [ Epoch 01160 ]
# * Relative error (gain):        6.3069e-03
# * Relative error (loss):        8.5460e-02
# * Relative error (collision):   1.9448e+04
# --------------------------------------------------
# [ Epoch 01170 ]
# * Relative error (gain):        6.2980e-03
# * Relative error (loss):        8.4074e-02
# * Relative error (collision):   1.9121e+04
# --------------------------------------------------
# [ Epoch 01180 ]
# * Relative error (gain):        6.3129e-03
# * Relative error (loss):        8.2697e-02
# * Relative error (collision):   1.8777e+04
# --------------------------------------------------
# [ Epoch 01190 ]
# * Relative error (gain):        6.3018e-03
# * Relative error (loss):        8.1329e-02
# * Relative error (collision):   1.8449e+04
# --------------------------------------------------
# [ Epoch 01200 ]
# * Relative error (gain):        6.2889e-03
# * Relative error (loss):        7.9968e-02
# * Relative error (collision):   1.8104e+04
# --------------------------------------------------
# [ Epoch 01210 ]
# * Relative error (gain):        6.2806e-03
# * Relative error (loss):        7.8616e-02
# * Relative error (collision):   1.7763e+04
# --------------------------------------------------
# [ Epoch 01220 ]
# * Relative error (gain):        6.2671e-03
# * Relative error (loss):        7.7272e-02
# * Relative error (collision):   1.7405e+04
# --------------------------------------------------
# [ Epoch 01230 ]
# * Relative error (gain):        6.2728e-03
# * Relative error (loss):        7.5935e-02
# * Relative error (collision):   1.7068e+04
# --------------------------------------------------
# [ Epoch 01240 ]
# * Relative error (gain):        6.2815e-03
# * Relative error (loss):        7.4605e-02
# * Relative error (collision):   1.6726e+04
# --------------------------------------------------
# [ Epoch 01250 ]
# * Relative error (gain):        6.2616e-03
# * Relative error (loss):        7.3283e-02
# * Relative error (collision):   1.6361e+04
# --------------------------------------------------
# [ Epoch 01260 ]
# * Relative error (gain):        6.2501e-03
# * Relative error (loss):        7.1969e-02
# * Relative error (collision):   1.6021e+04
# --------------------------------------------------
# [ Epoch 01270 ]
# * Relative error (gain):        6.2629e-03
# * Relative error (loss):        7.0662e-02
# * Relative error (collision):   1.5667e+04
# --------------------------------------------------
# [ Epoch 01280 ]
# * Relative error (gain):        6.2472e-03
# * Relative error (loss):        6.9364e-02
# * Relative error (collision):   1.5315e+04
# --------------------------------------------------
# [ Epoch 01290 ]
# * Relative error (gain):        6.2455e-03
# * Relative error (loss):        6.8074e-02
# * Relative error (collision):   1.4961e+04
# --------------------------------------------------
# [ Epoch 01300 ]
# * Relative error (gain):        6.2520e-03
# * Relative error (loss):        6.6794e-02
# * Relative error (collision):   1.4608e+04
# --------------------------------------------------
# [ Epoch 01310 ]
# * Relative error (gain):        6.2392e-03
# * Relative error (loss):        6.5525e-02
# * Relative error (collision):   1.4268e+04
# --------------------------------------------------
# [ Epoch 01320 ]
# * Relative error (gain):        6.2391e-03
# * Relative error (loss):        6.4268e-02
# * Relative error (collision):   1.3916e+04
# --------------------------------------------------
# [ Epoch 01330 ]
# * Relative error (gain):        6.2218e-03
# * Relative error (loss):        6.3027e-02
# * Relative error (collision):   1.3574e+04
# --------------------------------------------------
# [ Epoch 01340 ]
# * Relative error (gain):        6.2297e-03
# * Relative error (loss):        6.1801e-02
# * Relative error (collision):   1.3222e+04
# --------------------------------------------------
# [ Epoch 01350 ]
# * Relative error (gain):        6.2287e-03
# * Relative error (loss):        6.0594e-02
# * Relative error (collision):   1.2888e+04
# --------------------------------------------------
# [ Epoch 01360 ]
# * Relative error (gain):        6.2161e-03
# * Relative error (loss):        5.9411e-02
# * Relative error (collision):   1.2557e+04
# --------------------------------------------------
# [ Epoch 01370 ]
# * Relative error (gain):        6.2054e-03
# * Relative error (loss):        5.8255e-02
# * Relative error (collision):   1.2237e+04
# --------------------------------------------------
# [ Epoch 01380 ]
# * Relative error (gain):        6.2139e-03
# * Relative error (loss):        5.7130e-02
# * Relative error (collision):   1.1926e+04
# --------------------------------------------------
# [ Epoch 01390 ]
# * Relative error (gain):        6.1945e-03
# * Relative error (loss):        5.6041e-02
# * Relative error (collision):   1.1638e+04
# --------------------------------------------------
# [ Epoch 01400 ]
# * Relative error (gain):        6.2113e-03
# * Relative error (loss):        5.4985e-02
# * Relative error (collision):   1.1368e+04
# --------------------------------------------------
# [ Epoch 01410 ]
# * Relative error (gain):        6.2016e-03
# * Relative error (loss):        5.3964e-02
# * Relative error (collision):   1.1108e+04
# --------------------------------------------------
# [ Epoch 01420 ]
# * Relative error (gain):        6.1847e-03
# * Relative error (loss):        5.2979e-02
# * Relative error (collision):   1.0864e+04
# --------------------------------------------------
# [ Epoch 01430 ]
# * Relative error (gain):        6.2025e-03
# * Relative error (loss):        5.2028e-02
# * Relative error (collision):   1.0650e+04
# --------------------------------------------------
# [ Epoch 01440 ]
# * Relative error (gain):        6.1953e-03
# * Relative error (loss):        5.1110e-02
# * Relative error (collision):   1.0436e+04
# --------------------------------------------------
# [ Epoch 01450 ]
# * Relative error (gain):        6.2179e-03
# * Relative error (loss):        5.0223e-02
# * Relative error (collision):   1.0244e+04
# --------------------------------------------------
# [ Epoch 01460 ]
# * Relative error (gain):        6.1881e-03
# * Relative error (loss):        4.9364e-02
# * Relative error (collision):   1.0065e+04
# --------------------------------------------------
# [ Epoch 01470 ]
# * Relative error (gain):        6.1820e-03
# * Relative error (loss):        4.8534e-02
# * Relative error (collision):   9.8896e+03
# --------------------------------------------------
# [ Epoch 01480 ]
# * Relative error (gain):        6.1702e-03
# * Relative error (loss):        4.7730e-02
# * Relative error (collision):   9.7363e+03
# --------------------------------------------------
# [ Epoch 01490 ]
# * Relative error (gain):        6.1931e-03
# * Relative error (loss):        4.6951e-02
# * Relative error (collision):   9.5728e+03
# --------------------------------------------------
# [ Epoch 01500 ]
# * Relative error (gain):        6.2155e-03
# * Relative error (loss):        4.6195e-02
# * Relative error (collision):   9.4283e+03
# --------------------------------------------------
# [ Epoch 01510 ]
# * Relative error (gain):        6.2212e-03
# * Relative error (loss):        4.5461e-02
# * Relative error (collision):   9.2926e+03
# --------------------------------------------------
# [ Epoch 01520 ]
# * Relative error (gain):        6.1618e-03
# * Relative error (loss):        4.4749e-02
# * Relative error (collision):   9.1499e+03
# --------------------------------------------------
# [ Epoch 01530 ]
# * Relative error (gain):        6.1591e-03
# * Relative error (loss):        4.4058e-02
# * Relative error (collision):   9.0207e+03
# --------------------------------------------------
# [ Epoch 01540 ]
# * Relative error (gain):        6.1617e-03
# * Relative error (loss):        4.3385e-02
# * Relative error (collision):   8.8920e+03
# --------------------------------------------------
# [ Epoch 01550 ]
# * Relative error (gain):        6.1602e-03
# * Relative error (loss):        4.2730e-02
# * Relative error (collision):   8.7690e+03
# --------------------------------------------------
# [ Epoch 01560 ]
# * Relative error (gain):        6.1527e-03
# * Relative error (loss):        4.2094e-02
# * Relative error (collision):   8.6557e+03
# --------------------------------------------------
# [ Epoch 01570 ]
# * Relative error (gain):        6.1535e-03
# * Relative error (loss):        4.1473e-02
# * Relative error (collision):   8.5423e+03
# --------------------------------------------------
# [ Epoch 01580 ]
# * Relative error (gain):        6.1700e-03
# * Relative error (loss):        4.0867e-02
# * Relative error (collision):   8.4405e+03
# --------------------------------------------------
# [ Epoch 01590 ]
# * Relative error (gain):        6.1276e-03
# * Relative error (loss):        4.0276e-02
# * Relative error (collision):   8.3349e+03
# --------------------------------------------------
# [ Epoch 01600 ]
# * Relative error (gain):        6.1532e-03
# * Relative error (loss):        3.9700e-02
# * Relative error (collision):   8.2347e+03
# --------------------------------------------------
# [ Epoch 01610 ]
# * Relative error (gain):        6.1438e-03
# * Relative error (loss):        3.9136e-02
# * Relative error (collision):   8.1336e+03
# --------------------------------------------------
# [ Epoch 01620 ]
# * Relative error (gain):        6.1544e-03
# * Relative error (loss):        3.8586e-02
# * Relative error (collision):   8.0478e+03
# --------------------------------------------------
# [ Epoch 01630 ]
# * Relative error (gain):        6.1301e-03
# * Relative error (loss):        3.8047e-02
# * Relative error (collision):   7.9579e+03
# --------------------------------------------------
# [ Epoch 01640 ]
# * Relative error (gain):        6.1425e-03
# * Relative error (loss):        3.7518e-02
# * Relative error (collision):   7.8698e+03
# --------------------------------------------------
# [ Epoch 01650 ]
# * Relative error (gain):        6.1285e-03
# * Relative error (loss):        3.7001e-02
# * Relative error (collision):   7.7825e+03
# --------------------------------------------------
# [ Epoch 01660 ]
# * Relative error (gain):        6.1481e-03
# * Relative error (loss):        3.6493e-02
# * Relative error (collision):   7.6998e+03
# --------------------------------------------------
# [ Epoch 01670 ]
# * Relative error (gain):        6.1533e-03
# * Relative error (loss):        3.5996e-02
# * Relative error (collision):   7.6182e+03
# --------------------------------------------------
# [ Epoch 01680 ]
# * Relative error (gain):        6.1203e-03
# * Relative error (loss):        3.5507e-02
# * Relative error (collision):   7.5386e+03
# --------------------------------------------------
# [ Epoch 01690 ]
# * Relative error (gain):        6.1287e-03
# * Relative error (loss):        3.5027e-02
# * Relative error (collision):   7.4635e+03
# --------------------------------------------------
# [ Epoch 01700 ]
# * Relative error (gain):        6.1181e-03
# * Relative error (loss):        3.4557e-02
# * Relative error (collision):   7.3852e+03
# --------------------------------------------------
# [ Epoch 01710 ]
# * Relative error (gain):        6.1346e-03
# * Relative error (loss):        3.4093e-02
# * Relative error (collision):   7.3105e+03
# --------------------------------------------------
# [ Epoch 01720 ]
# * Relative error (gain):        6.1261e-03
# * Relative error (loss):        3.3637e-02
# * Relative error (collision):   7.2411e+03
# --------------------------------------------------
# [ Epoch 01730 ]
# * Relative error (gain):        6.1295e-03
# * Relative error (loss):        3.3189e-02
# * Relative error (collision):   7.1661e+03
# --------------------------------------------------
# [ Epoch 01740 ]
# * Relative error (gain):        6.1281e-03
# * Relative error (loss):        3.2746e-02
# * Relative error (collision):   7.1040e+03
# --------------------------------------------------
# [ Epoch 01750 ]
# * Relative error (gain):        6.1153e-03
# * Relative error (loss):        3.2310e-02
# * Relative error (collision):   7.0317e+03
# --------------------------------------------------
# [ Epoch 01760 ]
# * Relative error (gain):        6.1157e-03
# * Relative error (loss):        3.1879e-02
# * Relative error (collision):   6.9595e+03
# --------------------------------------------------
# [ Epoch 01770 ]
# * Relative error (gain):        6.1024e-03
# * Relative error (loss):        3.1455e-02
# * Relative error (collision):   6.8940e+03
# --------------------------------------------------
# [ Epoch 01780 ]
# * Relative error (gain):        6.1168e-03
# * Relative error (loss):        3.1037e-02
# * Relative error (collision):   6.8239e+03
# --------------------------------------------------
# [ Epoch 01790 ]
# * Relative error (gain):        6.0891e-03
# * Relative error (loss):        3.0622e-02
# * Relative error (collision):   6.7641e+03
# --------------------------------------------------
# [ Epoch 01800 ]
# * Relative error (gain):        6.1042e-03
# * Relative error (loss):        3.0213e-02
# * Relative error (collision):   6.6946e+03
# --------------------------------------------------
# [ Epoch 01810 ]
# * Relative error (gain):        6.1767e-03
# * Relative error (loss):        2.9810e-02
# * Relative error (collision):   6.6360e+03
# --------------------------------------------------
# [ Epoch 01820 ]
# * Relative error (gain):        6.1159e-03
# * Relative error (loss):        2.9411e-02
# * Relative error (collision):   6.5686e+03
# --------------------------------------------------
# [ Epoch 01830 ]
# * Relative error (gain):        6.1100e-03
# * Relative error (loss):        2.9018e-02
# * Relative error (collision):   6.5040e+03
# --------------------------------------------------
# [ Epoch 01840 ]
# * Relative error (gain):        6.0934e-03
# * Relative error (loss):        2.8631e-02
# * Relative error (collision):   6.4436e+03
# --------------------------------------------------
# [ Epoch 01850 ]
# * Relative error (gain):        6.0964e-03
# * Relative error (loss):        2.8248e-02
# * Relative error (collision):   6.3800e+03
# --------------------------------------------------
# [ Epoch 01860 ]
# * Relative error (gain):        6.0780e-03
# * Relative error (loss):        2.7870e-02
# * Relative error (collision):   6.3123e+03
# --------------------------------------------------
# [ Epoch 01870 ]
# * Relative error (gain):        6.0927e-03
# * Relative error (loss):        2.7494e-02
# * Relative error (collision):   6.2513e+03
# --------------------------------------------------
# [ Epoch 01880 ]
# * Relative error (gain):        6.0950e-03
# * Relative error (loss):        2.7122e-02
# * Relative error (collision):   6.2010e+03
# --------------------------------------------------
# [ Epoch 01890 ]
# * Relative error (gain):        6.0890e-03
# * Relative error (loss):        2.6754e-02
# * Relative error (collision):   6.1351e+03
# --------------------------------------------------
# [ Epoch 01900 ]
# * Relative error (gain):        6.0886e-03
# * Relative error (loss):        2.6389e-02
# * Relative error (collision):   6.0746e+03
# --------------------------------------------------
# [ Epoch 01910 ]
# * Relative error (gain):        6.0883e-03
# * Relative error (loss):        2.6026e-02
# * Relative error (collision):   6.0230e+03
# --------------------------------------------------
# [ Epoch 01920 ]
# * Relative error (gain):        6.0896e-03
# * Relative error (loss):        2.5667e-02
# * Relative error (collision):   5.9622e+03
# --------------------------------------------------
# [ Epoch 01930 ]
# * Relative error (gain):        6.0935e-03
# * Relative error (loss):        2.5312e-02
# * Relative error (collision):   5.9003e+03
# --------------------------------------------------
# [ Epoch 01940 ]
# * Relative error (gain):        6.0911e-03
# * Relative error (loss):        2.4960e-02
# * Relative error (collision):   5.8489e+03
# --------------------------------------------------
# [ Epoch 01950 ]
# * Relative error (gain):        6.0821e-03
# * Relative error (loss):        2.4615e-02
# * Relative error (collision):   5.7930e+03
# --------------------------------------------------
# [ Epoch 01960 ]
# * Relative error (gain):        6.0822e-03
# * Relative error (loss):        2.4275e-02
# * Relative error (collision):   5.7375e+03
# --------------------------------------------------
# [ Epoch 01970 ]
# * Relative error (gain):        6.0848e-03
# * Relative error (loss):        2.3939e-02
# * Relative error (collision):   5.6885e+03
# --------------------------------------------------
# [ Epoch 01980 ]
# * Relative error (gain):        6.0730e-03
# * Relative error (loss):        2.3608e-02
# * Relative error (collision):   5.6321e+03
# --------------------------------------------------
# [ Epoch 01990 ]
# * Relative error (gain):        6.0745e-03
# * Relative error (loss):        2.3280e-02
# * Relative error (collision):   5.5802e+03
# --------------------------------------------------
# [ Epoch 02000 ]
# * Relative error (gain):        6.0617e-03
# * Relative error (loss):        2.2956e-02
# * Relative error (collision):   5.5209e+03
# --------------------------------------------------
# [ Epoch 02010 ]
# * Relative error (gain):        6.0788e-03
# * Relative error (loss):        2.2637e-02
# * Relative error (collision):   5.4720e+03
# --------------------------------------------------
# [ Epoch 02020 ]
# * Relative error (gain):        6.0918e-03
# * Relative error (loss):        2.2322e-02
# * Relative error (collision):   5.4224e+03
# --------------------------------------------------
# [ Epoch 02030 ]
# * Relative error (gain):        6.0711e-03
# * Relative error (loss):        2.2014e-02
# * Relative error (collision):   5.3647e+03
# --------------------------------------------------
# [ Epoch 02040 ]
# * Relative error (gain):        6.0694e-03
# * Relative error (loss):        2.1711e-02
# * Relative error (collision):   5.3184e+03
# --------------------------------------------------
# [ Epoch 02050 ]
# * Relative error (gain):        6.0662e-03
# * Relative error (loss):        2.1414e-02
# * Relative error (collision):   5.2716e+03
# --------------------------------------------------
# [ Epoch 02060 ]
# * Relative error (gain):        6.0796e-03
# * Relative error (loss):        2.1123e-02
# * Relative error (collision):   5.2207e+03
# --------------------------------------------------
# [ Epoch 02070 ]
# * Relative error (gain):        6.0512e-03
# * Relative error (loss):        2.0842e-02
# * Relative error (collision):   5.1770e+03
# --------------------------------------------------
# [ Epoch 02080 ]
# * Relative error (gain):        6.0597e-03
# * Relative error (loss):        2.0568e-02
# * Relative error (collision):   5.1326e+03
# --------------------------------------------------
# [ Epoch 02090 ]
# * Relative error (gain):        6.0452e-03
# * Relative error (loss):        2.0299e-02
# * Relative error (collision):   5.0835e+03
# --------------------------------------------------
# [ Epoch 02100 ]
# * Relative error (gain):        6.0417e-03
# * Relative error (loss):        2.0036e-02
# * Relative error (collision):   5.0419e+03
# --------------------------------------------------
# [ Epoch 02110 ]
# * Relative error (gain):        6.0430e-03
# * Relative error (loss):        1.9780e-02
# * Relative error (collision):   5.0019e+03
# --------------------------------------------------
# [ Epoch 02120 ]
# * Relative error (gain):        6.0544e-03
# * Relative error (loss):        1.9530e-02
# * Relative error (collision):   4.9623e+03
# --------------------------------------------------
# [ Epoch 02130 ]
# * Relative error (gain):        6.0553e-03
# * Relative error (loss):        1.9286e-02
# * Relative error (collision):   4.9277e+03
# --------------------------------------------------
# [ Epoch 02140 ]
# * Relative error (gain):        6.0562e-03
# * Relative error (loss):        1.9047e-02
# * Relative error (collision):   4.8935e+03
# --------------------------------------------------
# [ Epoch 02150 ]
# * Relative error (gain):        6.0519e-03
# * Relative error (loss):        1.8815e-02
# * Relative error (collision):   4.8620e+03
# --------------------------------------------------
# [ Epoch 02160 ]
# * Relative error (gain):        6.0436e-03
# * Relative error (loss):        1.8590e-02
# * Relative error (collision):   4.8282e+03
# --------------------------------------------------
# [ Epoch 02170 ]
# * Relative error (gain):        6.0681e-03
# * Relative error (loss):        1.8371e-02
# * Relative error (collision):   4.8109e+03
# --------------------------------------------------
# [ Epoch 02180 ]
# * Relative error (gain):        6.0742e-03
# * Relative error (loss):        1.8156e-02
# * Relative error (collision):   4.7755e+03
# --------------------------------------------------
# [ Epoch 02190 ]
# * Relative error (gain):        6.0468e-03
# * Relative error (loss):        1.7944e-02
# * Relative error (collision):   4.7444e+03
# --------------------------------------------------
# [ Epoch 02200 ]
# * Relative error (gain):        6.0428e-03
# * Relative error (loss):        1.7737e-02
# * Relative error (collision):   4.7158e+03
# --------------------------------------------------
# [ Epoch 02210 ]
# * Relative error (gain):        6.0426e-03
# * Relative error (loss):        1.7535e-02
# * Relative error (collision):   4.6953e+03
# --------------------------------------------------
# [ Epoch 02220 ]
# * Relative error (gain):        6.0287e-03
# * Relative error (loss):        1.7339e-02
# * Relative error (collision):   4.6721e+03
# --------------------------------------------------
# [ Epoch 02230 ]
# * Relative error (gain):        6.0475e-03
# * Relative error (loss):        1.7145e-02
# * Relative error (collision):   4.6556e+03
# --------------------------------------------------
# [ Epoch 02240 ]
# * Relative error (gain):        6.0370e-03
# * Relative error (loss):        1.6956e-02
# * Relative error (collision):   4.6347e+03
# --------------------------------------------------
# [ Epoch 02250 ]
# * Relative error (gain):        6.0365e-03
# * Relative error (loss):        1.6769e-02
# * Relative error (collision):   4.6038e+03
# --------------------------------------------------
# [ Epoch 02260 ]
# * Relative error (gain):        6.0734e-03
# * Relative error (loss):        1.6588e-02
# * Relative error (collision):   4.5921e+03
# --------------------------------------------------
# [ Epoch 02270 ]
# * Relative error (gain):        6.0459e-03
# * Relative error (loss):        1.6408e-02
# * Relative error (collision):   4.5737e+03
# --------------------------------------------------
# [ Epoch 02280 ]
# * Relative error (gain):        6.0286e-03
# * Relative error (loss):        1.6232e-02
# * Relative error (collision):   4.5463e+03
# --------------------------------------------------
# [ Epoch 02290 ]
# * Relative error (gain):        6.0368e-03
# * Relative error (loss):        1.6056e-02
# * Relative error (collision):   4.5318e+03
# --------------------------------------------------
# [ Epoch 02300 ]
# * Relative error (gain):        6.0382e-03
# * Relative error (loss):        1.5883e-02
# * Relative error (collision):   4.5144e+03
# --------------------------------------------------
# [ Epoch 02310 ]
# * Relative error (gain):        6.0396e-03
# * Relative error (loss):        1.5716e-02
# * Relative error (collision):   4.5014e+03
# --------------------------------------------------
# [ Epoch 02320 ]
# * Relative error (gain):        6.0463e-03
# * Relative error (loss):        1.5553e-02
# * Relative error (collision):   4.4859e+03
# --------------------------------------------------
# [ Epoch 02330 ]
# * Relative error (gain):        6.0358e-03
# * Relative error (loss):        1.5394e-02
# * Relative error (collision):   4.4724e+03
# --------------------------------------------------
# [ Epoch 02340 ]
# * Relative error (gain):        6.0223e-03
# * Relative error (loss):        1.5238e-02
# * Relative error (collision):   4.4570e+03
# --------------------------------------------------
# [ Epoch 02350 ]
# * Relative error (gain):        6.0159e-03
# * Relative error (loss):        1.5085e-02
# * Relative error (collision):   4.4366e+03
# --------------------------------------------------
# [ Epoch 02360 ]
# * Relative error (gain):        6.0191e-03
# * Relative error (loss):        1.4936e-02
# * Relative error (collision):   4.4248e+03
# --------------------------------------------------
# [ Epoch 02370 ]
# * Relative error (gain):        6.0221e-03
# * Relative error (loss):        1.4790e-02
# * Relative error (collision):   4.4111e+03
# --------------------------------------------------
# [ Epoch 02380 ]
# * Relative error (gain):        6.0342e-03
# * Relative error (loss):        1.4647e-02
# * Relative error (collision):   4.3984e+03
# --------------------------------------------------
# [ Epoch 02390 ]
# * Relative error (gain):        6.0215e-03
# * Relative error (loss):        1.4507e-02
# * Relative error (collision):   4.3850e+03
# --------------------------------------------------
# [ Epoch 02400 ]
# * Relative error (gain):        6.0257e-03
# * Relative error (loss):        1.4369e-02
# * Relative error (collision):   4.3733e+03
# --------------------------------------------------
# [ Epoch 02410 ]
# * Relative error (gain):        6.0000e-03
# * Relative error (loss):        1.4234e-02
# * Relative error (collision):   4.3577e+03
# --------------------------------------------------
# [ Epoch 02420 ]
# * Relative error (gain):        6.0176e-03
# * Relative error (loss):        1.4101e-02
# * Relative error (collision):   4.3507e+03
# --------------------------------------------------
# [ Epoch 02430 ]
# * Relative error (gain):        6.0206e-03
# * Relative error (loss):        1.3971e-02
# * Relative error (collision):   4.3399e+03
# --------------------------------------------------
# [ Epoch 02440 ]
# * Relative error (gain):        5.9940e-03
# * Relative error (loss):        1.3842e-02
# ...
# * Relative error (collision):   2.9926e+03
# --------------------------------------------------
# [ Epoch 09200 ]
# * Relative error (gain):        5.8297e-03
# * Relative error (loss):        1.2435e-03
# * Relative error (collision):   2.9955e+03
# --------------------------------------------------
# [ Epoch 09210 ]
# * Relative error (gain):        5.8322e-03
# * Relative error (loss):        1.2414e-03
# * Relative error (collision):   2.9976e+03
# --------------------------------------------------
# [ Epoch 09220 ]
# * Relative error (gain):        5.8372e-03
# * Relative error (loss):        1.2403e-03
# * Relative error (collision):   2.9993e+03
# --------------------------------------------------
# [ Epoch 09230 ]
# * Relative error (gain):        5.8238e-03
# * Relative error (loss):        1.2374e-03
# * Relative error (collision):   2.9941e+03
# --------------------------------------------------
# [ Epoch 09240 ]
# * Relative error (gain):        5.8263e-03
# * Relative error (loss):        1.2353e-03
# * Relative error (collision):   2.9937e+03
# --------------------------------------------------
# [ Epoch 09250 ]
# * Relative error (gain):        5.8294e-03
# * Relative error (loss):        1.2333e-03
# * Relative error (collision):   2.9948e+03
# --------------------------------------------------
# [ Epoch 09260 ]
# * Relative error (gain):        5.8310e-03
# * Relative error (loss):        1.2316e-03
# * Relative error (collision):   2.9936e+03
# --------------------------------------------------
# [ Epoch 09270 ]
# * Relative error (gain):        5.8300e-03
# * Relative error (loss):        1.2292e-03
# * Relative error (collision):   2.9953e+03
# --------------------------------------------------
# [ Epoch 09280 ]
# * Relative error (gain):        5.8435e-03
# * Relative error (loss):        1.2271e-03
# * Relative error (collision):   2.9989e+03
# --------------------------------------------------
# [ Epoch 09290 ]
# * Relative error (gain):        5.8251e-03
# * Relative error (loss):        1.2252e-03
# * Relative error (collision):   2.9928e+03
# --------------------------------------------------
# [ Epoch 09300 ]
# * Relative error (gain):        5.8163e-03
# * Relative error (loss):        1.2231e-03
# * Relative error (collision):   2.9893e+03
# --------------------------------------------------
# [ Epoch 09310 ]
# * Relative error (gain):        6.0916e-03
# * Relative error (loss):        1.2209e-03
# * Relative error (collision):   3.1158e+03
# --------------------------------------------------
# [ Epoch 09320 ]
# * Relative error (gain):        5.9759e-03
# * Relative error (loss):        1.2188e-03
# * Relative error (collision):   3.0585e+03
# --------------------------------------------------
# [ Epoch 09330 ]
# * Relative error (gain):        6.0062e-03
# * Relative error (loss):        1.2169e-03
# * Relative error (collision):   3.0719e+03
# --------------------------------------------------
# [ Epoch 09340 ]
# * Relative error (gain):        5.9551e-03
# * Relative error (loss):        1.2150e-03
# * Relative error (collision):   3.0413e+03
# --------------------------------------------------
# [ Epoch 09350 ]
# * Relative error (gain):        5.8883e-03
# * Relative error (loss):        1.2127e-03
# * Relative error (collision):   3.0200e+03
# --------------------------------------------------
# [ Epoch 09360 ]
# * Relative error (gain):        5.8474e-03
# * Relative error (loss):        1.2106e-03
# * Relative error (collision):   2.9967e+03
# --------------------------------------------------
# [ Epoch 09370 ]
# * Relative error (gain):        5.8412e-03
# * Relative error (loss):        1.2087e-03
# * Relative error (collision):   2.9963e+03
# --------------------------------------------------
# [ Epoch 09380 ]
# * Relative error (gain):        5.8305e-03
# * Relative error (loss):        1.2068e-03
# * Relative error (collision):   2.9951e+03
# --------------------------------------------------
# [ Epoch 09390 ]
# * Relative error (gain):        5.8264e-03
# * Relative error (loss):        1.2047e-03
# * Relative error (collision):   2.9917e+03
# --------------------------------------------------
# [ Epoch 09400 ]
# * Relative error (gain):        5.8317e-03
# * Relative error (loss):        1.2028e-03
# * Relative error (collision):   2.9910e+03
# --------------------------------------------------
# [ Epoch 09410 ]
# * Relative error (gain):        5.8310e-03
# * Relative error (loss):        1.2008e-03
# * Relative error (collision):   2.9945e+03
# --------------------------------------------------
# [ Epoch 09420 ]
# * Relative error (gain):        5.8310e-03
# * Relative error (loss):        1.1988e-03
# * Relative error (collision):   2.9921e+03
# --------------------------------------------------
# [ Epoch 09430 ]
# * Relative error (gain):        5.8175e-03
# * Relative error (loss):        1.1969e-03
# * Relative error (collision):   2.9880e+03
# --------------------------------------------------
# [ Epoch 09440 ]
# * Relative error (gain):        5.8484e-03
# * Relative error (loss):        1.1950e-03
# * Relative error (collision):   3.0009e+03
# --------------------------------------------------
# [ Epoch 09450 ]
# * Relative error (gain):        5.8345e-03
# * Relative error (loss):        1.1932e-03
# * Relative error (collision):   2.9943e+03
# --------------------------------------------------
# [ Epoch 09460 ]
# * Relative error (gain):        5.8236e-03
# * Relative error (loss):        1.1917e-03
# * Relative error (collision):   2.9880e+03
# --------------------------------------------------
# [ Epoch 09470 ]
# * Relative error (gain):        5.8648e-03
# * Relative error (loss):        1.1896e-03
# * Relative error (collision):   3.0115e+03
# --------------------------------------------------
# [ Epoch 09480 ]
# * Relative error (gain):        5.8351e-03
# * Relative error (loss):        1.1878e-03
# * Relative error (collision):   2.9920e+03
# --------------------------------------------------
# [ Epoch 09490 ]
# * Relative error (gain):        5.8215e-03
# * Relative error (loss):        1.1858e-03
# * Relative error (collision):   2.9873e+03
# --------------------------------------------------
# [ Epoch 09500 ]
# * Relative error (gain):        5.8378e-03
# * Relative error (loss):        1.1841e-03
# * Relative error (collision):   2.9963e+03
# --------------------------------------------------
# [ Epoch 09510 ]
# * Relative error (gain):        5.8359e-03
# * Relative error (loss):        1.1821e-03
# * Relative error (collision):   2.9937e+03
# --------------------------------------------------
# [ Epoch 09520 ]
# * Relative error (gain):        5.8299e-03
# * Relative error (loss):        1.1803e-03
# * Relative error (collision):   2.9914e+03
# --------------------------------------------------
# [ Epoch 09530 ]
# * Relative error (gain):        5.8253e-03
# * Relative error (loss):        1.1785e-03
# * Relative error (collision):   2.9885e+03
# --------------------------------------------------
# [ Epoch 09540 ]
# * Relative error (gain):        5.8328e-03
# * Relative error (loss):        1.1766e-03
# * Relative error (collision):   2.9910e+03
# --------------------------------------------------
# [ Epoch 09550 ]
# * Relative error (gain):        5.8318e-03
# * Relative error (loss):        1.1747e-03
# * Relative error (collision):   2.9905e+03
# --------------------------------------------------
# [ Epoch 09560 ]
# * Relative error (gain):        5.8327e-03
# * Relative error (loss):        1.1729e-03
# * Relative error (collision):   2.9914e+03
# --------------------------------------------------
# [ Epoch 09570 ]
# * Relative error (gain):        5.8178e-03
# * Relative error (loss):        1.1712e-03
# * Relative error (collision):   2.9869e+03
# --------------------------------------------------
# [ Epoch 09580 ]
# * Relative error (gain):        5.8321e-03
# * Relative error (loss):        1.1693e-03
# * Relative error (collision):   2.9905e+03
# --------------------------------------------------
# [ Epoch 09590 ]
# * Relative error (gain):        5.8286e-03
# * Relative error (loss):        1.1677e-03
# * Relative error (collision):   2.9895e+03
# --------------------------------------------------
# [ Epoch 09600 ]
# * Relative error (gain):        5.8285e-03
# * Relative error (loss):        1.1659e-03
# * Relative error (collision):   2.9899e+03
# --------------------------------------------------
# [ Epoch 09610 ]
# * Relative error (gain):        5.8199e-03
# * Relative error (loss):        1.1638e-03
# * Relative error (collision):   2.9887e+03
# --------------------------------------------------
# [ Epoch 09620 ]
# * Relative error (gain):        5.8340e-03
# * Relative error (loss):        1.1621e-03
# * Relative error (collision):   2.9923e+03
# --------------------------------------------------
# [ Epoch 09630 ]
# * Relative error (gain):        5.8218e-03
# * Relative error (loss):        1.1603e-03
# * Relative error (collision):   2.9880e+03
# --------------------------------------------------
# [ Epoch 09640 ]
# * Relative error (gain):        5.8494e-03
# * Relative error (loss):        1.1586e-03
# * Relative error (collision):   2.9988e+03
# --------------------------------------------------
# [ Epoch 09650 ]
# * Relative error (gain):        5.8263e-03
# * Relative error (loss):        1.1569e-03
# * Relative error (collision):   2.9878e+03
# --------------------------------------------------
# [ Epoch 09660 ]
# * Relative error (gain):        6.0348e-03
# * Relative error (loss):        1.1547e-03
# * Relative error (collision):   3.0797e+03
# --------------------------------------------------
# [ Epoch 09670 ]
# * Relative error (gain):        5.9221e-03
# * Relative error (loss):        1.1529e-03
# * Relative error (collision):   3.0325e+03
# --------------------------------------------------
# [ Epoch 09680 ]
# * Relative error (gain):        5.9545e-03
# * Relative error (loss):        1.1510e-03
# * Relative error (collision):   3.0387e+03
# --------------------------------------------------
# [ Epoch 09690 ]
# * Relative error (gain):        5.9387e-03
# * Relative error (loss):        1.1495e-03
# * Relative error (collision):   3.0327e+03
# --------------------------------------------------
# [ Epoch 09700 ]
# * Relative error (gain):        6.2103e-03
# * Relative error (loss):        1.1476e-03
# * Relative error (collision):   3.1615e+03
# --------------------------------------------------
# [ Epoch 09710 ]
# * Relative error (gain):        6.1499e-03
# * Relative error (loss):        1.1463e-03
# * Relative error (collision):   3.1369e+03
# --------------------------------------------------
# [ Epoch 09720 ]
# * Relative error (gain):        6.0768e-03
# * Relative error (loss):        1.1443e-03
# * Relative error (collision):   3.0946e+03
# --------------------------------------------------
# [ Epoch 09730 ]
# * Relative error (gain):        5.9911e-03
# * Relative error (loss):        1.1424e-03
# * Relative error (collision):   3.0603e+03
# --------------------------------------------------
# [ Epoch 09740 ]
# * Relative error (gain):        5.9371e-03
# * Relative error (loss):        1.1407e-03
# * Relative error (collision):   3.0402e+03
# --------------------------------------------------
# [ Epoch 09750 ]
# * Relative error (gain):        5.8231e-03
# * Relative error (loss):        1.1391e-03
# * Relative error (collision):   2.9903e+03
# --------------------------------------------------
# [ Epoch 09760 ]
# * Relative error (gain):        5.8113e-03
# * Relative error (loss):        1.1373e-03
# * Relative error (collision):   2.9800e+03
# --------------------------------------------------
# [ Epoch 09770 ]
# * Relative error (gain):        5.7904e-03
# * Relative error (loss):        1.1360e-03
# * Relative error (collision):   2.9754e+03
# --------------------------------------------------
# [ Epoch 09780 ]
# * Relative error (gain):        5.8005e-03
# * Relative error (loss):        1.1341e-03
# * Relative error (collision):   2.9785e+03
# --------------------------------------------------
# [ Epoch 09790 ]
# * Relative error (gain):        5.8182e-03
# * Relative error (loss):        1.1321e-03
# * Relative error (collision):   2.9818e+03
# --------------------------------------------------
# [ Epoch 09800 ]
# * Relative error (gain):        5.8194e-03
# * Relative error (loss):        1.1303e-03
# * Relative error (collision):   2.9848e+03
# --------------------------------------------------
# [ Epoch 09810 ]
# * Relative error (gain):        5.8211e-03
# * Relative error (loss):        1.1288e-03
# * Relative error (collision):   2.9833e+03
# --------------------------------------------------
# [ Epoch 09820 ]
# * Relative error (gain):        5.8141e-03
# * Relative error (loss):        1.1270e-03
# * Relative error (collision):   2.9816e+03
# --------------------------------------------------
# [ Epoch 09830 ]
# * Relative error (gain):        5.8180e-03
# * Relative error (loss):        1.1254e-03
# * Relative error (collision):   2.9815e+03
# --------------------------------------------------
# [ Epoch 09840 ]
# * Relative error (gain):        5.8217e-03
# * Relative error (loss):        1.1240e-03
# * Relative error (collision):   2.9846e+03
# --------------------------------------------------
# [ Epoch 09850 ]
# * Relative error (gain):        5.8194e-03
# * Relative error (loss):        1.1219e-03
# * Relative error (collision):   2.9829e+03
# --------------------------------------------------
# [ Epoch 09860 ]
# * Relative error (gain):        5.8155e-03
# * Relative error (loss):        1.1204e-03
# * Relative error (collision):   2.9828e+03
# --------------------------------------------------
# [ Epoch 09870 ]
# * Relative error (gain):        5.9992e-03
# * Relative error (loss):        1.1186e-03
# * Relative error (collision):   3.0653e+03
# --------------------------------------------------
# [ Epoch 09880 ]
# * Relative error (gain):        5.9607e-03
# * Relative error (loss):        1.1169e-03
# * Relative error (collision):   3.0448e+03
# --------------------------------------------------
# [ Epoch 09890 ]
# * Relative error (gain):        5.8319e-03
# * Relative error (loss):        1.1153e-03
# * Relative error (collision):   2.9888e+03
# --------------------------------------------------
# [ Epoch 09900 ]
# * Relative error (gain):        5.8315e-03
# * Relative error (loss):        1.1137e-03
# * Relative error (collision):   2.9886e+03
# --------------------------------------------------
# [ Epoch 09910 ]
# * Relative error (gain):        5.8294e-03
# * Relative error (loss):        1.1118e-03
# * Relative error (collision):   2.9876e+03
# --------------------------------------------------
# [ Epoch 09920 ]
# * Relative error (gain):        5.8253e-03
# * Relative error (loss):        1.1100e-03
# * Relative error (collision):   2.9860e+03
# --------------------------------------------------
# [ Epoch 09930 ]
# * Relative error (gain):        5.8162e-03
# * Relative error (loss):        1.1087e-03
# * Relative error (collision):   2.9808e+03
# --------------------------------------------------
# [ Epoch 09940 ]
# * Relative error (gain):        5.8150e-03
# * Relative error (loss):        1.1070e-03
# * Relative error (collision):   2.9825e+03
# --------------------------------------------------
# [ Epoch 09950 ]
# * Relative error (gain):        6.0187e-03
# * Relative error (loss):        1.1054e-03
# * Relative error (collision):   3.0711e+03
# --------------------------------------------------
# [ Epoch 09960 ]
# * Relative error (gain):        5.9537e-03
# * Relative error (loss):        1.1037e-03
# * Relative error (collision):   3.0414e+03
# --------------------------------------------------
# [ Epoch 09970 ]
# * Relative error (gain):        5.9130e-03
# * Relative error (loss):        1.1021e-03
# * Relative error (collision):   3.0260e+03
# --------------------------------------------------
# [ Epoch 09980 ]
# * Relative error (gain):        5.8132e-03
# * Relative error (loss):        1.1006e-03
# * Relative error (collision):   2.9792e+03
# --------------------------------------------------
# [ Epoch 09990 ]
# * Relative error (gain):        5.8289e-03
# * Relative error (loss):        1.0991e-03
# * Relative error (collision):   2.9853e+03
# --------------------------------------------------
# [ Epoch 10000 ]
# * Relative error (gain):        5.8242e-03
# * Relative error (loss):        1.0974e-03
# * Relative error (collision):   2.9831e+03
# --------------------------------------------------
# FourierBoltzmannLayer()

# %%
arr_f, arr_gain, arr_loss = dataset[:]
arr_q = (arr_gain - arr_loss).to(device)
pred = specnet.forward(torch.fft.fftn(arr_f.to(device), dim=FFT_DIM, norm=FFT_NORM))
pred = torch.fft.ifftn(pred, dim=FFT_DIM, norm=FFT_NORM).real.detach()

# %%
plt.imshow((pred-arr_q)[51*30, 0, 0, ..., 0].cpu().numpy(), cmap='jet')
plt.colorbar()
plt.show()

# %% [markdown]
# End of file

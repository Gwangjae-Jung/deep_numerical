# %%
from    typing              import  *
from    typing_extensions   import  Self

from    tqdm.notebook       import  tqdm

import  numpy               as  np
import  matplotlib.pyplot   as  plt

import  torch
from    torch.utils.data    import  Dataset, DataLoader


from    pathlib             import  Path
root_dir    = r"/media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE"
path_root   = Path(root_dir)
path_lib    = path_root / "python_deep_numerical"
path_data   = path_root / "datasets"

import  sys
sys.path.append( str(path_lib) )
from    pytorch.layers                  import  FourierLandauLayer
from    pytorch.torch_numerical         import  utils
from    pytorch.utils                   import  initialize_weights


dtype  = torch.float32
dtype_complex = utils.dtype_real_to_complex(dtype)
device = torch.device('cuda:2')
__dtype_str = str(dtype).split(".")[-1]
dtype_and_device = {'dtype': dtype, 'device': device}
print(f"Device for computation\n>>> {device}")
# Out:
# Device for computation
# >>> cuda:2

# %%
DIMENSION:  int     = 2
RESOLUTION: int     = 64
VHS_ALPHA:  float   = 0.0

_file = path_data / f"{__dtype_str}/Landau__alpha_{int(VHS_ALPHA)}__res_{RESOLUTION}.npz"
print(f"Loading data from\n>>> {_file}")
file = np.load(_file)

V_MAX:      float   = float(file['v_max'])
DELTA_V:    float   = (2*V_MAX) / RESOLUTION
FFT_NORM:   str     = 'forward'

VHS_COEFF:  float   = file['vhs_coeff']
# Out:
# Loading data from
# >>> /media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE/datasets/float32/Landau__alpha_0__res_64.npz

# %%
class CustomDataset(Dataset):
    def __init__(
            self,
            distr:      torch.Tensor,
            gain_fft:   torch.Tensor,
            loss_fft:   torch.Tensor,
            vhs_alpha:  Optional[torch.Tensor]  = None,
            dim:        Optional[int]           = None,
            squeeze_space: bool = False,
        ) -> Self:
        self.dim:       int                         = dim
        self.distr:     torch.Tensor                = distr
        self.gain_fft:  torch.Tensor                = gain_fft
        self.loss_fft:  torch.Tensor                = loss_fft
        self.vhs_alpha: Optional[torch.Tensor]      = vhs_alpha
        self.__fft_dim: tuple[int] = tuple(range(1+dim, 1+2*dim))
        
        if squeeze_space:
            self.distr      = self.distr.reshape(distr.size(0), *distr.shape[-1-dim:])
            self.gain_fft   = self.gain_fft.reshape(gain_fft.size(0), *gain_fft.shape[-1-dim:])
            self.loss_fft   = self.loss_fft.reshape(loss_fft.size(0), *loss_fft.shape[-1-dim:])
            self.__fft_dim  = tuple(range(1, 1+dim))
            
        return
    
    
    def __getitem__(self, index: int) -> tuple[torch.Tensor]:
        if self.vhs_alpha:
            return self.distr[index], self.gain_fft[index], self.loss_fft[index], self.vhs_alpha[index]
        else:
            return self.distr[index], self.gain_fft[index], self.loss_fft[index]
    
    def __len__(self) -> int:
        return self.distr.size(0)
    
    
    @property
    def fft_dim(self) -> tuple[int]:
        return self.__fft_dim

# %%
dataset  = CustomDataset(
    torch.tensor(file['data'], dtype=dtype),
    torch.tensor(file['gain_fft'], dtype=dtype_complex),
    torch.tensor(file['loss_fft'], dtype=dtype_complex),
    dim=DIMENSION,
    squeeze_space=False,
)
dataloader  = DataLoader(dataset, batch_size=256, shuffle=True)
FFT_DIM = dataset.fft_dim

# %%
specnet     = FourierLandauLayer(DIMENSION, 8).to(device)
initialize_weights(specnet, 'xavier uniform')
optimizer   = torch.optim.Adam(specnet.parameters(), lr=1e-2)

print(specnet)
# Out:
# ==============================< FourierLandauLayer >==============================
# [ Subnetworks ]
#
# ----------------------------------------------------------------------------------
# [ Parameters ]
# ( params_id )
# - Shape:       [16, 16, 1]
# - Data type:   torch.complex64
# ( params_proj )
# - Shape:       [16, 16, 1, 2, 2]
# - Data type:   torch.complex64
# ----------------------------------------------------------------------------------
# Number of parameters: 2560
# ==================================================================================

# %%
NUM_EPOCHS: int = 10000
dv = DELTA_V**DIMENSION
specnet.train()

data:       torch.Tensor
gain_fft:   torch.Tensor
loss_fft:   torch.Tensor

for epoch in tqdm(range(1, 1+NUM_EPOCHS)):
    abs_error:  float = 0.0
    rel_error:  float = 0.0
    
    for data, gain_fft, loss_fft in dataloader:
        data        = data.to(device)
        data_fft:   torch.Tensor = torch.fft.fftn(data, dim=FFT_DIM, norm=FFT_NORM)
        gain_fft    = gain_fft.to(device)
        loss_fft    = loss_fft.to(device)
        target_collision:   torch.Tensor = torch.fft.ifftn(gain_fft-loss_fft, dim=FFT_DIM, norm=FFT_NORM).real

        # pred_gain_fft = sm_object.compute_gain_fft(None, data_fft)
        # pred_loss_fft = sm_object.compute_loss_fft(None, data_fft)
        # pred_gain_fft = specnet.compute_gain_fft(data_fft)
        # pred_loss_fft = specnet.compute_loss_fft(data_fft)
        pred_fft        = specnet.forward(data_fft)
        pred_collision: torch.Tensor = torch.fft.ifftn(pred_fft, dim=FFT_DIM, norm=FFT_NORM).real

        _data_size = len(data)
        _abs_error = utils.absolute_error(pred_collision, target_collision).mean()
        _rel_error = utils.relative_error(pred_collision, target_collision).mean()
        abs_error += _abs_error.item() * _data_size
        rel_error += _rel_error.item() * _data_size
        
        optimizer.zero_grad()
        _rel_error.backward()
        optimizer.step()
        
    __abs_scale = dv/len(dataset)
    __rel_scale = 1.0/len(dataset)
    abs_error       *= __abs_scale
    rel_error       *= __rel_scale
    if epoch%10==0 or epoch==1:
        print(f"[ Epoch {str(epoch).zfill(len(str(NUM_EPOCHS)))} ]")
        print(f"* Absolute error:       {abs_error:.4e}")
        print(f"* Relative error:       {rel_error:.4e}")
        print('-'*80)
    if rel_error < 1e-3:
        print(f"Achieved relative error {_rel_error:.4e} at epoch {epoch}.")
        break

specnet.eval()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# [ Epoch 00001 ]
# * Absolute error:       2.0245e-01
# * Relative error:       9.1070e-01
# --------------------------------------------------------------------------------
# [ Epoch 00010 ]
# * Absolute error:       1.3140e-01
# * Relative error:       3.6418e-01
# --------------------------------------------------------------------------------
# [ Epoch 00020 ]
# * Absolute error:       7.6638e-02
# * Relative error:       2.1465e-01
# --------------------------------------------------------------------------------
# [ Epoch 00030 ]
# * Absolute error:       5.5057e-02
# * Relative error:       1.4664e-01
# --------------------------------------------------------------------------------
# [ Epoch 00040 ]
# * Absolute error:       4.9535e-02
# * Relative error:       1.2833e-01
# --------------------------------------------------------------------------------
# [ Epoch 00050 ]
# * Absolute error:       4.8387e-02
# * Relative error:       1.2347e-01
# --------------------------------------------------------------------------------
# [ Epoch 00060 ]
# * Absolute error:       4.7912e-02
# * Relative error:       1.2155e-01
# --------------------------------------------------------------------------------
# [ Epoch 00070 ]
# * Absolute error:       4.7544e-02
# * Relative error:       1.2002e-01
# --------------------------------------------------------------------------------
# [ Epoch 00080 ]
# * Absolute error:       4.7179e-02
# * Relative error:       1.1865e-01
# --------------------------------------------------------------------------------
# [ Epoch 00090 ]
# * Absolute error:       4.6824e-02
# * Relative error:       1.1735e-01
# --------------------------------------------------------------------------------
# [ Epoch 00100 ]
# * Absolute error:       4.6424e-02
# * Relative error:       1.1601e-01
# --------------------------------------------------------------------------------
# [ Epoch 00110 ]
# * Absolute error:       4.5983e-02
# * Relative error:       1.1473e-01
# --------------------------------------------------------------------------------
# [ Epoch 00120 ]
# * Absolute error:       4.5508e-02
# * Relative error:       1.1353e-01
# --------------------------------------------------------------------------------
# [ Epoch 00130 ]
# * Absolute error:       4.4990e-02
# * Relative error:       1.1230e-01
# --------------------------------------------------------------------------------
# [ Epoch 00140 ]
# * Absolute error:       4.4436e-02
# * Relative error:       1.1113e-01
# --------------------------------------------------------------------------------
# [ Epoch 00150 ]
# * Absolute error:       4.3856e-02
# * Relative error:       1.0997e-01
# --------------------------------------------------------------------------------
# [ Epoch 00160 ]
# * Absolute error:       4.3263e-02
# * Relative error:       1.0891e-01
# --------------------------------------------------------------------------------
# [ Epoch 00170 ]
# * Absolute error:       4.2648e-02
# * Relative error:       1.0785e-01
# --------------------------------------------------------------------------------
# [ Epoch 00180 ]
# * Absolute error:       4.2021e-02
# * Relative error:       1.0691e-01
# --------------------------------------------------------------------------------
# [ Epoch 00190 ]
# * Absolute error:       4.1403e-02
# * Relative error:       1.0574e-01
# --------------------------------------------------------------------------------
# [ Epoch 00200 ]
# * Absolute error:       4.0781e-02
# * Relative error:       1.0478e-01
# --------------------------------------------------------------------------------
# [ Epoch 00210 ]
# * Absolute error:       4.0169e-02
# * Relative error:       1.0377e-01
# --------------------------------------------------------------------------------
# [ Epoch 00220 ]
# * Absolute error:       3.9549e-02
# * Relative error:       1.0283e-01
# --------------------------------------------------------------------------------
# [ Epoch 00230 ]
# * Absolute error:       3.8981e-02
# * Relative error:       1.0194e-01
# --------------------------------------------------------------------------------
# [ Epoch 00240 ]
# * Absolute error:       3.8403e-02
# * Relative error:       1.0114e-01
# --------------------------------------------------------------------------------
# [ Epoch 00250 ]
# * Absolute error:       3.7843e-02
# * Relative error:       1.0022e-01
# --------------------------------------------------------------------------------
# [ Epoch 00260 ]
# * Absolute error:       3.7298e-02
# * Relative error:       9.9414e-02
# --------------------------------------------------------------------------------
# [ Epoch 00270 ]
# * Absolute error:       3.6770e-02
# * Relative error:       9.8564e-02
# --------------------------------------------------------------------------------
# [ Epoch 00280 ]
# * Absolute error:       3.6261e-02
# * Relative error:       9.7838e-02
# --------------------------------------------------------------------------------
# [ Epoch 00290 ]
# * Absolute error:       3.5758e-02
# * Relative error:       9.7044e-02
# --------------------------------------------------------------------------------
# [ Epoch 00300 ]
# * Absolute error:       3.5299e-02
# * Relative error:       9.6374e-02
# --------------------------------------------------------------------------------
# [ Epoch 00310 ]
# * Absolute error:       3.4822e-02
# * Relative error:       9.5696e-02
# --------------------------------------------------------------------------------
# [ Epoch 00320 ]
# * Absolute error:       3.4348e-02
# * Relative error:       9.4991e-02
# --------------------------------------------------------------------------------
# [ Epoch 00330 ]
# * Absolute error:       3.3923e-02
# * Relative error:       9.4318e-02
# --------------------------------------------------------------------------------
# [ Epoch 00340 ]
# * Absolute error:       3.3532e-02
# * Relative error:       9.3730e-02
# --------------------------------------------------------------------------------
# [ Epoch 00350 ]
# * Absolute error:       3.3105e-02
# * Relative error:       9.3047e-02
# --------------------------------------------------------------------------------
# [ Epoch 00360 ]
# * Absolute error:       3.2726e-02
# * Relative error:       9.2530e-02
# --------------------------------------------------------------------------------
# [ Epoch 00370 ]
# * Absolute error:       3.2338e-02
# * Relative error:       9.1939e-02
# --------------------------------------------------------------------------------
# [ Epoch 00380 ]
# * Absolute error:       3.1958e-02
# * Relative error:       9.1352e-02
# --------------------------------------------------------------------------------
# [ Epoch 00390 ]
# * Absolute error:       3.1604e-02
# * Relative error:       9.0837e-02
# --------------------------------------------------------------------------------
# [ Epoch 00400 ]
# * Absolute error:       3.1264e-02
# * Relative error:       9.0260e-02
# --------------------------------------------------------------------------------
# [ Epoch 00410 ]
# * Absolute error:       3.0915e-02
# * Relative error:       8.9737e-02
# --------------------------------------------------------------------------------
# [ Epoch 00420 ]
# * Absolute error:       3.0584e-02
# * Relative error:       8.9215e-02
# --------------------------------------------------------------------------------
# [ Epoch 00430 ]
# * Absolute error:       3.0267e-02
# * Relative error:       8.8778e-02
# --------------------------------------------------------------------------------
# [ Epoch 00440 ]
# * Absolute error:       2.9966e-02
# * Relative error:       8.8250e-02
# --------------------------------------------------------------------------------
# [ Epoch 00450 ]
# * Absolute error:       2.9679e-02
# * Relative error:       8.7876e-02
# --------------------------------------------------------------------------------
# [ Epoch 00460 ]
# * Absolute error:       2.9396e-02
# * Relative error:       8.7352e-02
# --------------------------------------------------------------------------------
# [ Epoch 00470 ]
# * Absolute error:       2.9103e-02
# * Relative error:       8.6909e-02
# --------------------------------------------------------------------------------
# [ Epoch 00480 ]
# * Absolute error:       2.8828e-02
# * Relative error:       8.6501e-02
# --------------------------------------------------------------------------------
# [ Epoch 00490 ]
# * Absolute error:       2.8580e-02
# * Relative error:       8.6089e-02
# --------------------------------------------------------------------------------
# [ Epoch 00500 ]
# * Absolute error:       2.8328e-02
# * Relative error:       8.5633e-02
# --------------------------------------------------------------------------------
# [ Epoch 00510 ]
# * Absolute error:       2.8079e-02
# * Relative error:       8.5244e-02
# --------------------------------------------------------------------------------
# [ Epoch 00520 ]
# * Absolute error:       2.7843e-02
# * Relative error:       8.4885e-02
# --------------------------------------------------------------------------------
# [ Epoch 00530 ]
# * Absolute error:       2.7602e-02
# * Relative error:       8.4444e-02
# --------------------------------------------------------------------------------
# [ Epoch 00540 ]
# * Absolute error:       2.7375e-02
# * Relative error:       8.4038e-02
# --------------------------------------------------------------------------------
# [ Epoch 00550 ]
# * Absolute error:       2.7163e-02
# * Relative error:       8.3730e-02
# --------------------------------------------------------------------------------
# [ Epoch 00560 ]
# * Absolute error:       2.6950e-02
# * Relative error:       8.3365e-02
# --------------------------------------------------------------------------------
# [ Epoch 00570 ]
# * Absolute error:       2.6751e-02
# * Relative error:       8.2950e-02
# --------------------------------------------------------------------------------
# [ Epoch 00580 ]
# * Absolute error:       2.6541e-02
# * Relative error:       8.2601e-02
# --------------------------------------------------------------------------------
# [ Epoch 00590 ]
# * Absolute error:       2.6347e-02
# * Relative error:       8.2253e-02
# --------------------------------------------------------------------------------
# [ Epoch 00600 ]
# * Absolute error:       2.6163e-02
# * Relative error:       8.1993e-02
# --------------------------------------------------------------------------------
# [ Epoch 00610 ]
# * Absolute error:       2.5978e-02
# * Relative error:       8.1643e-02
# --------------------------------------------------------------------------------
# [ Epoch 00620 ]
# * Absolute error:       2.5797e-02
# * Relative error:       8.1301e-02
# --------------------------------------------------------------------------------
# [ Epoch 00630 ]
# * Absolute error:       2.5618e-02
# * Relative error:       8.0957e-02
# --------------------------------------------------------------------------------
# [ Epoch 00640 ]
# * Absolute error:       2.5456e-02
# * Relative error:       8.0608e-02
# --------------------------------------------------------------------------------
# [ Epoch 00650 ]
# * Absolute error:       2.5282e-02
# * Relative error:       8.0337e-02
# --------------------------------------------------------------------------------
# [ Epoch 00660 ]
# * Absolute error:       2.5115e-02
# * Relative error:       7.9986e-02
# --------------------------------------------------------------------------------
# [ Epoch 00670 ]
# * Absolute error:       2.4958e-02
# * Relative error:       7.9738e-02
# --------------------------------------------------------------------------------
# [ Epoch 00680 ]
# * Absolute error:       2.4805e-02
# * Relative error:       7.9404e-02
# --------------------------------------------------------------------------------
# [ Epoch 00690 ]
# * Absolute error:       2.4645e-02
# * Relative error:       7.9086e-02
# --------------------------------------------------------------------------------
# [ Epoch 00700 ]
# * Absolute error:       2.4519e-02
# * Relative error:       7.8818e-02
# --------------------------------------------------------------------------------
# [ Epoch 00710 ]
# * Absolute error:       2.4365e-02
# * Relative error:       7.8531e-02
# --------------------------------------------------------------------------------
# [ Epoch 00720 ]
# * Absolute error:       2.4225e-02
# * Relative error:       7.8237e-02
# --------------------------------------------------------------------------------
# [ Epoch 00730 ]
# * Absolute error:       2.4088e-02
# * Relative error:       7.7966e-02
# --------------------------------------------------------------------------------
# [ Epoch 00740 ]
# * Absolute error:       2.3952e-02
# * Relative error:       7.7682e-02
# --------------------------------------------------------------------------------
# [ Epoch 00750 ]
# * Absolute error:       2.3828e-02
# * Relative error:       7.7433e-02
# --------------------------------------------------------------------------------
# [ Epoch 00760 ]
# * Absolute error:       2.3691e-02
# * Relative error:       7.7148e-02
# --------------------------------------------------------------------------------
# [ Epoch 00770 ]
# * Absolute error:       2.3572e-02
# * Relative error:       7.6881e-02
# --------------------------------------------------------------------------------
# [ Epoch 00780 ]
# * Absolute error:       2.3455e-02
# * Relative error:       7.6652e-02
# --------------------------------------------------------------------------------
# [ Epoch 00790 ]
# * Absolute error:       2.3322e-02
# * Relative error:       7.6363e-02
# --------------------------------------------------------------------------------
# [ Epoch 00800 ]
# * Absolute error:       2.3198e-02
# * Relative error:       7.6092e-02
# --------------------------------------------------------------------------------
# [ Epoch 00810 ]
# * Absolute error:       2.3090e-02
# * Relative error:       7.5843e-02
# --------------------------------------------------------------------------------
# [ Epoch 00820 ]
# * Absolute error:       2.2980e-02
# * Relative error:       7.5654e-02
# --------------------------------------------------------------------------------
# [ Epoch 00830 ]
# * Absolute error:       2.2862e-02
# * Relative error:       7.5379e-02
# --------------------------------------------------------------------------------
# [ Epoch 00840 ]
# * Absolute error:       2.2761e-02
# * Relative error:       7.5196e-02
# --------------------------------------------------------------------------------
# [ Epoch 00850 ]
# * Absolute error:       2.2649e-02
# * Relative error:       7.4903e-02
# --------------------------------------------------------------------------------
# [ Epoch 00860 ]
# * Absolute error:       2.2549e-02
# * Relative error:       7.4682e-02
# --------------------------------------------------------------------------------
# [ Epoch 00870 ]
# * Absolute error:       2.2454e-02
# * Relative error:       7.4449e-02
# --------------------------------------------------------------------------------
# [ Epoch 00880 ]
# * Absolute error:       2.2344e-02
# * Relative error:       7.4266e-02
# --------------------------------------------------------------------------------
# [ Epoch 00890 ]
# * Absolute error:       2.2242e-02
# * Relative error:       7.3955e-02
# --------------------------------------------------------------------------------
# [ Epoch 00900 ]
# * Absolute error:       2.2142e-02
# * Relative error:       7.3739e-02
# --------------------------------------------------------------------------------
# [ Epoch 00910 ]
# * Absolute error:       2.2048e-02
# * Relative error:       7.3526e-02
# --------------------------------------------------------------------------------
# [ Epoch 00920 ]
# * Absolute error:       2.1963e-02
# * Relative error:       7.3328e-02
# --------------------------------------------------------------------------------
# [ Epoch 00930 ]
# * Absolute error:       2.1857e-02
# * Relative error:       7.3113e-02
# --------------------------------------------------------------------------------
# [ Epoch 00940 ]
# * Absolute error:       2.1772e-02
# * Relative error:       7.2894e-02
# --------------------------------------------------------------------------------
# [ Epoch 00950 ]
# * Absolute error:       2.1671e-02
# * Relative error:       7.2696e-02
# --------------------------------------------------------------------------------
# [ Epoch 00960 ]
# * Absolute error:       2.1593e-02
# * Relative error:       7.2519e-02
# --------------------------------------------------------------------------------
# [ Epoch 00970 ]
# * Absolute error:       2.1532e-02
# * Relative error:       7.2542e-02
# --------------------------------------------------------------------------------
# [ Epoch 00980 ]
# * Absolute error:       2.1422e-02
# * Relative error:       7.2094e-02
# --------------------------------------------------------------------------------
# [ Epoch 00990 ]
# * Absolute error:       2.1327e-02
# * Relative error:       7.1880e-02
# --------------------------------------------------------------------------------
# [ Epoch 01000 ]
# * Absolute error:       2.1254e-02
# * Relative error:       7.1676e-02
# --------------------------------------------------------------------------------
# [ Epoch 01010 ]
# * Absolute error:       2.1170e-02
# * Relative error:       7.1533e-02
# --------------------------------------------------------------------------------
# [ Epoch 01020 ]
# * Absolute error:       2.1089e-02
# * Relative error:       7.1321e-02
# --------------------------------------------------------------------------------
# [ Epoch 01030 ]
# * Absolute error:       2.1012e-02
# * Relative error:       7.1115e-02
# --------------------------------------------------------------------------------
# [ Epoch 01040 ]
# * Absolute error:       2.0938e-02
# * Relative error:       7.0916e-02
# --------------------------------------------------------------------------------
# [ Epoch 01050 ]
# * Absolute error:       2.0867e-02
# * Relative error:       7.0709e-02
# --------------------------------------------------------------------------------
# [ Epoch 01060 ]
# * Absolute error:       2.0796e-02
# * Relative error:       7.0571e-02
# --------------------------------------------------------------------------------
# [ Epoch 01070 ]
# * Absolute error:       2.0725e-02
# * Relative error:       7.0401e-02
# --------------------------------------------------------------------------------
# [ Epoch 01080 ]
# * Absolute error:       2.0634e-02
# * Relative error:       7.0165e-02
# --------------------------------------------------------------------------------
# [ Epoch 01090 ]
# * Absolute error:       2.0573e-02
# * Relative error:       6.9983e-02
# --------------------------------------------------------------------------------
# [ Epoch 01100 ]
# * Absolute error:       2.0506e-02
# * Relative error:       6.9916e-02
# --------------------------------------------------------------------------------
# [ Epoch 01110 ]
# * Absolute error:       2.0427e-02
# * Relative error:       6.9651e-02
# --------------------------------------------------------------------------------
# [ Epoch 01120 ]
# * Absolute error:       2.0353e-02
# * Relative error:       6.9439e-02
# --------------------------------------------------------------------------------
# [ Epoch 01130 ]
# * Absolute error:       2.0300e-02
# * Relative error:       6.9343e-02
# --------------------------------------------------------------------------------
# [ Epoch 01140 ]
# * Absolute error:       2.0221e-02
# * Relative error:       6.9151e-02
# --------------------------------------------------------------------------------
# [ Epoch 01150 ]
# * Absolute error:       2.0159e-02
# * Relative error:       6.8891e-02
# --------------------------------------------------------------------------------
# [ Epoch 01160 ]
# * Absolute error:       2.0102e-02
# * Relative error:       6.8786e-02
# --------------------------------------------------------------------------------
# [ Epoch 01170 ]
# * Absolute error:       2.0034e-02
# * Relative error:       6.8601e-02
# --------------------------------------------------------------------------------
# [ Epoch 01180 ]
# * Absolute error:       1.9973e-02
# * Relative error:       6.8463e-02
# --------------------------------------------------------------------------------
# [ Epoch 01190 ]
# * Absolute error:       1.9922e-02
# * Relative error:       6.8386e-02
# --------------------------------------------------------------------------------
# [ Epoch 01200 ]
# * Absolute error:       1.9839e-02
# * Relative error:       6.8076e-02
# --------------------------------------------------------------------------------
# [ Epoch 01210 ]
# * Absolute error:       1.9783e-02
# * Relative error:       6.7970e-02
# --------------------------------------------------------------------------------
# [ Epoch 01220 ]
# * Absolute error:       1.9723e-02
# * Relative error:       6.7760e-02
# --------------------------------------------------------------------------------
# [ Epoch 01230 ]
# * Absolute error:       1.9675e-02
# * Relative error:       6.7697e-02
# --------------------------------------------------------------------------------
# [ Epoch 01240 ]
# * Absolute error:       1.9601e-02
# * Relative error:       6.7405e-02
# --------------------------------------------------------------------------------
# [ Epoch 01250 ]
# * Absolute error:       1.9557e-02
# * Relative error:       6.7343e-02
# --------------------------------------------------------------------------------
# [ Epoch 01260 ]
# * Absolute error:       1.9504e-02
# * Relative error:       6.7138e-02
# --------------------------------------------------------------------------------
# [ Epoch 01270 ]
# * Absolute error:       1.9444e-02
# * Relative error:       6.7021e-02
# --------------------------------------------------------------------------------
# [ Epoch 01280 ]
# * Absolute error:       1.9388e-02
# * Relative error:       6.6806e-02
# --------------------------------------------------------------------------------
# [ Epoch 01290 ]
# * Absolute error:       1.9331e-02
# * Relative error:       6.6689e-02
# --------------------------------------------------------------------------------
# [ Epoch 01300 ]
# * Absolute error:       1.9273e-02
# * Relative error:       6.6510e-02
# --------------------------------------------------------------------------------
# [ Epoch 01310 ]
# * Absolute error:       1.9220e-02
# * Relative error:       6.6372e-02
# --------------------------------------------------------------------------------
# [ Epoch 01320 ]
# * Absolute error:       1.9175e-02
# * Relative error:       6.6221e-02
# --------------------------------------------------------------------------------
# [ Epoch 01330 ]
# * Absolute error:       1.9134e-02
# * Relative error:       6.6156e-02
# --------------------------------------------------------------------------------
# [ Epoch 01340 ]
# * Absolute error:       1.9067e-02
# * Relative error:       6.5916e-02
# --------------------------------------------------------------------------------
# [ Epoch 01350 ]
# * Absolute error:       1.9015e-02
# * Relative error:       6.5772e-02
# --------------------------------------------------------------------------------
# [ Epoch 01360 ]
# * Absolute error:       1.8970e-02
# * Relative error:       6.5660e-02
# --------------------------------------------------------------------------------
# [ Epoch 01370 ]
# * Absolute error:       1.8927e-02
# * Relative error:       6.5466e-02
# --------------------------------------------------------------------------------
# [ Epoch 01380 ]
# * Absolute error:       1.8881e-02
# * Relative error:       6.5410e-02
# --------------------------------------------------------------------------------
# [ Epoch 01390 ]
# * Absolute error:       1.8826e-02
# * Relative error:       6.5190e-02
# --------------------------------------------------------------------------------
# [ Epoch 01400 ]
# * Absolute error:       1.8781e-02
# * Relative error:       6.5045e-02
# --------------------------------------------------------------------------------
# [ Epoch 01410 ]
# * Absolute error:       1.8737e-02
# * Relative error:       6.4939e-02
# --------------------------------------------------------------------------------
# [ Epoch 01420 ]
# * Absolute error:       1.8696e-02
# * Relative error:       6.4818e-02
# --------------------------------------------------------------------------------
# [ Epoch 01430 ]
# * Absolute error:       1.8650e-02
# * Relative error:       6.4666e-02
# --------------------------------------------------------------------------------
# [ Epoch 01440 ]
# * Absolute error:       1.8593e-02
# * Relative error:       6.4528e-02
# --------------------------------------------------------------------------------
# [ Epoch 01450 ]
# * Absolute error:       1.8549e-02
# * Relative error:       6.4384e-02
# --------------------------------------------------------------------------------
# [ Epoch 01460 ]
# * Absolute error:       1.8505e-02
# * Relative error:       6.4216e-02
# --------------------------------------------------------------------------------
# [ Epoch 01470 ]
# * Absolute error:       1.8471e-02
# * Relative error:       6.4148e-02
# --------------------------------------------------------------------------------
# [ Epoch 01480 ]
# * Absolute error:       1.8415e-02
# * Relative error:       6.3948e-02
# --------------------------------------------------------------------------------
# [ Epoch 01490 ]
# * Absolute error:       1.8381e-02
# * Relative error:       6.3841e-02
# --------------------------------------------------------------------------------
# [ Epoch 01500 ]
# * Absolute error:       1.8344e-02
# * Relative error:       6.3752e-02
# --------------------------------------------------------------------------------
# [ Epoch 01510 ]
# * Absolute error:       1.8304e-02
# * Relative error:       6.3630e-02
# --------------------------------------------------------------------------------
# [ Epoch 01520 ]
# * Absolute error:       1.8265e-02
# * Relative error:       6.3514e-02
# --------------------------------------------------------------------------------
# [ Epoch 01530 ]
# * Absolute error:       1.8222e-02
# * Relative error:       6.3333e-02
# --------------------------------------------------------------------------------
# [ Epoch 01540 ]
# * Absolute error:       1.8180e-02
# * Relative error:       6.3212e-02
# --------------------------------------------------------------------------------
# [ Epoch 01550 ]
# * Absolute error:       1.8134e-02
# * Relative error:       6.3038e-02
# --------------------------------------------------------------------------------
# [ Epoch 01560 ]
# * Absolute error:       1.8092e-02
# * Relative error:       6.2928e-02
# --------------------------------------------------------------------------------
# [ Epoch 01570 ]
# * Absolute error:       1.8066e-02
# * Relative error:       6.2830e-02
# --------------------------------------------------------------------------------
# [ Epoch 01580 ]
# * Absolute error:       1.8023e-02
# * Relative error:       6.2729e-02
# --------------------------------------------------------------------------------
# [ Epoch 01590 ]
# * Absolute error:       1.7991e-02
# * Relative error:       6.2625e-02
# --------------------------------------------------------------------------------
# [ Epoch 01600 ]
# * Absolute error:       1.7942e-02
# * Relative error:       6.2462e-02
# --------------------------------------------------------------------------------
# [ Epoch 01610 ]
# * Absolute error:       1.7908e-02
# * Relative error:       6.2362e-02
# --------------------------------------------------------------------------------
# [ Epoch 01620 ]
# * Absolute error:       1.7874e-02
# * Relative error:       6.2204e-02
# --------------------------------------------------------------------------------
# [ Epoch 01630 ]
# * Absolute error:       1.7838e-02
# * Relative error:       6.2083e-02
# --------------------------------------------------------------------------------
# [ Epoch 01640 ]
# * Absolute error:       1.7786e-02
# * Relative error:       6.1940e-02
# --------------------------------------------------------------------------------
# [ Epoch 01650 ]
# * Absolute error:       1.7764e-02
# * Relative error:       6.1875e-02
# --------------------------------------------------------------------------------
# [ Epoch 01660 ]
# * Absolute error:       1.7716e-02
# * Relative error:       6.1727e-02
# --------------------------------------------------------------------------------
# [ Epoch 01670 ]
# * Absolute error:       1.7685e-02
# * Relative error:       6.1648e-02
# --------------------------------------------------------------------------------
# [ Epoch 01680 ]
# * Absolute error:       1.7660e-02
# * Relative error:       6.1520e-02
# --------------------------------------------------------------------------------
# [ Epoch 01690 ]
# * Absolute error:       1.7628e-02
# * Relative error:       6.1458e-02
# --------------------------------------------------------------------------------
# [ Epoch 01700 ]
# * Absolute error:       1.7585e-02
# * Relative error:       6.1260e-02
# --------------------------------------------------------------------------------
# [ Epoch 01710 ]
# * Absolute error:       1.7545e-02
# * Relative error:       6.1159e-02
# --------------------------------------------------------------------------------
# [ Epoch 01720 ]
# * Absolute error:       1.7513e-02
# * Relative error:       6.1045e-02
# --------------------------------------------------------------------------------
# [ Epoch 01730 ]
# * Absolute error:       1.7480e-02
# * Relative error:       6.0954e-02
# --------------------------------------------------------------------------------
# [ Epoch 01740 ]
# * Absolute error:       1.7437e-02
# * Relative error:       6.0819e-02
# --------------------------------------------------------------------------------
# [ Epoch 01750 ]
# * Absolute error:       1.7413e-02
# * Relative error:       6.0727e-02
# --------------------------------------------------------------------------------
# [ Epoch 01760 ]
# * Absolute error:       1.7385e-02
# * Relative error:       6.0645e-02
# --------------------------------------------------------------------------------
# [ Epoch 01770 ]
# * Absolute error:       1.7348e-02
# * Relative error:       6.0492e-02
# --------------------------------------------------------------------------------
# [ Epoch 01780 ]
# * Absolute error:       1.7307e-02
# * Relative error:       6.0376e-02
# --------------------------------------------------------------------------------
# [ Epoch 01790 ]
# * Absolute error:       1.7291e-02
# * Relative error:       6.0286e-02
# --------------------------------------------------------------------------------
# [ Epoch 01800 ]
# * Absolute error:       1.7255e-02
# * Relative error:       6.0199e-02
# --------------------------------------------------------------------------------
# [ Epoch 01810 ]
# * Absolute error:       1.7221e-02
# * Relative error:       6.0090e-02
# --------------------------------------------------------------------------------
# [ Epoch 01820 ]
# * Absolute error:       1.7195e-02
# * Relative error:       5.9937e-02
# --------------------------------------------------------------------------------
# [ Epoch 01830 ]
# * Absolute error:       1.7164e-02
# * Relative error:       5.9867e-02
# --------------------------------------------------------------------------------
# [ Epoch 01840 ]
# * Absolute error:       1.7120e-02
# * Relative error:       5.9725e-02
# --------------------------------------------------------------------------------
# [ Epoch 01850 ]
# * Absolute error:       1.7100e-02
# * Relative error:       5.9643e-02
# --------------------------------------------------------------------------------
# [ Epoch 01860 ]
# * Absolute error:       1.7069e-02
# * Relative error:       5.9532e-02
# --------------------------------------------------------------------------------
# [ Epoch 01870 ]
# * Absolute error:       1.7038e-02
# * Relative error:       5.9422e-02
# --------------------------------------------------------------------------------
# [ Epoch 01880 ]
# * Absolute error:       1.7004e-02
# * Relative error:       5.9304e-02
# --------------------------------------------------------------------------------
# [ Epoch 01890 ]
# * Absolute error:       1.6980e-02
# * Relative error:       5.9196e-02
# --------------------------------------------------------------------------------
# [ Epoch 01900 ]
# * Absolute error:       1.6947e-02
# * Relative error:       5.9127e-02
# --------------------------------------------------------------------------------
# [ Epoch 01910 ]
# * Absolute error:       1.6919e-02
# * Relative error:       5.9003e-02
# --------------------------------------------------------------------------------
# [ Epoch 01920 ]
# * Absolute error:       1.6889e-02
# * Relative error:       5.8923e-02
# --------------------------------------------------------------------------------
# [ Epoch 01930 ]
# * Absolute error:       1.6870e-02
# * Relative error:       5.8821e-02
# --------------------------------------------------------------------------------
# [ Epoch 01940 ]
# * Absolute error:       1.6826e-02
# * Relative error:       5.8698e-02
# --------------------------------------------------------------------------------
# [ Epoch 01950 ]
# * Absolute error:       1.6798e-02
# * Relative error:       5.8590e-02
# --------------------------------------------------------------------------------
# [ Epoch 01960 ]
# * Absolute error:       1.6767e-02
# * Relative error:       5.8464e-02
# --------------------------------------------------------------------------------
# [ Epoch 01970 ]
# * Absolute error:       1.6757e-02
# * Relative error:       5.8427e-02
# --------------------------------------------------------------------------------
# [ Epoch 01980 ]
# * Absolute error:       1.6719e-02
# * Relative error:       5.8315e-02
# --------------------------------------------------------------------------------
# [ Epoch 01990 ]
# * Absolute error:       1.6695e-02
# * Relative error:       5.8187e-02
# --------------------------------------------------------------------------------
# [ Epoch 02000 ]
# * Absolute error:       1.6669e-02
# * Relative error:       5.8104e-02
# --------------------------------------------------------------------------------
# [ Epoch 02010 ]
# * Absolute error:       1.6638e-02
# * Relative error:       5.7992e-02
# --------------------------------------------------------------------------------
# [ Epoch 02020 ]
# * Absolute error:       1.6628e-02
# * Relative error:       5.8008e-02
# --------------------------------------------------------------------------------
# [ Epoch 02030 ]
# * Absolute error:       1.6594e-02
# * Relative error:       5.7915e-02
# --------------------------------------------------------------------------------
# [ Epoch 02040 ]
# * Absolute error:       1.6575e-02
# * Relative error:       5.7759e-02
# --------------------------------------------------------------------------------
# [ Epoch 02050 ]
# * Absolute error:       1.6544e-02
# * Relative error:       5.7649e-02
# --------------------------------------------------------------------------------
# [ Epoch 02060 ]
# * Absolute error:       1.6509e-02
# * Relative error:       5.7538e-02
# --------------------------------------------------------------------------------
# [ Epoch 02070 ]
# * Absolute error:       1.6491e-02
# * Relative error:       5.7514e-02
# --------------------------------------------------------------------------------
# [ Epoch 02080 ]
# * Absolute error:       1.6462e-02
# * Relative error:       5.7367e-02
# --------------------------------------------------------------------------------
# [ Epoch 02090 ]
# * Absolute error:       1.6443e-02
# * Relative error:       5.7267e-02
# --------------------------------------------------------------------------------
# [ Epoch 02100 ]
# * Absolute error:       1.6422e-02
# * Relative error:       5.7191e-02
# --------------------------------------------------------------------------------
# [ Epoch 02110 ]
# * Absolute error:       1.6392e-02
# * Relative error:       5.7093e-02
# --------------------------------------------------------------------------------
# [ Epoch 02120 ]
# * Absolute error:       1.6372e-02
# * Relative error:       5.7015e-02
# --------------------------------------------------------------------------------
# [ Epoch 02130 ]
# * Absolute error:       1.6346e-02
# * Relative error:       5.6904e-02
# --------------------------------------------------------------------------------
# [ Epoch 02140 ]
# * Absolute error:       1.6329e-02
# * Relative error:       5.6897e-02
# --------------------------------------------------------------------------------
# [ Epoch 02150 ]
# * Absolute error:       1.6304e-02
# * Relative error:       5.6786e-02
# --------------------------------------------------------------------------------
# [ Epoch 02160 ]
# * Absolute error:       1.6276e-02
# * Relative error:       5.6676e-02
# --------------------------------------------------------------------------------
# [ Epoch 02170 ]
# * Absolute error:       1.6255e-02
# * Relative error:       5.6562e-02
# --------------------------------------------------------------------------------
# [ Epoch 02180 ]
# * Absolute error:       1.6222e-02
# * Relative error:       5.6452e-02
# --------------------------------------------------------------------------------
# [ Epoch 02190 ]
# * Absolute error:       1.6207e-02
# * Relative error:       5.6428e-02
# --------------------------------------------------------------------------------
# [ Epoch 02200 ]
# * Absolute error:       1.6184e-02
# * Relative error:       5.6339e-02
# --------------------------------------------------------------------------------
# [ Epoch 02210 ]
# * Absolute error:       1.6172e-02
# * Relative error:       5.6302e-02
# --------------------------------------------------------------------------------
# [ Epoch 02220 ]
# * Absolute error:       1.6141e-02
# * Relative error:       5.6142e-02
# --------------------------------------------------------------------------------
# [ Epoch 02230 ]
# * Absolute error:       1.6126e-02
# * Relative error:       5.6102e-02
# --------------------------------------------------------------------------------
# [ Epoch 02240 ]
# * Absolute error:       1.6095e-02
# * Relative error:       5.5969e-02
# --------------------------------------------------------------------------------
# [ Epoch 02250 ]
# * Absolute error:       1.6072e-02
# * Relative error:       5.5913e-02
# --------------------------------------------------------------------------------
# [ Epoch 02260 ]
# * Absolute error:       1.6053e-02
# * Relative error:       5.5857e-02
# --------------------------------------------------------------------------------
# [ Epoch 02270 ]
# * Absolute error:       1.6030e-02
# * Relative error:       5.5799e-02
# --------------------------------------------------------------------------------
# [ Epoch 02280 ]
# * Absolute error:       1.6015e-02
# * Relative error:       5.5670e-02
# --------------------------------------------------------------------------------
# [ Epoch 02290 ]
# * Absolute error:       1.5982e-02
# * Relative error:       5.5557e-02
# --------------------------------------------------------------------------------
# [ Epoch 02300 ]
# * Absolute error:       1.5964e-02
# * Relative error:       5.5535e-02
# --------------------------------------------------------------------------------
# [ Epoch 02310 ]
# * Absolute error:       1.5956e-02
# * Relative error:       5.5437e-02
# --------------------------------------------------------------------------------
# [ Epoch 02320 ]
# * Absolute error:       1.5925e-02
# * Relative error:       5.5320e-02
# --------------------------------------------------------------------------------
# [ Epoch 02330 ]
# * Absolute error:       1.5896e-02
# * Relative error:       5.5250e-02
# --------------------------------------------------------------------------------
# [ Epoch 02340 ]
# * Absolute error:       1.5885e-02
# * Relative error:       5.5186e-02
# --------------------------------------------------------------------------------
# [ Epoch 02350 ]
# * Absolute error:       1.5859e-02
# * Relative error:       5.5076e-02
# --------------------------------------------------------------------------------
# [ Epoch 02360 ]
# * Absolute error:       1.5837e-02
# * Relative error:       5.4971e-02
# --------------------------------------------------------------------------------
# [ Epoch 02370 ]
# * Absolute error:       1.5825e-02
# * Relative error:       5.4943e-02
# --------------------------------------------------------------------------------
# [ Epoch 02380 ]
# * Absolute error:       1.5804e-02
# * Relative error:       5.4865e-02
# --------------------------------------------------------------------------------
# [ Epoch 02390 ]
# * Absolute error:       1.5778e-02
# * Relative error:       5.4774e-02
# --------------------------------------------------------------------------------
# [ Epoch 02400 ]
# * Absolute error:       1.5755e-02
# * Relative error:       5.4668e-02
# --------------------------------------------------------------------------------
# [ Epoch 02410 ]
# * Absolute error:       1.5731e-02
# * Relative error:       5.4609e-02
# --------------------------------------------------------------------------------
# [ Epoch 02420 ]
# * Absolute error:       1.5714e-02
# * Relative error:       5.4518e-02
# --------------------------------------------------------------------------------
# [ Epoch 02430 ]
# * Absolute error:       1.5696e-02
# * Relative error:       5.4454e-02
# --------------------------------------------------------------------------------
# [ Epoch 02440 ]
# * Absolute error:       1.5673e-02
# * Relative error:       5.4363e-02
# --------------------------------------------------------------------------------
# [ Epoch 02450 ]
# * Absolute error:       1.5659e-02
# * Relative error:       5.4310e-02
# --------------------------------------------------------------------------------
# [ Epoch 02460 ]
# * Absolute error:       1.5643e-02
# * Relative error:       5.4249e-02
# --------------------------------------------------------------------------------
# [ Epoch 02470 ]
# * Absolute error:       1.5626e-02
# * Relative error:       5.4232e-02
# --------------------------------------------------------------------------------
# [ Epoch 02480 ]
# * Absolute error:       1.5600e-02
# * Relative error:       5.4139e-02
# --------------------------------------------------------------------------------
# [ Epoch 02490 ]
# * Absolute error:       1.5581e-02
# * Relative error:       5.4004e-02
# --------------------------------------------------------------------------------
# [ Epoch 02500 ]
# * Absolute error:       1.5568e-02
# * Relative error:       5.3992e-02
# --------------------------------------------------------------------------------
# [ Epoch 02510 ]
# * Absolute error:       1.5551e-02
# * Relative error:       5.3880e-02
# --------------------------------------------------------------------------------
# [ Epoch 02520 ]
# * Absolute error:       1.5524e-02
# * Relative error:       5.3828e-02
# --------------------------------------------------------------------------------
# [ Epoch 02530 ]
# * Absolute error:       1.5495e-02
# * Relative error:       5.3755e-02
# --------------------------------------------------------------------------------
# [ Epoch 02540 ]
# * Absolute error:       1.5485e-02
# * Relative error:       5.3650e-02
# --------------------------------------------------------------------------------
# [ Epoch 02550 ]
# * Absolute error:       1.5471e-02
# * Relative error:       5.3560e-02
# --------------------------------------------------------------------------------
# [ Epoch 02560 ]
# * Absolute error:       1.5455e-02
# * Relative error:       5.3506e-02
# --------------------------------------------------------------------------------
# [ Epoch 02570 ]
# * Absolute error:       1.5425e-02
# * Relative error:       5.3412e-02
# --------------------------------------------------------------------------------
# [ Epoch 02580 ]
# * Absolute error:       1.5423e-02
# * Relative error:       5.3500e-02
# --------------------------------------------------------------------------------
# [ Epoch 02590 ]
# * Absolute error:       1.5391e-02
# * Relative error:       5.3296e-02
# --------------------------------------------------------------------------------
# [ Epoch 02600 ]
# * Absolute error:       1.5376e-02
# * Relative error:       5.3228e-02
# --------------------------------------------------------------------------------
# [ Epoch 02610 ]
# * Absolute error:       1.5352e-02
# * Relative error:       5.3149e-02
# --------------------------------------------------------------------------------
# [ Epoch 02620 ]
# * Absolute error:       1.5336e-02
# * Relative error:       5.3101e-02
# --------------------------------------------------------------------------------
# [ Epoch 02630 ]
# * Absolute error:       1.5318e-02
# * Relative error:       5.3022e-02
# --------------------------------------------------------------------------------
# [ Epoch 02640 ]
# * Absolute error:       1.5317e-02
# * Relative error:       5.3053e-02
# --------------------------------------------------------------------------------
# [ Epoch 02650 ]
# * Absolute error:       1.5297e-02
# * Relative error:       5.2932e-02
# --------------------------------------------------------------------------------
# [ Epoch 02660 ]
# * Absolute error:       1.5270e-02
# * Relative error:       5.2871e-02
# --------------------------------------------------------------------------------
# [ Epoch 02670 ]
# * Absolute error:       1.5261e-02
# * Relative error:       5.2814e-02
# --------------------------------------------------------------------------------
# [ Epoch 02680 ]
# * Absolute error:       1.5230e-02
# * Relative error:       5.2672e-02
# --------------------------------------------------------------------------------
# [ Epoch 02690 ]
# * Absolute error:       1.5228e-02
# * Relative error:       5.2679e-02
# --------------------------------------------------------------------------------
# [ Epoch 02700 ]
# * Absolute error:       1.5204e-02
# * Relative error:       5.2582e-02
# --------------------------------------------------------------------------------
# [ Epoch 02710 ]
# * Absolute error:       1.5184e-02
# * Relative error:       5.2488e-02
# --------------------------------------------------------------------------------
# [ Epoch 02720 ]
# * Absolute error:       1.5167e-02
# * Relative error:       5.2468e-02
# --------------------------------------------------------------------------------
# [ Epoch 02730 ]
# * Absolute error:       1.5151e-02
# * Relative error:       5.2372e-02
# --------------------------------------------------------------------------------
# [ Epoch 02740 ]
# * Absolute error:       1.5137e-02
# * Relative error:       5.2334e-02
# --------------------------------------------------------------------------------
# [ Epoch 02750 ]
# * Absolute error:       1.5120e-02
# * Relative error:       5.2251e-02
# --------------------------------------------------------------------------------
# [ Epoch 02760 ]
# * Absolute error:       1.5099e-02
# * Relative error:       5.2177e-02
# --------------------------------------------------------------------------------
# [ Epoch 02770 ]
# * Absolute error:       1.5085e-02
# * Relative error:       5.2153e-02
# --------------------------------------------------------------------------------
# [ Epoch 02780 ]
# * Absolute error:       1.5069e-02
# * Relative error:       5.2032e-02
# --------------------------------------------------------------------------------
# [ Epoch 02790 ]
# * Absolute error:       1.5051e-02
# * Relative error:       5.2007e-02
# --------------------------------------------------------------------------------
# [ Epoch 02800 ]
# * Absolute error:       1.5039e-02
# * Relative error:       5.1939e-02
# --------------------------------------------------------------------------------
# [ Epoch 02810 ]
# * Absolute error:       1.5021e-02
# * Relative error:       5.1873e-02
# --------------------------------------------------------------------------------
# [ Epoch 02820 ]
# * Absolute error:       1.5004e-02
# * Relative error:       5.1841e-02
# --------------------------------------------------------------------------------
# [ Epoch 02830 ]
# * Absolute error:       1.4989e-02
# * Relative error:       5.1759e-02
# --------------------------------------------------------------------------------
# [ Epoch 02840 ]
# * Absolute error:       1.4970e-02
# * Relative error:       5.1688e-02
# --------------------------------------------------------------------------------
# [ Epoch 02850 ]
# * Absolute error:       1.4961e-02
# * Relative error:       5.1721e-02
# --------------------------------------------------------------------------------
# [ Epoch 02860 ]
# * Absolute error:       1.4940e-02
# * Relative error:       5.1577e-02
# --------------------------------------------------------------------------------
# [ Epoch 02870 ]
# ...
# --------------------------------------------------------------------------------
# [ Epoch 09060 ]
# * Absolute error:       1.0860e-02
# * Relative error:       3.5863e-02
# --------------------------------------------------------------------------------
# [ Epoch 09070 ]
# * Absolute error:       1.0859e-02
# * Relative error:       3.5858e-02
# --------------------------------------------------------------------------------
# [ Epoch 09080 ]
# * Absolute error:       1.0858e-02
# * Relative error:       3.5829e-02
# --------------------------------------------------------------------------------
# [ Epoch 09090 ]
# * Absolute error:       1.0852e-02
# * Relative error:       3.5805e-02
# --------------------------------------------------------------------------------
# [ Epoch 09100 ]
# * Absolute error:       1.0849e-02
# * Relative error:       3.5834e-02
# --------------------------------------------------------------------------------
# [ Epoch 09110 ]
# * Absolute error:       1.0850e-02
# * Relative error:       3.5815e-02
# --------------------------------------------------------------------------------
# [ Epoch 09120 ]
# * Absolute error:       1.0846e-02
# * Relative error:       3.5795e-02
# --------------------------------------------------------------------------------
# [ Epoch 09130 ]
# * Absolute error:       1.0849e-02
# * Relative error:       3.5792e-02
# --------------------------------------------------------------------------------
# [ Epoch 09140 ]
# * Absolute error:       1.0843e-02
# * Relative error:       3.5777e-02
# --------------------------------------------------------------------------------
# [ Epoch 09150 ]
# * Absolute error:       1.0842e-02
# * Relative error:       3.5826e-02
# --------------------------------------------------------------------------------
# [ Epoch 09160 ]
# * Absolute error:       1.0840e-02
# * Relative error:       3.5762e-02
# --------------------------------------------------------------------------------
# [ Epoch 09170 ]
# * Absolute error:       1.0834e-02
# * Relative error:       3.5726e-02
# --------------------------------------------------------------------------------
# [ Epoch 09180 ]
# * Absolute error:       1.0829e-02
# * Relative error:       3.5722e-02
# --------------------------------------------------------------------------------
# [ Epoch 09190 ]
# * Absolute error:       1.0827e-02
# * Relative error:       3.5707e-02
# --------------------------------------------------------------------------------
# [ Epoch 09200 ]
# * Absolute error:       1.0829e-02
# * Relative error:       3.5718e-02
# --------------------------------------------------------------------------------
# [ Epoch 09210 ]
# * Absolute error:       1.0824e-02
# * Relative error:       3.5680e-02
# --------------------------------------------------------------------------------
# [ Epoch 09220 ]
# * Absolute error:       1.0823e-02
# * Relative error:       3.5693e-02
# --------------------------------------------------------------------------------
# [ Epoch 09230 ]
# * Absolute error:       1.0824e-02
# * Relative error:       3.5673e-02
# --------------------------------------------------------------------------------
# [ Epoch 09240 ]
# * Absolute error:       1.0820e-02
# * Relative error:       3.5665e-02
# --------------------------------------------------------------------------------
# [ Epoch 09250 ]
# * Absolute error:       1.0817e-02
# * Relative error:       3.5670e-02
# --------------------------------------------------------------------------------
# [ Epoch 09260 ]
# * Absolute error:       1.0819e-02
# * Relative error:       3.5680e-02
# --------------------------------------------------------------------------------
# [ Epoch 09270 ]
# * Absolute error:       1.0812e-02
# * Relative error:       3.5622e-02
# --------------------------------------------------------------------------------
# [ Epoch 09280 ]
# * Absolute error:       1.0814e-02
# * Relative error:       3.5615e-02
# --------------------------------------------------------------------------------
# [ Epoch 09290 ]
# * Absolute error:       1.0805e-02
# * Relative error:       3.5586e-02
# --------------------------------------------------------------------------------
# [ Epoch 09300 ]
# * Absolute error:       1.0805e-02
# * Relative error:       3.5579e-02
# --------------------------------------------------------------------------------
# [ Epoch 09310 ]
# * Absolute error:       1.0806e-02
# * Relative error:       3.5602e-02
# --------------------------------------------------------------------------------
# [ Epoch 09320 ]
# * Absolute error:       1.0800e-02
# * Relative error:       3.5610e-02
# --------------------------------------------------------------------------------
# [ Epoch 09330 ]
# * Absolute error:       1.0800e-02
# * Relative error:       3.5548e-02
# --------------------------------------------------------------------------------
# [ Epoch 09340 ]
# * Absolute error:       1.0796e-02
# * Relative error:       3.5533e-02
# --------------------------------------------------------------------------------
# [ Epoch 09350 ]
# * Absolute error:       1.0790e-02
# * Relative error:       3.5522e-02
# --------------------------------------------------------------------------------
# [ Epoch 09360 ]
# * Absolute error:       1.0793e-02
# * Relative error:       3.5565e-02
# --------------------------------------------------------------------------------
# [ Epoch 09370 ]
# * Absolute error:       1.0792e-02
# * Relative error:       3.5563e-02
# --------------------------------------------------------------------------------
# [ Epoch 09380 ]
# * Absolute error:       1.0788e-02
# * Relative error:       3.5526e-02
# --------------------------------------------------------------------------------
# [ Epoch 09390 ]
# * Absolute error:       1.0784e-02
# * Relative error:       3.5489e-02
# --------------------------------------------------------------------------------
# [ Epoch 09400 ]
# * Absolute error:       1.0780e-02
# * Relative error:       3.5482e-02
# --------------------------------------------------------------------------------
# [ Epoch 09410 ]
# * Absolute error:       1.0780e-02
# * Relative error:       3.5459e-02
# --------------------------------------------------------------------------------
# [ Epoch 09420 ]
# * Absolute error:       1.0777e-02
# * Relative error:       3.5471e-02
# --------------------------------------------------------------------------------
# [ Epoch 09430 ]
# * Absolute error:       1.0775e-02
# * Relative error:       3.5439e-02
# --------------------------------------------------------------------------------
# [ Epoch 09440 ]
# * Absolute error:       1.0770e-02
# * Relative error:       3.5441e-02
# --------------------------------------------------------------------------------
# [ Epoch 09450 ]
# * Absolute error:       1.0771e-02
# * Relative error:       3.5435e-02
# --------------------------------------------------------------------------------
# [ Epoch 09460 ]
# * Absolute error:       1.0767e-02
# * Relative error:       3.5419e-02
# --------------------------------------------------------------------------------
# [ Epoch 09470 ]
# * Absolute error:       1.0762e-02
# * Relative error:       3.5391e-02
# --------------------------------------------------------------------------------
# [ Epoch 09480 ]
# * Absolute error:       1.0760e-02
# * Relative error:       3.5369e-02
# --------------------------------------------------------------------------------
# [ Epoch 09490 ]
# * Absolute error:       1.0762e-02
# * Relative error:       3.5360e-02
# --------------------------------------------------------------------------------
# [ Epoch 09500 ]
# * Absolute error:       1.0762e-02
# * Relative error:       3.5398e-02
# --------------------------------------------------------------------------------
# [ Epoch 09510 ]
# * Absolute error:       1.0759e-02
# * Relative error:       3.5373e-02
# --------------------------------------------------------------------------------
# [ Epoch 09520 ]
# * Absolute error:       1.0755e-02
# * Relative error:       3.5347e-02
# --------------------------------------------------------------------------------
# [ Epoch 09530 ]
# * Absolute error:       1.0757e-02
# * Relative error:       3.5454e-02
# --------------------------------------------------------------------------------
# [ Epoch 09540 ]
# * Absolute error:       1.0750e-02
# * Relative error:       3.5318e-02
# --------------------------------------------------------------------------------
# [ Epoch 09550 ]
# * Absolute error:       1.0744e-02
# * Relative error:       3.5285e-02
# --------------------------------------------------------------------------------
# [ Epoch 09560 ]
# * Absolute error:       1.0743e-02
# * Relative error:       3.5276e-02
# --------------------------------------------------------------------------------
# [ Epoch 09570 ]
# * Absolute error:       1.0740e-02
# * Relative error:       3.5289e-02
# --------------------------------------------------------------------------------
# [ Epoch 09580 ]
# * Absolute error:       1.0736e-02
# * Relative error:       3.5258e-02
# --------------------------------------------------------------------------------
# [ Epoch 09590 ]
# * Absolute error:       1.0737e-02
# * Relative error:       3.5271e-02
# --------------------------------------------------------------------------------
# [ Epoch 09600 ]
# * Absolute error:       1.0742e-02
# * Relative error:       3.5281e-02
# --------------------------------------------------------------------------------
# [ Epoch 09610 ]
# * Absolute error:       1.0730e-02
# * Relative error:       3.5227e-02
# --------------------------------------------------------------------------------
# [ Epoch 09620 ]
# * Absolute error:       1.0734e-02
# * Relative error:       3.5239e-02
# --------------------------------------------------------------------------------
# [ Epoch 09630 ]
# * Absolute error:       1.0728e-02
# * Relative error:       3.5220e-02
# --------------------------------------------------------------------------------
# [ Epoch 09640 ]
# * Absolute error:       1.0724e-02
# * Relative error:       3.5201e-02
# --------------------------------------------------------------------------------
# [ Epoch 09650 ]
# * Absolute error:       1.0725e-02
# * Relative error:       3.5179e-02
# --------------------------------------------------------------------------------
# [ Epoch 09660 ]
# * Absolute error:       1.0724e-02
# * Relative error:       3.5180e-02
# --------------------------------------------------------------------------------
# [ Epoch 09670 ]
# * Absolute error:       1.0722e-02
# * Relative error:       3.5198e-02
# --------------------------------------------------------------------------------
# [ Epoch 09680 ]
# * Absolute error:       1.0717e-02
# * Relative error:       3.5169e-02
# --------------------------------------------------------------------------------
# [ Epoch 09690 ]
# * Absolute error:       1.0715e-02
# * Relative error:       3.5148e-02
# --------------------------------------------------------------------------------
# [ Epoch 09700 ]
# * Absolute error:       1.0717e-02
# * Relative error:       3.5182e-02
# --------------------------------------------------------------------------------
# [ Epoch 09710 ]
# * Absolute error:       1.0714e-02
# * Relative error:       3.5131e-02
# --------------------------------------------------------------------------------
# [ Epoch 09720 ]
# * Absolute error:       1.0714e-02
# * Relative error:       3.5142e-02
# --------------------------------------------------------------------------------
# [ Epoch 09730 ]
# * Absolute error:       1.0707e-02
# * Relative error:       3.5125e-02
# --------------------------------------------------------------------------------
# [ Epoch 09740 ]
# * Absolute error:       1.0705e-02
# * Relative error:       3.5116e-02
# --------------------------------------------------------------------------------
# [ Epoch 09750 ]
# * Absolute error:       1.0705e-02
# * Relative error:       3.5086e-02
# --------------------------------------------------------------------------------
# [ Epoch 09760 ]
# * Absolute error:       1.0699e-02
# * Relative error:       3.5063e-02
# --------------------------------------------------------------------------------
# [ Epoch 09770 ]
# * Absolute error:       1.0699e-02
# * Relative error:       3.5058e-02
# --------------------------------------------------------------------------------
# [ Epoch 09780 ]
# * Absolute error:       1.0700e-02
# * Relative error:       3.5087e-02
# --------------------------------------------------------------------------------
# [ Epoch 09790 ]
# * Absolute error:       1.0694e-02
# * Relative error:       3.5041e-02
# --------------------------------------------------------------------------------
# [ Epoch 09800 ]
# * Absolute error:       1.0691e-02
# * Relative error:       3.5044e-02
# --------------------------------------------------------------------------------
# [ Epoch 09810 ]
# * Absolute error:       1.0690e-02
# * Relative error:       3.5026e-02
# --------------------------------------------------------------------------------
# [ Epoch 09820 ]
# * Absolute error:       1.0687e-02
# * Relative error:       3.5010e-02
# --------------------------------------------------------------------------------
# [ Epoch 09830 ]
# * Absolute error:       1.0683e-02
# * Relative error:       3.5006e-02
# --------------------------------------------------------------------------------
# [ Epoch 09840 ]
# * Absolute error:       1.0678e-02
# * Relative error:       3.4980e-02
# --------------------------------------------------------------------------------
# [ Epoch 09850 ]
# * Absolute error:       1.0683e-02
# * Relative error:       3.4980e-02
# --------------------------------------------------------------------------------
# [ Epoch 09860 ]
# * Absolute error:       1.0684e-02
# * Relative error:       3.5008e-02
# --------------------------------------------------------------------------------
# [ Epoch 09870 ]
# * Absolute error:       1.0675e-02
# * Relative error:       3.4945e-02
# --------------------------------------------------------------------------------
# [ Epoch 09880 ]
# * Absolute error:       1.0679e-02
# * Relative error:       3.4963e-02
# --------------------------------------------------------------------------------
# [ Epoch 09890 ]
# * Absolute error:       1.0675e-02
# * Relative error:       3.4965e-02
# --------------------------------------------------------------------------------
# [ Epoch 09900 ]
# * Absolute error:       1.0672e-02
# * Relative error:       3.4939e-02
# --------------------------------------------------------------------------------
# [ Epoch 09910 ]
# * Absolute error:       1.0670e-02
# * Relative error:       3.4937e-02
# --------------------------------------------------------------------------------
# [ Epoch 09920 ]
# * Absolute error:       1.0666e-02
# * Relative error:       3.4886e-02
# --------------------------------------------------------------------------------
# [ Epoch 09930 ]
# * Absolute error:       1.0662e-02
# * Relative error:       3.4908e-02
# --------------------------------------------------------------------------------
# [ Epoch 09940 ]
# * Absolute error:       1.0668e-02
# * Relative error:       3.4925e-02
# --------------------------------------------------------------------------------
# [ Epoch 09950 ]
# * Absolute error:       1.0666e-02
# * Relative error:       3.4896e-02
# --------------------------------------------------------------------------------
# [ Epoch 09960 ]
# * Absolute error:       1.0657e-02
# * Relative error:       3.4836e-02
# --------------------------------------------------------------------------------
# [ Epoch 09970 ]
# * Absolute error:       1.0657e-02
# * Relative error:       3.4869e-02
# --------------------------------------------------------------------------------
# [ Epoch 09980 ]
# * Absolute error:       1.0656e-02
# * Relative error:       3.4864e-02
# --------------------------------------------------------------------------------
# [ Epoch 09990 ]
# * Absolute error:       1.0649e-02
# * Relative error:       3.4819e-02
# --------------------------------------------------------------------------------
# [ Epoch 10000 ]
# * Absolute error:       1.0654e-02
# * Relative error:       3.4842e-02
# --------------------------------------------------------------------------------
# FourierLandauLayer()

# %%
idx = torch.randint(0, len(data), (1,)).item()
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
d1 = pred_collision[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
d2 = target_collision[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
d3 = (pred_collision-target_collision)[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
fig.colorbar(axes[0].imshow(d1))
fig.colorbar(axes[1].imshow(d2))
fig.colorbar(axes[2].imshow(np.abs(d3)))
plt.show()

# %%
torch.save(
    obj = specnet.cpu().state_dict(),
    f   = path_data / f"Landau__alpha_{int(VHS_ALPHA)}__res_{RESOLUTION}__specnet__deg_8.pth"
)

# %% [markdown]
# End of file

# %%
from    typing              import  *
from    typing_extensions   import  Self

from    tqdm.notebook       import  tqdm

import  numpy               as  np
import  matplotlib.pyplot   as  plt

import  torch
from    torch.utils.data    import  Dataset, DataLoader


from    pathlib             import  Path
root_dir    = r"/media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE"
path_root   = Path(root_dir)
path_lib    = path_root / "python_deep_numerical"
path_data   = path_root / "datasets"

import  sys
sys.path.append( str(path_lib) )
from    pytorch.layers                  import  FourierLandauLayer
from    pytorch.torch_numerical         import  utils
from    pytorch.utils                   import  initialize_weights


dtype  = torch.float32
dtype_complex = utils.dtype_real_to_complex(dtype)
device = torch.device('cuda:1')
__dtype_str = str(dtype).split(".")[-1]
dtype_and_device = {'dtype': dtype, 'device': device}
print(f"Device for computation\n>>> {device}")
# Out:
# Device for computation
# >>> cuda:1

# %%
DIMENSION:  int     = 2
RESOLUTION: int     = 64
VHS_ALPHA:  float   = 0.0

_file = path_data / f"{__dtype_str}/Landau__alpha_{int(VHS_ALPHA)}__res_{RESOLUTION}.npz"
print(f"Loading data from\n>>> {_file}")
file = np.load(_file)

V_MAX:      float   = float(file['v_max'])
DELTA_V:    float   = (2*V_MAX) / RESOLUTION
FFT_NORM:   str     = 'forward'

VHS_COEFF:  float   = file['vhs_coeff']
# Out:
# Loading data from
# >>> /media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE/datasets/float32/Landau__alpha_0__res_64.npz

# %%
class CustomDataset(Dataset):
    def __init__(
            self,
            distr:      torch.Tensor,
            gain_fft:   torch.Tensor,
            loss_fft:   torch.Tensor,
            vhs_alpha:  Optional[torch.Tensor]  = None,
            dim:        Optional[int]           = None,
            squeeze_space: bool = False,
        ) -> Self:
        self.dim:       int                         = dim
        self.distr:     torch.Tensor                = distr
        self.gain_fft:  torch.Tensor                = gain_fft
        self.loss_fft:  torch.Tensor                = loss_fft
        self.vhs_alpha: Optional[torch.Tensor]      = vhs_alpha
        self.__fft_dim: tuple[int] = tuple(range(1+dim, 1+2*dim))
        
        if squeeze_space:
            self.distr      = self.distr.reshape(distr.size(0), *distr.shape[-1-dim:])
            self.gain_fft   = self.gain_fft.reshape(gain_fft.size(0), *gain_fft.shape[-1-dim:])
            self.loss_fft   = self.loss_fft.reshape(loss_fft.size(0), *loss_fft.shape[-1-dim:])
            self.__fft_dim  = tuple(range(1, 1+dim))
            
        return
    
    
    def __getitem__(self, index: int) -> tuple[torch.Tensor]:
        if self.vhs_alpha:
            return self.distr[index], self.gain_fft[index], self.loss_fft[index], self.vhs_alpha[index]
        else:
            return self.distr[index], self.gain_fft[index], self.loss_fft[index]
    
    def __len__(self) -> int:
        return self.distr.size(0)
    
    
    @property
    def fft_dim(self) -> tuple[int]:
        return self.__fft_dim

# %%
dataset  = CustomDataset(
    torch.tensor(file['data'], dtype=dtype),
    torch.tensor(file['gain_fft'], dtype=dtype_complex),
    torch.tensor(file['loss_fft'], dtype=dtype_complex),
    dim=DIMENSION,
    squeeze_space=False,
)
dataloader  = DataLoader(dataset, batch_size=256, shuffle=True)
FFT_DIM = dataset.fft_dim

# %%
specnet     = FourierLandauLayer(DIMENSION, 10).to(device)
initialize_weights(specnet, 'xavier uniform')
optimizer   = torch.optim.Adam(specnet.parameters(), lr=1e-2)
# lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.9)

print(specnet)
# Out:
# ==============================< FourierLandauLayer >==============================
# [ Subnetworks ]
#
# ----------------------------------------------------------------------------------
# [ Parameters ]
# ( params_id )
# - Shape:       [20, 20, 1]
# - Data type:   torch.complex64
# ( params_proj )
# - Shape:       [20, 20, 1, 2, 2]
# - Data type:   torch.complex64
# ----------------------------------------------------------------------------------
# Number of parameters: 4000
# ==================================================================================

# %%
NUM_EPOCHS: int = 10000
dv = DELTA_V**DIMENSION
specnet.train()

data:       torch.Tensor
gain_fft:   torch.Tensor
loss_fft:   torch.Tensor

for epoch in tqdm(range(1, 1+NUM_EPOCHS)):
    abs_error:          float = 0.0
    rel_error:          float = 0.0
    rel_error_gain:     float = 0.0
    rel_error_loss:     float = 0.0
    
    for data, gain_fft, loss_fft in dataloader:
        data        = data.to(device)
        data_fft:   torch.Tensor = torch.fft.fftn(data, dim=FFT_DIM, norm=FFT_NORM)
        gain_fft    = gain_fft.to(device)
        loss_fft    = loss_fft.to(device)
        target_gain:      torch.Tensor = torch.fft.ifftn(gain_fft, dim=FFT_DIM, norm=FFT_NORM).real
        target_loss:      torch.Tensor = torch.fft.ifftn(loss_fft, dim=FFT_DIM, norm=FFT_NORM).real
        target_collision = target_gain-target_loss

        # pred_gain_fft = sm_object.compute_gain_fft(None, data_fft)
        # pred_loss_fft = sm_object.compute_loss_fft(None, data_fft)
        pred_gain_fft   = specnet.compute_gain_fft(data_fft)
        pred_loss_fft   = specnet.compute_loss_fft(data_fft)
        pred_fft        = pred_gain_fft-pred_loss_fft
        pred_gain:      torch.Tensor = torch.fft.ifftn(pred_gain_fft, dim=FFT_DIM, norm=FFT_NORM).real
        pred_loss:      torch.Tensor = torch.fft.ifftn(pred_loss_fft, dim=FFT_DIM, norm=FFT_NORM).real
        pred_collision = pred_gain-pred_loss

        _data_size = len(data)
        _abs_error = utils.absolute_error(pred_collision, target_collision).mean()
        _rel_error = utils.relative_error(pred_collision, target_collision).mean()
        _rel_error_gain = utils.relative_error(pred_gain, target_gain).mean()
        _rel_error_loss = utils.relative_error(pred_loss, target_loss).mean()
        abs_error += _abs_error.item() * _data_size
        rel_error += _rel_error.item() * _data_size
        rel_error_gain += _rel_error_gain.item() * _data_size
        rel_error_loss += _rel_error_loss.item() * _data_size
        
        train_loss = _rel_error
        
        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()
        
    __abs_scale = dv/len(dataset)
    __rel_scale = 1.0/len(dataset)
    abs_error       *= __abs_scale
    rel_error       *= __rel_scale
    if epoch%10==0 or epoch==1:
        
        print(
            ' '.join(
                (
                    f"[ Epoch {str(epoch).zfill(len(str(NUM_EPOCHS)))} ]",
                    # f"lr={lr_scheduler.get_last_lr()[0]:.4e}",
                )
            )
        )
        print(f"* Absolute error:           {abs_error:.4e}")
        print(f"* Relative error:           {rel_error:.4e}")
        print(f"* Relative error (gain):    {rel_error_gain:.4e}")
        print(f"* Relative error (loss):    {rel_error_loss:.4e}")
        print('-'*80)
    if rel_error < 1e-3:
        print(f"Achieved relative error {_rel_error:.4e} at epoch {epoch}.")
        break
    # lr_scheduler.step()

specnet.eval()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# [ Epoch 00001 ]
# * Absolute error:           2.0165e-01
# * Relative error:           9.0935e-01
# * Relative error (gain):    2.9440e+03
# * Relative error (loss):    2.8986e+03
# --------------------------------------------------------------------------------
# [ Epoch 00010 ]
# * Absolute error:           1.0785e-01
# * Relative error:           3.2867e-01
# * Relative error (gain):    2.8712e+03
# * Relative error (loss):    2.4085e+03
# --------------------------------------------------------------------------------
# [ Epoch 00020 ]
# * Absolute error:           4.6080e-02
# * Relative error:           1.6918e-01
# * Relative error (gain):    2.8815e+03
# * Relative error (loss):    2.2347e+03
# --------------------------------------------------------------------------------
# [ Epoch 00030 ]
# * Absolute error:           3.6336e-02
# * Relative error:           1.2948e-01
# * Relative error (gain):    2.9311e+03
# * Relative error (loss):    2.2765e+03
# --------------------------------------------------------------------------------
# [ Epoch 00040 ]
# * Absolute error:           3.5416e-02
# * Relative error:           1.1912e-01
# * Relative error (gain):    2.9938e+03
# * Relative error (loss):    2.3247e+03
# --------------------------------------------------------------------------------
# [ Epoch 00050 ]
# * Absolute error:           3.5192e-02
# * Relative error:           1.1468e-01
# * Relative error (gain):    3.0456e+03
# * Relative error (loss):    2.3529e+03
# --------------------------------------------------------------------------------
# [ Epoch 00060 ]
# * Absolute error:           3.4737e-02
# * Relative error:           1.1164e-01
# * Relative error (gain):    3.0866e+03
# * Relative error (loss):    2.3714e+03
# --------------------------------------------------------------------------------
# [ Epoch 00070 ]
# * Absolute error:           3.4046e-02
# * Relative error:           1.0884e-01
# * Relative error (gain):    3.1213e+03
# * Relative error (loss):    2.3840e+03
# --------------------------------------------------------------------------------
# [ Epoch 00080 ]
# * Absolute error:           3.3232e-02
# * Relative error:           1.0618e-01
# * Relative error (gain):    3.1532e+03
# * Relative error (loss):    2.3946e+03
# --------------------------------------------------------------------------------
# [ Epoch 00090 ]
# * Absolute error:           3.2370e-02
# * Relative error:           1.0369e-01
# * Relative error (gain):    3.1845e+03
# * Relative error (loss):    2.4043e+03
# --------------------------------------------------------------------------------
# [ Epoch 00100 ]
# * Absolute error:           3.1450e-02
# * Relative error:           1.0137e-01
# * Relative error (gain):    3.2148e+03
# * Relative error (loss):    2.4129e+03
# --------------------------------------------------------------------------------
# [ Epoch 00110 ]
# * Absolute error:           3.0472e-02
# * Relative error:           9.9186e-02
# * Relative error (gain):    3.2438e+03
# * Relative error (loss):    2.4201e+03
# --------------------------------------------------------------------------------
# [ Epoch 00120 ]
# * Absolute error:           2.9494e-02
# * Relative error:           9.7219e-02
# * Relative error (gain):    3.2736e+03
# * Relative error (loss):    2.4290e+03
# --------------------------------------------------------------------------------
# [ Epoch 00130 ]
# * Absolute error:           2.8508e-02
# * Relative error:           9.5258e-02
# * Relative error (gain):    3.3029e+03
# * Relative error (loss):    2.4365e+03
# --------------------------------------------------------------------------------
# [ Epoch 00140 ]
# * Absolute error:           2.7537e-02
# * Relative error:           9.3588e-02
# * Relative error (gain):    3.3335e+03
# * Relative error (loss):    2.4453e+03
# --------------------------------------------------------------------------------
# [ Epoch 00150 ]
# * Absolute error:           2.6601e-02
# * Relative error:           9.2071e-02
# * Relative error (gain):    3.3654e+03
# * Relative error (loss):    2.4545e+03
# --------------------------------------------------------------------------------
# [ Epoch 00160 ]
# * Absolute error:           2.5686e-02
# * Relative error:           9.0632e-02
# * Relative error (gain):    3.3980e+03
# * Relative error (loss):    2.4647e+03
# --------------------------------------------------------------------------------
# [ Epoch 00170 ]
# * Absolute error:           2.4838e-02
# * Relative error:           8.9307e-02
# * Relative error (gain):    3.4317e+03
# * Relative error (loss):    2.4757e+03
# --------------------------------------------------------------------------------
# [ Epoch 00180 ]
# * Absolute error:           2.4059e-02
# * Relative error:           8.8084e-02
# * Relative error (gain):    3.4661e+03
# * Relative error (loss):    2.4873e+03
# --------------------------------------------------------------------------------
# [ Epoch 00190 ]
# * Absolute error:           2.3310e-02
# * Relative error:           8.6976e-02
# * Relative error (gain):    3.5015e+03
# * Relative error (loss):    2.4993e+03
# --------------------------------------------------------------------------------
# [ Epoch 00200 ]
# * Absolute error:           2.2599e-02
# * Relative error:           8.5953e-02
# * Relative error (gain):    3.5377e+03
# * Relative error (loss):    2.5125e+03
# --------------------------------------------------------------------------------
# [ Epoch 00210 ]
# * Absolute error:           2.1968e-02
# * Relative error:           8.4966e-02
# * Relative error (gain):    3.5737e+03
# * Relative error (loss):    2.5251e+03
# --------------------------------------------------------------------------------
# [ Epoch 00220 ]
# * Absolute error:           2.1366e-02
# * Relative error:           8.4116e-02
# * Relative error (gain):    3.6098e+03
# * Relative error (loss):    2.5382e+03
# --------------------------------------------------------------------------------
# [ Epoch 00230 ]
# * Absolute error:           2.0814e-02
# * Relative error:           8.3302e-02
# * Relative error (gain):    3.6461e+03
# * Relative error (loss):    2.5512e+03
# --------------------------------------------------------------------------------
# [ Epoch 00240 ]
# * Absolute error:           2.0275e-02
# * Relative error:           8.2372e-02
# * Relative error (gain):    3.6822e+03
# * Relative error (loss):    2.5641e+03
# --------------------------------------------------------------------------------
# [ Epoch 00250 ]
# * Absolute error:           1.9785e-02
# * Relative error:           8.1645e-02
# * Relative error (gain):    3.7183e+03
# * Relative error (loss):    2.5769e+03
# --------------------------------------------------------------------------------
# [ Epoch 00260 ]
# * Absolute error:           1.9313e-02
# * Relative error:           8.0940e-02
# * Relative error (gain):    3.7547e+03
# * Relative error (loss):    2.5899e+03
# --------------------------------------------------------------------------------
# [ Epoch 00270 ]
# * Absolute error:           1.8866e-02
# * Relative error:           8.0173e-02
# * Relative error (gain):    3.7901e+03
# * Relative error (loss):    2.6025e+03
# --------------------------------------------------------------------------------
# [ Epoch 00280 ]
# * Absolute error:           1.8447e-02
# * Relative error:           7.9494e-02
# * Relative error (gain):    3.8255e+03
# * Relative error (loss):    2.6147e+03
# --------------------------------------------------------------------------------
# [ Epoch 00290 ]
# * Absolute error:           1.8036e-02
# * Relative error:           7.8896e-02
# * Relative error (gain):    3.8606e+03
# * Relative error (loss):    2.6266e+03
# --------------------------------------------------------------------------------
# [ Epoch 00300 ]
# * Absolute error:           1.7638e-02
# * Relative error:           7.8261e-02
# * Relative error (gain):    3.8956e+03
# * Relative error (loss):    2.6385e+03
# --------------------------------------------------------------------------------
# [ Epoch 00310 ]
# * Absolute error:           1.7282e-02
# * Relative error:           7.7651e-02
# * Relative error (gain):    3.9307e+03
# * Relative error (loss):    2.6503e+03
# --------------------------------------------------------------------------------
# [ Epoch 00320 ]
# * Absolute error:           1.6925e-02
# * Relative error:           7.7071e-02
# * Relative error (gain):    3.9657e+03
# * Relative error (loss):    2.6620e+03
# --------------------------------------------------------------------------------
# [ Epoch 00330 ]
# * Absolute error:           1.6569e-02
# * Relative error:           7.6463e-02
# * Relative error (gain):    4.0003e+03
# * Relative error (loss):    2.6735e+03
# --------------------------------------------------------------------------------
# [ Epoch 00340 ]
# * Absolute error:           1.6230e-02
# * Relative error:           7.5922e-02
# * Relative error (gain):    4.0349e+03
# * Relative error (loss):    2.6848e+03
# --------------------------------------------------------------------------------
# [ Epoch 00350 ]
# * Absolute error:           1.5914e-02
# * Relative error:           7.5344e-02
# * Relative error (gain):    4.0694e+03
# * Relative error (loss):    2.6960e+03
# --------------------------------------------------------------------------------
# [ Epoch 00360 ]
# * Absolute error:           1.5606e-02
# * Relative error:           7.4827e-02
# * Relative error (gain):    4.1038e+03
# * Relative error (loss):    2.7072e+03
# --------------------------------------------------------------------------------
# [ Epoch 00370 ]
# * Absolute error:           1.5311e-02
# * Relative error:           7.4360e-02
# * Relative error (gain):    4.1380e+03
# * Relative error (loss):    2.7182e+03
# --------------------------------------------------------------------------------
# [ Epoch 00380 ]
# * Absolute error:           1.5015e-02
# * Relative error:           7.3817e-02
# * Relative error (gain):    4.1705e+03
# * Relative error (loss):    2.7283e+03
# --------------------------------------------------------------------------------
# [ Epoch 00390 ]
# * Absolute error:           1.4742e-02
# * Relative error:           7.3308e-02
# * Relative error (gain):    4.2031e+03
# * Relative error (loss):    2.7382e+03
# --------------------------------------------------------------------------------
# [ Epoch 00400 ]
# * Absolute error:           1.4466e-02
# * Relative error:           7.2813e-02
# * Relative error (gain):    4.2346e+03
# * Relative error (loss):    2.7478e+03
# --------------------------------------------------------------------------------
# [ Epoch 00410 ]
# * Absolute error:           1.4212e-02
# * Relative error:           7.2386e-02
# * Relative error (gain):    4.2664e+03
# * Relative error (loss):    2.7575e+03
# --------------------------------------------------------------------------------
# [ Epoch 00420 ]
# * Absolute error:           1.3970e-02
# * Relative error:           7.1993e-02
# * Relative error (gain):    4.2979e+03
# * Relative error (loss):    2.7670e+03
# --------------------------------------------------------------------------------
# [ Epoch 00430 ]
# * Absolute error:           1.3732e-02
# * Relative error:           7.1538e-02
# * Relative error (gain):    4.3292e+03
# * Relative error (loss):    2.7763e+03
# --------------------------------------------------------------------------------
# [ Epoch 00440 ]
# * Absolute error:           1.3475e-02
# * Relative error:           7.1009e-02
# * Relative error (gain):    4.3608e+03
# * Relative error (loss):    2.7857e+03
# --------------------------------------------------------------------------------
# [ Epoch 00450 ]
# * Absolute error:           1.3250e-02
# * Relative error:           7.0568e-02
# * Relative error (gain):    4.3920e+03
# * Relative error (loss):    2.7953e+03
# --------------------------------------------------------------------------------
# [ Epoch 00460 ]
# * Absolute error:           1.3034e-02
# * Relative error:           7.0184e-02
# * Relative error (gain):    4.4242e+03
# * Relative error (loss):    2.8054e+03
# --------------------------------------------------------------------------------
# [ Epoch 00470 ]
# * Absolute error:           1.2826e-02
# * Relative error:           6.9792e-02
# * Relative error (gain):    4.4554e+03
# * Relative error (loss):    2.8148e+03
# --------------------------------------------------------------------------------
# [ Epoch 00480 ]
# * Absolute error:           1.2613e-02
# * Relative error:           6.9331e-02
# * Relative error (gain):    4.4871e+03
# * Relative error (loss):    2.8247e+03
# --------------------------------------------------------------------------------
# [ Epoch 00490 ]
# * Absolute error:           1.2412e-02
# * Relative error:           6.8920e-02
# * Relative error (gain):    4.5183e+03
# * Relative error (loss):    2.8343e+03
# --------------------------------------------------------------------------------
# [ Epoch 00500 ]
# * Absolute error:           1.2221e-02
# * Relative error:           6.8502e-02
# * Relative error (gain):    4.5492e+03
# * Relative error (loss):    2.8436e+03
# --------------------------------------------------------------------------------
# [ Epoch 00510 ]
# * Absolute error:           1.2036e-02
# * Relative error:           6.8145e-02
# * Relative error (gain):    4.5794e+03
# * Relative error (loss):    2.8527e+03
# --------------------------------------------------------------------------------
# [ Epoch 00520 ]
# * Absolute error:           1.1852e-02
# * Relative error:           6.7749e-02
# * Relative error (gain):    4.6086e+03
# * Relative error (loss):    2.8613e+03
# --------------------------------------------------------------------------------
# [ Epoch 00530 ]
# * Absolute error:           1.1683e-02
# * Relative error:           6.7390e-02
# * Relative error (gain):    4.6382e+03
# * Relative error (loss):    2.8703e+03
# --------------------------------------------------------------------------------
# [ Epoch 00540 ]
# * Absolute error:           1.1507e-02
# * Relative error:           6.7018e-02
# * Relative error (gain):    4.6673e+03
# * Relative error (loss):    2.8791e+03
# --------------------------------------------------------------------------------
# [ Epoch 00550 ]
# * Absolute error:           1.1342e-02
# * Relative error:           6.6625e-02
# * Relative error (gain):    4.6952e+03
# * Relative error (loss):    2.8874e+03
# --------------------------------------------------------------------------------
# [ Epoch 00560 ]
# * Absolute error:           1.1203e-02
# * Relative error:           6.6367e-02
# * Relative error (gain):    4.7229e+03
# * Relative error (loss):    2.8957e+03
# --------------------------------------------------------------------------------
# [ Epoch 00570 ]
# * Absolute error:           1.1036e-02
# * Relative error:           6.5969e-02
# * Relative error (gain):    4.7506e+03
# * Relative error (loss):    2.9039e+03
# --------------------------------------------------------------------------------
# [ Epoch 00580 ]
# * Absolute error:           1.0894e-02
# * Relative error:           6.5726e-02
# * Relative error (gain):    4.7783e+03
# * Relative error (loss):    2.9123e+03
# --------------------------------------------------------------------------------
# [ Epoch 00590 ]
# * Absolute error:           1.0737e-02
# * Relative error:           6.5320e-02
# * Relative error (gain):    4.8047e+03
# * Relative error (loss):    2.9202e+03
# --------------------------------------------------------------------------------
# [ Epoch 00600 ]
# * Absolute error:           1.0597e-02
# * Relative error:           6.4985e-02
# * Relative error (gain):    4.8314e+03
# * Relative error (loss):    2.9280e+03
# --------------------------------------------------------------------------------
# [ Epoch 00610 ]
# * Absolute error:           1.0469e-02
# * Relative error:           6.4697e-02
# * Relative error (gain):    4.8581e+03
# * Relative error (loss):    2.9359e+03
# --------------------------------------------------------------------------------
# [ Epoch 00620 ]
# * Absolute error:           1.0331e-02
# * Relative error:           6.4406e-02
# * Relative error (gain):    4.8847e+03
# * Relative error (loss):    2.9441e+03
# --------------------------------------------------------------------------------
# [ Epoch 00630 ]
# * Absolute error:           1.0201e-02
# * Relative error:           6.4062e-02
# * Relative error (gain):    4.9107e+03
# * Relative error (loss):    2.9517e+03
# --------------------------------------------------------------------------------
# [ Epoch 00640 ]
# * Absolute error:           1.0090e-02
# * Relative error:           6.3865e-02
# * Relative error (gain):    4.9364e+03
# * Relative error (loss):    2.9593e+03
# --------------------------------------------------------------------------------
# [ Epoch 00650 ]
# * Absolute error:           9.9611e-03
# * Relative error:           6.3495e-02
# * Relative error (gain):    4.9622e+03
# * Relative error (loss):    2.9671e+03
# --------------------------------------------------------------------------------
# [ Epoch 00660 ]
# * Absolute error:           9.8275e-03
# * Relative error:           6.3141e-02
# * Relative error (gain):    4.9873e+03
# * Relative error (loss):    2.9746e+03
# --------------------------------------------------------------------------------
# [ Epoch 00670 ]
# * Absolute error:           9.7217e-03
# * Relative error:           6.2927e-02
# * Relative error (gain):    5.0123e+03
# * Relative error (loss):    2.9820e+03
# --------------------------------------------------------------------------------
# [ Epoch 00680 ]
# * Absolute error:           9.6079e-03
# * Relative error:           6.2611e-02
# * Relative error (gain):    5.0367e+03
# * Relative error (loss):    2.9895e+03
# --------------------------------------------------------------------------------
# [ Epoch 00690 ]
# * Absolute error:           9.5152e-03
# * Relative error:           6.2411e-02
# * Relative error (gain):    5.0603e+03
# * Relative error (loss):    2.9964e+03
# --------------------------------------------------------------------------------
# [ Epoch 00700 ]
# * Absolute error:           9.4029e-03
# * Relative error:           6.2053e-02
# * Relative error (gain):    5.0838e+03
# * Relative error (loss):    3.0034e+03
# --------------------------------------------------------------------------------
# [ Epoch 00710 ]
# * Absolute error:           9.3111e-03
# * Relative error:           6.1854e-02
# * Relative error (gain):    5.1077e+03
# * Relative error (loss):    3.0108e+03
# --------------------------------------------------------------------------------
# [ Epoch 00720 ]
# * Absolute error:           9.2250e-03
# * Relative error:           6.1690e-02
# * Relative error (gain):    5.1307e+03
# * Relative error (loss):    3.0175e+03
# --------------------------------------------------------------------------------
# [ Epoch 00730 ]
# * Absolute error:           9.1156e-03
# * Relative error:           6.1349e-02
# * Relative error (gain):    5.1536e+03
# * Relative error (loss):    3.0244e+03
# --------------------------------------------------------------------------------
# [ Epoch 00740 ]
# * Absolute error:           9.0264e-03
# * Relative error:           6.1086e-02
# * Relative error (gain):    5.1767e+03
# * Relative error (loss):    3.0313e+03
# --------------------------------------------------------------------------------
# [ Epoch 00750 ]
# * Absolute error:           8.9314e-03
# * Relative error:           6.0798e-02
# * Relative error (gain):    5.1995e+03
# * Relative error (loss):    3.0382e+03
# --------------------------------------------------------------------------------
# [ Epoch 00760 ]
# * Absolute error:           8.8400e-03
# * Relative error:           6.0542e-02
# * Relative error (gain):    5.2221e+03
# * Relative error (loss):    3.0449e+03
# --------------------------------------------------------------------------------
# [ Epoch 00770 ]
# * Absolute error:           8.7557e-03
# * Relative error:           6.0321e-02
# * Relative error (gain):    5.2438e+03
# * Relative error (loss):    3.0514e+03
# --------------------------------------------------------------------------------
# [ Epoch 00780 ]
# * Absolute error:           8.6719e-03
# * Relative error:           6.0071e-02
# * Relative error (gain):    5.2657e+03
# * Relative error (loss):    3.0578e+03
# --------------------------------------------------------------------------------
# [ Epoch 00790 ]
# * Absolute error:           8.5959e-03
# * Relative error:           5.9874e-02
# * Relative error (gain):    5.2874e+03
# * Relative error (loss):    3.0643e+03
# --------------------------------------------------------------------------------
# [ Epoch 00800 ]
# * Absolute error:           8.5081e-03
# * Relative error:           5.9574e-02
# * Relative error (gain):    5.3088e+03
# * Relative error (loss):    3.0706e+03
# --------------------------------------------------------------------------------
# [ Epoch 00810 ]
# * Absolute error:           8.4300e-03
# * Relative error:           5.9339e-02
# * Relative error (gain):    5.3298e+03
# * Relative error (loss):    3.0769e+03
# --------------------------------------------------------------------------------
# [ Epoch 00820 ]
# * Absolute error:           8.3554e-03
# * Relative error:           5.9129e-02
# * Relative error (gain):    5.3508e+03
# * Relative error (loss):    3.0830e+03
# --------------------------------------------------------------------------------
# [ Epoch 00830 ]
# * Absolute error:           8.2841e-03
# * Relative error:           5.8933e-02
# * Relative error (gain):    5.3711e+03
# * Relative error (loss):    3.0888e+03
# --------------------------------------------------------------------------------
# [ Epoch 00840 ]
# * Absolute error:           8.2001e-03
# * Relative error:           5.8649e-02
# * Relative error (gain):    5.3909e+03
# * Relative error (loss):    3.0946e+03
# --------------------------------------------------------------------------------
# [ Epoch 00850 ]
# * Absolute error:           8.1261e-03
# * Relative error:           5.8430e-02
# * Relative error (gain):    5.4103e+03
# * Relative error (loss):    3.1000e+03
# --------------------------------------------------------------------------------
# [ Epoch 00860 ]
# * Absolute error:           8.0668e-03
# * Relative error:           5.8240e-02
# * Relative error (gain):    5.4298e+03
# * Relative error (loss):    3.1058e+03
# --------------------------------------------------------------------------------
# [ Epoch 00870 ]
# * Absolute error:           7.9980e-03
# * Relative error:           5.8019e-02
# * Relative error (gain):    5.4486e+03
# * Relative error (loss):    3.1111e+03
# --------------------------------------------------------------------------------
# [ Epoch 00880 ]
# * Absolute error:           7.9331e-03
# * Relative error:           5.7832e-02
# * Relative error (gain):    5.4670e+03
# * Relative error (loss):    3.1164e+03
# --------------------------------------------------------------------------------
# [ Epoch 00890 ]
# * Absolute error:           7.8771e-03
# * Relative error:           5.7618e-02
# * Relative error (gain):    5.4853e+03
# * Relative error (loss):    3.1216e+03
# --------------------------------------------------------------------------------
# [ Epoch 00900 ]
# * Absolute error:           7.8010e-03
# * Relative error:           5.7409e-02
# * Relative error (gain):    5.5031e+03
# * Relative error (loss):    3.1264e+03
# --------------------------------------------------------------------------------
# [ Epoch 00910 ]
# * Absolute error:           7.7389e-03
# * Relative error:           5.7193e-02
# * Relative error (gain):    5.5208e+03
# * Relative error (loss):    3.1315e+03
# --------------------------------------------------------------------------------
# [ Epoch 00920 ]
# * Absolute error:           7.6889e-03
# * Relative error:           5.7030e-02
# * Relative error (gain):    5.5380e+03
# * Relative error (loss):    3.1363e+03
# --------------------------------------------------------------------------------
# [ Epoch 00930 ]
# * Absolute error:           7.6282e-03
# * Relative error:           5.6858e-02
# * Relative error (gain):    5.5550e+03
# * Relative error (loss):    3.1410e+03
# --------------------------------------------------------------------------------
# [ Epoch 00940 ]
# * Absolute error:           7.5587e-03
# * Relative error:           5.6593e-02
# * Relative error (gain):    5.5710e+03
# * Relative error (loss):    3.1454e+03
# --------------------------------------------------------------------------------
# [ Epoch 00950 ]
# * Absolute error:           7.5020e-03
# * Relative error:           5.6381e-02
# * Relative error (gain):    5.5871e+03
# * Relative error (loss):    3.1497e+03
# --------------------------------------------------------------------------------
# [ Epoch 00960 ]
# * Absolute error:           7.4588e-03
# * Relative error:           5.6222e-02
# * Relative error (gain):    5.6032e+03
# * Relative error (loss):    3.1541e+03
# --------------------------------------------------------------------------------
# [ Epoch 00970 ]
# * Absolute error:           7.4167e-03
# * Relative error:           5.6133e-02
# * Relative error (gain):    5.6197e+03
# * Relative error (loss):    3.1587e+03
# --------------------------------------------------------------------------------
# [ Epoch 00980 ]
# * Absolute error:           7.3542e-03
# * Relative error:           5.5870e-02
# * Relative error (gain):    5.6357e+03
# * Relative error (loss):    3.1632e+03
# --------------------------------------------------------------------------------
# [ Epoch 00990 ]
# * Absolute error:           7.2929e-03
# * Relative error:           5.5641e-02
# * Relative error (gain):    5.6517e+03
# * Relative error (loss):    3.1677e+03
# --------------------------------------------------------------------------------
# [ Epoch 01000 ]
# * Absolute error:           7.2352e-03
# * Relative error:           5.5439e-02
# * Relative error (gain):    5.6675e+03
# * Relative error (loss):    3.1719e+03
# --------------------------------------------------------------------------------
# [ Epoch 01010 ]
# * Absolute error:           7.1902e-03
# * Relative error:           5.5259e-02
# * Relative error (gain):    5.6834e+03
# * Relative error (loss):    3.1762e+03
# --------------------------------------------------------------------------------
# [ Epoch 01020 ]
# * Absolute error:           7.1403e-03
# * Relative error:           5.5093e-02
# * Relative error (gain):    5.6992e+03
# * Relative error (loss):    3.1807e+03
# --------------------------------------------------------------------------------
# [ Epoch 01030 ]
# * Absolute error:           7.0880e-03
# * Relative error:           5.4882e-02
# * Relative error (gain):    5.7143e+03
# * Relative error (loss):    3.1848e+03
# --------------------------------------------------------------------------------
# [ Epoch 01040 ]
# * Absolute error:           7.0519e-03
# * Relative error:           5.4791e-02
# * Relative error (gain):    5.7294e+03
# * Relative error (loss):    3.1890e+03
# --------------------------------------------------------------------------------
# [ Epoch 01050 ]
# * Absolute error:           6.9999e-03
# * Relative error:           5.4527e-02
# * Relative error (gain):    5.7441e+03
# * Relative error (loss):    3.1930e+03
# --------------------------------------------------------------------------------
# [ Epoch 01060 ]
# * Absolute error:           6.9640e-03
# * Relative error:           5.4414e-02
# * Relative error (gain):    5.7593e+03
# * Relative error (loss):    3.1973e+03
# --------------------------------------------------------------------------------
# [ Epoch 01070 ]
# * Absolute error:           6.9209e-03
# * Relative error:           5.4238e-02
# * Relative error (gain):    5.7740e+03
# * Relative error (loss):    3.2012e+03
# --------------------------------------------------------------------------------
# [ Epoch 01080 ]
# * Absolute error:           6.8672e-03
# * Relative error:           5.4022e-02
# * Relative error (gain):    5.7887e+03
# * Relative error (loss):    3.2055e+03
# --------------------------------------------------------------------------------
# [ Epoch 01090 ]
# * Absolute error:           6.8395e-03
# * Relative error:           5.3938e-02
# * Relative error (gain):    5.8034e+03
# * Relative error (loss):    3.2097e+03
# --------------------------------------------------------------------------------
# [ Epoch 01100 ]
# * Absolute error:           6.7836e-03
# * Relative error:           5.3692e-02
# * Relative error (gain):    5.8171e+03
# * Relative error (loss):    3.2134e+03
# --------------------------------------------------------------------------------
# [ Epoch 01110 ]
# * Absolute error:           6.7371e-03
# * Relative error:           5.3501e-02
# * Relative error (gain):    5.8305e+03
# * Relative error (loss):    3.2170e+03
# --------------------------------------------------------------------------------
# [ Epoch 01120 ]
# * Absolute error:           6.7133e-03
# * Relative error:           5.3430e-02
# * Relative error (gain):    5.8440e+03
# * Relative error (loss):    3.2207e+03
# --------------------------------------------------------------------------------
# [ Epoch 01130 ]
# * Absolute error:           6.6708e-03
# * Relative error:           5.3244e-02
# * Relative error (gain):    5.8572e+03
# * Relative error (loss):    3.2243e+03
# --------------------------------------------------------------------------------
# [ Epoch 01140 ]
# * Absolute error:           6.6350e-03
# * Relative error:           5.3110e-02
# * Relative error (gain):    5.8708e+03
# * Relative error (loss):    3.2282e+03
# --------------------------------------------------------------------------------
# [ Epoch 01150 ]
# * Absolute error:           6.5973e-03
# * Relative error:           5.2984e-02
# * Relative error (gain):    5.8844e+03
# * Relative error (loss):    3.2319e+03
# --------------------------------------------------------------------------------
# [ Epoch 01160 ]
# * Absolute error:           6.5513e-03
# * Relative error:           5.2754e-02
# * Relative error (gain):    5.8964e+03
# * Relative error (loss):    3.2352e+03
# --------------------------------------------------------------------------------
# [ Epoch 01170 ]
# * Absolute error:           6.5224e-03
# * Relative error:           5.2675e-02
# * Relative error (gain):    5.9084e+03
# * Relative error (loss):    3.2384e+03
# --------------------------------------------------------------------------------
# [ Epoch 01180 ]
# * Absolute error:           6.4733e-03
# * Relative error:           5.2431e-02
# * Relative error (gain):    5.9201e+03
# * Relative error (loss):    3.2414e+03
# --------------------------------------------------------------------------------
# [ Epoch 01190 ]
# * Absolute error:           6.4424e-03
# * Relative error:           5.2276e-02
# * Relative error (gain):    5.9321e+03
# * Relative error (loss):    3.2446e+03
# --------------------------------------------------------------------------------
# [ Epoch 01200 ]
# * Absolute error:           6.4108e-03
# * Relative error:           5.2146e-02
# * Relative error (gain):    5.9439e+03
# * Relative error (loss):    3.2477e+03
# --------------------------------------------------------------------------------
# [ Epoch 01210 ]
# * Absolute error:           6.3786e-03
# * Relative error:           5.2007e-02
# * Relative error (gain):    5.9559e+03
# * Relative error (loss):    3.2508e+03
# --------------------------------------------------------------------------------
# [ Epoch 01220 ]
# * Absolute error:           6.3362e-03
# * Relative error:           5.1839e-02
# * Relative error (gain):    5.9673e+03
# * Relative error (loss):    3.2537e+03
# --------------------------------------------------------------------------------
# [ Epoch 01230 ]
# * Absolute error:           6.3028e-03
# * Relative error:           5.1678e-02
# * Relative error (gain):    5.9785e+03
# * Relative error (loss):    3.2565e+03
# --------------------------------------------------------------------------------
# [ Epoch 01240 ]
# * Absolute error:           6.2733e-03
# * Relative error:           5.1559e-02
# * Relative error (gain):    5.9897e+03
# * Relative error (loss):    3.2595e+03
# --------------------------------------------------------------------------------
# [ Epoch 01250 ]
# * Absolute error:           6.2427e-03
# * Relative error:           5.1419e-02
# * Relative error (gain):    6.0003e+03
# * Relative error (loss):    3.2621e+03
# --------------------------------------------------------------------------------
# [ Epoch 01260 ]
# * Absolute error:           6.2086e-03
# * Relative error:           5.1249e-02
# * Relative error (gain):    6.0110e+03
# * Relative error (loss):    3.2648e+03
# --------------------------------------------------------------------------------
# [ Epoch 01270 ]
# * Absolute error:           6.1822e-03
# * Relative error:           5.1138e-02
# * Relative error (gain):    6.0217e+03
# * Relative error (loss):    3.2675e+03
# --------------------------------------------------------------------------------
# [ Epoch 01280 ]
# * Absolute error:           6.1455e-03
# * Relative error:           5.0963e-02
# * Relative error (gain):    6.0321e+03
# * Relative error (loss):    3.2700e+03
# --------------------------------------------------------------------------------
# [ Epoch 01290 ]
# * Absolute error:           6.1236e-03
# * Relative error:           5.0862e-02
# * Relative error (gain):    6.0429e+03
# * Relative error (loss):    3.2728e+03
# --------------------------------------------------------------------------------
# [ Epoch 01300 ]
# * Absolute error:           6.0891e-03
# * Relative error:           5.0689e-02
# * Relative error (gain):    6.0535e+03
# * Relative error (loss):    3.2756e+03
# --------------------------------------------------------------------------------
# [ Epoch 01310 ]
# * Absolute error:           6.0635e-03
# * Relative error:           5.0562e-02
# * Relative error (gain):    6.0644e+03
# * Relative error (loss):    3.2785e+03
# --------------------------------------------------------------------------------
# [ Epoch 01320 ]
# * Absolute error:           6.0349e-03
# * Relative error:           5.0421e-02
# * Relative error (gain):    6.0753e+03
# * Relative error (loss):    3.2815e+03
# --------------------------------------------------------------------------------
# [ Epoch 01330 ]
# * Absolute error:           6.0037e-03
# * Relative error:           5.0294e-02
# * Relative error (gain):    6.0862e+03
# * Relative error (loss):    3.2844e+03
# --------------------------------------------------------------------------------
# [ Epoch 01340 ]
# * Absolute error:           5.9864e-03
# * Relative error:           5.0171e-02
# * Relative error (gain):    6.0971e+03
# * Relative error (loss):    3.2874e+03
# --------------------------------------------------------------------------------
# [ Epoch 01350 ]
# * Absolute error:           5.9530e-03
# * Relative error:           5.0025e-02
# * Relative error (gain):    6.1080e+03
# * Relative error (loss):    3.2904e+03
# --------------------------------------------------------------------------------
# [ Epoch 01360 ]
# * Absolute error:           5.9249e-03
# * Relative error:           4.9902e-02
# * Relative error (gain):    6.1188e+03
# * Relative error (loss):    3.2934e+03
# --------------------------------------------------------------------------------
# [ Epoch 01370 ]
# * Absolute error:           5.8909e-03
# * Relative error:           4.9734e-02
# * Relative error (gain):    6.1294e+03
# * Relative error (loss):    3.2963e+03
# --------------------------------------------------------------------------------
# [ Epoch 01380 ]
# * Absolute error:           5.8750e-03
# * Relative error:           4.9629e-02
# * Relative error (gain):    6.1395e+03
# * Relative error (loss):    3.2990e+03
# --------------------------------------------------------------------------------
# [ Epoch 01390 ]
# * Absolute error:           5.8406e-03
# * Relative error:           4.9487e-02
# * Relative error (gain):    6.1495e+03
# * Relative error (loss):    3.3018e+03
# --------------------------------------------------------------------------------
# [ Epoch 01400 ]
# * Absolute error:           5.8134e-03
# * Relative error:           4.9342e-02
# * Relative error (gain):    6.1596e+03
# * Relative error (loss):    3.3045e+03
# --------------------------------------------------------------------------------
# [ Epoch 01410 ]
# * Absolute error:           5.7902e-03
# * Relative error:           4.9264e-02
# * Relative error (gain):    6.1694e+03
# * Relative error (loss):    3.3071e+03
# --------------------------------------------------------------------------------
# [ Epoch 01420 ]
# * Absolute error:           5.7695e-03
# * Relative error:           4.9118e-02
# * Relative error (gain):    6.1791e+03
# * Relative error (loss):    3.3097e+03
# --------------------------------------------------------------------------------
# [ Epoch 01430 ]
# * Absolute error:           5.7473e-03
# * Relative error:           4.9028e-02
# * Relative error (gain):    6.1890e+03
# * Relative error (loss):    3.3125e+03
# --------------------------------------------------------------------------------
# [ Epoch 01440 ]
# * Absolute error:           5.7177e-03
# * Relative error:           4.8888e-02
# * Relative error (gain):    6.1983e+03
# * Relative error (loss):    3.3148e+03
# --------------------------------------------------------------------------------
# [ Epoch 01450 ]
# * Absolute error:           5.6911e-03
# * Relative error:           4.8719e-02
# * Relative error (gain):    6.2075e+03
# * Relative error (loss):    3.3173e+03
# --------------------------------------------------------------------------------
# [ Epoch 01460 ]
# * Absolute error:           5.6672e-03
# * Relative error:           4.8619e-02
# * Relative error (gain):    6.2162e+03
# * Relative error (loss):    3.3195e+03
# --------------------------------------------------------------------------------
# [ Epoch 01470 ]
# * Absolute error:           5.6517e-03
# * Relative error:           4.8489e-02
# * Relative error (gain):    6.2246e+03
# * Relative error (loss):    3.3217e+03
# --------------------------------------------------------------------------------
# [ Epoch 01480 ]
# * Absolute error:           5.6236e-03
# * Relative error:           4.8393e-02
# * Relative error (gain):    6.2334e+03
# * Relative error (loss):    3.3239e+03
# --------------------------------------------------------------------------------
# [ Epoch 01490 ]
# * Absolute error:           5.6164e-03
# * Relative error:           4.8319e-02
# * Relative error (gain):    6.2418e+03
# * Relative error (loss):    3.3262e+03
# --------------------------------------------------------------------------------
# [ Epoch 01500 ]
# * Absolute error:           5.5888e-03
# * Relative error:           4.8204e-02
# * Relative error (gain):    6.2503e+03
# * Relative error (loss):    3.3283e+03
# --------------------------------------------------------------------------------
# [ Epoch 01510 ]
# * Absolute error:           5.5564e-03
# * Relative error:           4.8042e-02
# * Relative error (gain):    6.2585e+03
# * Relative error (loss):    3.3305e+03
# --------------------------------------------------------------------------------
# [ Epoch 01520 ]
# * Absolute error:           5.5413e-03
# * Relative error:           4.7941e-02
# * Relative error (gain):    6.2667e+03
# * Relative error (loss):    3.3326e+03
# --------------------------------------------------------------------------------
# [ Epoch 01530 ]
# * Absolute error:           5.5225e-03
# * Relative error:           4.7858e-02
# * Relative error (gain):    6.2749e+03
# * Relative error (loss):    3.3348e+03
# --------------------------------------------------------------------------------
# [ Epoch 01540 ]
# * Absolute error:           5.5035e-03
# * Relative error:           4.7757e-02
# * Relative error (gain):    6.2828e+03
# * Relative error (loss):    3.3369e+03
# --------------------------------------------------------------------------------
# [ Epoch 01550 ]
# * Absolute error:           5.4741e-03
# * Relative error:           4.7633e-02
# * Relative error (gain):    6.2907e+03
# * Relative error (loss):    3.3390e+03
# --------------------------------------------------------------------------------
# [ Epoch 01560 ]
# * Absolute error:           5.4547e-03
# * Relative error:           4.7489e-02
# * Relative error (gain):    6.2988e+03
# * Relative error (loss):    3.3411e+03
# --------------------------------------------------------------------------------
# [ Epoch 01570 ]
# * Absolute error:           5.4314e-03
# * Relative error:           4.7405e-02
# * Relative error (gain):    6.3070e+03
# * Relative error (loss):    3.3433e+03
# --------------------------------------------------------------------------------
# [ Epoch 01580 ]
# * Absolute error:           5.4192e-03
# * Relative error:           4.7283e-02
# * Relative error (gain):    6.3153e+03
# * Relative error (loss):    3.3457e+03
# --------------------------------------------------------------------------------
# [ Epoch 01590 ]
# * Absolute error:           5.3977e-03
# * Relative error:           4.7188e-02
# * Relative error (gain):    6.3235e+03
# * Relative error (loss):    3.3479e+03
# --------------------------------------------------------------------------------
# [ Epoch 01600 ]
# * Absolute error:           5.3827e-03
# * Relative error:           4.7103e-02
# * Relative error (gain):    6.3316e+03
# * Relative error (loss):    3.3502e+03
# --------------------------------------------------------------------------------
# [ Epoch 01610 ]
# * Absolute error:           5.3617e-03
# * Relative error:           4.6971e-02
# * Relative error (gain):    6.3390e+03
# * Relative error (loss):    3.3520e+03
# --------------------------------------------------------------------------------
# [ Epoch 01620 ]
# * Absolute error:           5.3460e-03
# * Relative error:           4.6885e-02
# * Relative error (gain):    6.3467e+03
# * Relative error (loss):    3.3541e+03
# --------------------------------------------------------------------------------
# [ Epoch 01630 ]
# * Absolute error:           5.3203e-03
# * Relative error:           4.6732e-02
# * Relative error (gain):    6.3545e+03
# * Relative error (loss):    3.3562e+03
# --------------------------------------------------------------------------------
# [ Epoch 01640 ]
# * Absolute error:           5.3039e-03
# * Relative error:           4.6655e-02
# * Relative error (gain):    6.3623e+03
# * Relative error (loss):    3.3584e+03
# --------------------------------------------------------------------------------
# [ Epoch 01650 ]
# * Absolute error:           5.2984e-03
# * Relative error:           4.6598e-02
# * Relative error (gain):    6.3698e+03
# * Relative error (loss):    3.3604e+03
# --------------------------------------------------------------------------------
# [ Epoch 01660 ]
# * Absolute error:           5.2706e-03
# * Relative error:           4.6460e-02
# * Relative error (gain):    6.3773e+03
# * Relative error (loss):    3.3624e+03
# --------------------------------------------------------------------------------
# [ Epoch 01670 ]
# * Absolute error:           5.2499e-03
# * Relative error:           4.6330e-02
# * Relative error (gain):    6.3847e+03
# * Relative error (loss):    3.3645e+03
# --------------------------------------------------------------------------------
# [ Epoch 01680 ]
# * Absolute error:           5.2374e-03
# * Relative error:           4.6258e-02
# * Relative error (gain):    6.3919e+03
# * Relative error (loss):    3.3665e+03
# --------------------------------------------------------------------------------
# [ Epoch 01690 ]
# * Absolute error:           5.2157e-03
# * Relative error:           4.6150e-02
# * Relative error (gain):    6.3990e+03
# * Relative error (loss):    3.3684e+03
# --------------------------------------------------------------------------------
# [ Epoch 01700 ]
# * Absolute error:           5.1991e-03
# * Relative error:           4.6050e-02
# * Relative error (gain):    6.4061e+03
# * Relative error (loss):    3.3703e+03
# --------------------------------------------------------------------------------
# [ Epoch 01710 ]
# * Absolute error:           5.1863e-03
# * Relative error:           4.5949e-02
# * Relative error (gain):    6.4132e+03
# * Relative error (loss):    3.3723e+03
# --------------------------------------------------------------------------------
# [ Epoch 01720 ]
# * Absolute error:           5.1659e-03
# * Relative error:           4.5843e-02
# * Relative error (gain):    6.4202e+03
# * Relative error (loss):    3.3743e+03
# --------------------------------------------------------------------------------
# [ Epoch 01730 ]
# * Absolute error:           5.1594e-03
# * Relative error:           4.5800e-02
# * Relative error (gain):    6.4273e+03
# * Relative error (loss):    3.3763e+03
# --------------------------------------------------------------------------------
# [ Epoch 01740 ]
# * Absolute error:           5.1408e-03
# * Relative error:           4.5710e-02
# * Relative error (gain):    6.4341e+03
# * Relative error (loss):    3.3781e+03
# --------------------------------------------------------------------------------
# [ Epoch 01750 ]
# * Absolute error:           5.1251e-03
# * Relative error:           4.5636e-02
# * Relative error (gain):    6.4409e+03
# * Relative error (loss):    3.3802e+03
# --------------------------------------------------------------------------------
# [ Epoch 01760 ]
# * Absolute error:           5.1072e-03
# * Relative error:           4.5501e-02
# * Relative error (gain):    6.4473e+03
# * Relative error (loss):    3.3818e+03
# --------------------------------------------------------------------------------
# [ Epoch 01770 ]
# * Absolute error:           5.0933e-03
# * Relative error:           4.5430e-02
# * Relative error (gain):    6.4540e+03
# * Relative error (loss):    3.3838e+03
# --------------------------------------------------------------------------------
# [ Epoch 01780 ]
# * Absolute error:           5.0737e-03
# * Relative error:           4.5298e-02
# * Relative error (gain):    6.4603e+03
# * Relative error (loss):    3.3856e+03
# --------------------------------------------------------------------------------
# [ Epoch 01790 ]
# * Absolute error:           5.0614e-03
# * Relative error:           4.5239e-02
# * Relative error (gain):    6.4667e+03
# * Relative error (loss):    3.3874e+03
# --------------------------------------------------------------------------------
# [ Epoch 01800 ]
# * Absolute error:           5.0432e-03
# * Relative error:           4.5106e-02
# * Relative error (gain):    6.4730e+03
# * Relative error (loss):    3.3892e+03
# --------------------------------------------------------------------------------
# [ Epoch 01810 ]
# * Absolute error:           5.0315e-03
# * Relative error:           4.5042e-02
# * Relative error (gain):    6.4796e+03
# * Relative error (loss):    3.3912e+03
# --------------------------------------------------------------------------------
# [ Epoch 01820 ]
# * Absolute error:           5.0160e-03
# * Relative error:           4.4955e-02
# * Relative error (gain):    6.4858e+03
# * Relative error (loss):    3.3928e+03
# --------------------------------------------------------------------------------
# [ Epoch 01830 ]
# * Absolute error:           5.0058e-03
# * Relative error:           4.4870e-02
# * Relative error (gain):    6.4920e+03
# * Relative error (loss):    3.3946e+03
# --------------------------------------------------------------------------------
# [ Epoch 01840 ]
# * Absolute error:           4.9869e-03
# * Relative error:           4.4779e-02
# * Relative error (gain):    6.4981e+03
# * Relative error (loss):    3.3963e+03
# --------------------------------------------------------------------------------
# [ Epoch 01850 ]
# * Absolute error:           4.9754e-03
# * Relative error:           4.4695e-02
# * Relative error (gain):    6.5044e+03
# * Relative error (loss):    3.3982e+03
# --------------------------------------------------------------------------------
# [ Epoch 01860 ]
# * Absolute error:           4.9560e-03
# * Relative error:           4.4585e-02
# * Relative error (gain):    6.5106e+03
# * Relative error (loss):    3.4000e+03
# --------------------------------------------------------------------------------
# [ Epoch 01870 ]
# * Absolute error:           4.9522e-03
# * Relative error:           4.4525e-02
# * Relative error (gain):    6.5167e+03
# * Relative error (loss):    3.4017e+03
# --------------------------------------------------------------------------------
# [ Epoch 01880 ]
# * Absolute error:           4.9402e-03
# * Relative error:           4.4461e-02
# * Relative error (gain):    6.5227e+03
# * Relative error (loss):    3.4035e+03
# --------------------------------------------------------------------------------
# [ Epoch 01890 ]
# * Absolute error:           4.9172e-03
# * Relative error:           4.4322e-02
# * Relative error (gain):    6.5284e+03
# ...
# [ Epoch 09380 ]
# * Absolute error:           2.6422e-03
# * Relative error:           2.5525e-02
# * Relative error (gain):    7.2250e+03
# * Relative error (loss):    3.9258e+03
# --------------------------------------------------------------------------------
# [ Epoch 09390 ]
# * Absolute error:           2.6425e-03
# * Relative error:           2.5520e-02
# * Relative error (gain):    7.2257e+03
# * Relative error (loss):    3.9264e+03
# --------------------------------------------------------------------------------
# [ Epoch 09400 ]
# * Absolute error:           2.6370e-03
# * Relative error:           2.5465e-02
# * Relative error (gain):    7.2261e+03
# * Relative error (loss):    3.9267e+03
# --------------------------------------------------------------------------------
# [ Epoch 09410 ]
# * Absolute error:           2.6411e-03
# * Relative error:           2.5509e-02
# * Relative error (gain):    7.2269e+03
# * Relative error (loss):    3.9273e+03
# --------------------------------------------------------------------------------
# [ Epoch 09420 ]
# * Absolute error:           2.6358e-03
# * Relative error:           2.5447e-02
# * Relative error (gain):    7.2274e+03
# * Relative error (loss):    3.9277e+03
# --------------------------------------------------------------------------------
# [ Epoch 09430 ]
# * Absolute error:           2.6372e-03
# * Relative error:           2.5465e-02
# * Relative error (gain):    7.2280e+03
# * Relative error (loss):    3.9283e+03
# --------------------------------------------------------------------------------
# [ Epoch 09440 ]
# * Absolute error:           2.6485e-03
# * Relative error:           2.5527e-02
# * Relative error (gain):    7.2286e+03
# * Relative error (loss):    3.9286e+03
# --------------------------------------------------------------------------------
# [ Epoch 09450 ]
# * Absolute error:           2.6331e-03
# * Relative error:           2.5437e-02
# * Relative error (gain):    7.2292e+03
# * Relative error (loss):    3.9291e+03
# --------------------------------------------------------------------------------
# [ Epoch 09460 ]
# * Absolute error:           2.6336e-03
# * Relative error:           2.5429e-02
# * Relative error (gain):    7.2296e+03
# * Relative error (loss):    3.9295e+03
# --------------------------------------------------------------------------------
# [ Epoch 09470 ]
# * Absolute error:           2.6395e-03
# * Relative error:           2.5436e-02
# * Relative error (gain):    7.2303e+03
# * Relative error (loss):    3.9300e+03
# --------------------------------------------------------------------------------
# [ Epoch 09480 ]
# * Absolute error:           2.6319e-03
# * Relative error:           2.5407e-02
# * Relative error (gain):    7.2307e+03
# * Relative error (loss):    3.9304e+03
# --------------------------------------------------------------------------------
# [ Epoch 09490 ]
# * Absolute error:           2.6334e-03
# * Relative error:           2.5412e-02
# * Relative error (gain):    7.2314e+03
# * Relative error (loss):    3.9310e+03
# --------------------------------------------------------------------------------
# [ Epoch 09500 ]
# * Absolute error:           2.6328e-03
# * Relative error:           2.5385e-02
# * Relative error (gain):    7.2320e+03
# * Relative error (loss):    3.9314e+03
# --------------------------------------------------------------------------------
# [ Epoch 09510 ]
# * Absolute error:           2.6333e-03
# * Relative error:           2.5416e-02
# * Relative error (gain):    7.2326e+03
# * Relative error (loss):    3.9318e+03
# --------------------------------------------------------------------------------
# [ Epoch 09520 ]
# * Absolute error:           2.6297e-03
# * Relative error:           2.5401e-02
# * Relative error (gain):    7.2330e+03
# * Relative error (loss):    3.9322e+03
# --------------------------------------------------------------------------------
# [ Epoch 09530 ]
# * Absolute error:           2.6304e-03
# * Relative error:           2.5383e-02
# * Relative error (gain):    7.2338e+03
# * Relative error (loss):    3.9328e+03
# --------------------------------------------------------------------------------
# [ Epoch 09540 ]
# * Absolute error:           2.6277e-03
# * Relative error:           2.5341e-02
# * Relative error (gain):    7.2342e+03
# * Relative error (loss):    3.9332e+03
# --------------------------------------------------------------------------------
# [ Epoch 09550 ]
# * Absolute error:           2.6249e-03
# * Relative error:           2.5331e-02
# * Relative error (gain):    7.2347e+03
# * Relative error (loss):    3.9336e+03
# --------------------------------------------------------------------------------
# [ Epoch 09560 ]
# * Absolute error:           2.6343e-03
# * Relative error:           2.5381e-02
# * Relative error (gain):    7.2353e+03
# * Relative error (loss):    3.9341e+03
# --------------------------------------------------------------------------------
# [ Epoch 09570 ]
# * Absolute error:           2.6350e-03
# * Relative error:           2.5401e-02
# * Relative error (gain):    7.2359e+03
# * Relative error (loss):    3.9345e+03
# --------------------------------------------------------------------------------
# [ Epoch 09580 ]
# * Absolute error:           2.6299e-03
# * Relative error:           2.5346e-02
# * Relative error (gain):    7.2363e+03
# * Relative error (loss):    3.9349e+03
# --------------------------------------------------------------------------------
# [ Epoch 09590 ]
# * Absolute error:           2.6229e-03
# * Relative error:           2.5309e-02
# * Relative error (gain):    7.2371e+03
# * Relative error (loss):    3.9355e+03
# --------------------------------------------------------------------------------
# [ Epoch 09600 ]
# * Absolute error:           2.6301e-03
# * Relative error:           2.5344e-02
# * Relative error (gain):    7.2376e+03
# * Relative error (loss):    3.9359e+03
# --------------------------------------------------------------------------------
# [ Epoch 09610 ]
# * Absolute error:           2.6222e-03
# * Relative error:           2.5291e-02
# * Relative error (gain):    7.2381e+03
# * Relative error (loss):    3.9363e+03
# --------------------------------------------------------------------------------
# [ Epoch 09620 ]
# * Absolute error:           2.6254e-03
# * Relative error:           2.5318e-02
# * Relative error (gain):    7.2387e+03
# * Relative error (loss):    3.9368e+03
# --------------------------------------------------------------------------------
# [ Epoch 09630 ]
# * Absolute error:           2.6198e-03
# * Relative error:           2.5273e-02
# * Relative error (gain):    7.2393e+03
# * Relative error (loss):    3.9373e+03
# --------------------------------------------------------------------------------
# [ Epoch 09640 ]
# * Absolute error:           2.6240e-03
# * Relative error:           2.5287e-02
# * Relative error (gain):    7.2398e+03
# * Relative error (loss):    3.9377e+03
# --------------------------------------------------------------------------------
# [ Epoch 09650 ]
# * Absolute error:           2.6237e-03
# * Relative error:           2.5293e-02
# * Relative error (gain):    7.2403e+03
# * Relative error (loss):    3.9380e+03
# --------------------------------------------------------------------------------
# [ Epoch 09660 ]
# * Absolute error:           2.6230e-03
# * Relative error:           2.5290e-02
# * Relative error (gain):    7.2409e+03
# * Relative error (loss):    3.9386e+03
# --------------------------------------------------------------------------------
# [ Epoch 09670 ]
# * Absolute error:           2.6223e-03
# * Relative error:           2.5262e-02
# * Relative error (gain):    7.2415e+03
# * Relative error (loss):    3.9390e+03
# --------------------------------------------------------------------------------
# [ Epoch 09680 ]
# * Absolute error:           2.6244e-03
# * Relative error:           2.5279e-02
# * Relative error (gain):    7.2422e+03
# * Relative error (loss):    3.9396e+03
# --------------------------------------------------------------------------------
# [ Epoch 09690 ]
# * Absolute error:           2.6210e-03
# * Relative error:           2.5254e-02
# * Relative error (gain):    7.2427e+03
# * Relative error (loss):    3.9399e+03
# --------------------------------------------------------------------------------
# [ Epoch 09700 ]
# * Absolute error:           2.6173e-03
# * Relative error:           2.5233e-02
# * Relative error (gain):    7.2432e+03
# * Relative error (loss):    3.9404e+03
# --------------------------------------------------------------------------------
# [ Epoch 09710 ]
# * Absolute error:           2.6286e-03
# * Relative error:           2.5318e-02
# * Relative error (gain):    7.2438e+03
# * Relative error (loss):    3.9408e+03
# --------------------------------------------------------------------------------
# [ Epoch 09720 ]
# * Absolute error:           2.6217e-03
# * Relative error:           2.5256e-02
# * Relative error (gain):    7.2443e+03
# * Relative error (loss):    3.9412e+03
# --------------------------------------------------------------------------------
# [ Epoch 09730 ]
# * Absolute error:           2.6139e-03
# * Relative error:           2.5201e-02
# * Relative error (gain):    7.2449e+03
# * Relative error (loss):    3.9416e+03
# --------------------------------------------------------------------------------
# [ Epoch 09740 ]
# * Absolute error:           2.6132e-03
# * Relative error:           2.5166e-02
# * Relative error (gain):    7.2455e+03
# * Relative error (loss):    3.9421e+03
# --------------------------------------------------------------------------------
# [ Epoch 09750 ]
# * Absolute error:           2.6126e-03
# * Relative error:           2.5165e-02
# * Relative error (gain):    7.2462e+03
# * Relative error (loss):    3.9426e+03
# --------------------------------------------------------------------------------
# [ Epoch 09760 ]
# * Absolute error:           2.6168e-03
# * Relative error:           2.5206e-02
# * Relative error (gain):    7.2467e+03
# * Relative error (loss):    3.9430e+03
# --------------------------------------------------------------------------------
# [ Epoch 09770 ]
# * Absolute error:           2.6160e-03
# * Relative error:           2.5222e-02
# * Relative error (gain):    7.2473e+03
# * Relative error (loss):    3.9435e+03
# --------------------------------------------------------------------------------
# [ Epoch 09780 ]
# * Absolute error:           2.6092e-03
# * Relative error:           2.5142e-02
# * Relative error (gain):    7.2479e+03
# * Relative error (loss):    3.9440e+03
# --------------------------------------------------------------------------------
# [ Epoch 09790 ]
# * Absolute error:           2.6067e-03
# * Relative error:           2.5134e-02
# * Relative error (gain):    7.2484e+03
# * Relative error (loss):    3.9444e+03
# --------------------------------------------------------------------------------
# [ Epoch 09800 ]
# * Absolute error:           2.6049e-03
# * Relative error:           2.5112e-02
# * Relative error (gain):    7.2491e+03
# * Relative error (loss):    3.9449e+03
# --------------------------------------------------------------------------------
# [ Epoch 09810 ]
# * Absolute error:           2.6109e-03
# * Relative error:           2.5147e-02
# * Relative error (gain):    7.2497e+03
# * Relative error (loss):    3.9453e+03
# --------------------------------------------------------------------------------
# [ Epoch 09820 ]
# * Absolute error:           2.6081e-03
# * Relative error:           2.5132e-02
# * Relative error (gain):    7.2501e+03
# * Relative error (loss):    3.9457e+03
# --------------------------------------------------------------------------------
# [ Epoch 09830 ]
# * Absolute error:           2.6040e-03
# * Relative error:           2.5092e-02
# * Relative error (gain):    7.2509e+03
# * Relative error (loss):    3.9462e+03
# --------------------------------------------------------------------------------
# [ Epoch 09840 ]
# * Absolute error:           2.6078e-03
# * Relative error:           2.5123e-02
# * Relative error (gain):    7.2515e+03
# * Relative error (loss):    3.9467e+03
# --------------------------------------------------------------------------------
# [ Epoch 09850 ]
# * Absolute error:           2.6053e-03
# * Relative error:           2.5086e-02
# * Relative error (gain):    7.2520e+03
# * Relative error (loss):    3.9471e+03
# --------------------------------------------------------------------------------
# [ Epoch 09860 ]
# * Absolute error:           2.6076e-03
# * Relative error:           2.5105e-02
# * Relative error (gain):    7.2526e+03
# * Relative error (loss):    3.9476e+03
# --------------------------------------------------------------------------------
# [ Epoch 09870 ]
# * Absolute error:           2.6061e-03
# * Relative error:           2.5093e-02
# * Relative error (gain):    7.2531e+03
# * Relative error (loss):    3.9479e+03
# --------------------------------------------------------------------------------
# [ Epoch 09880 ]
# * Absolute error:           2.6015e-03
# * Relative error:           2.5056e-02
# * Relative error (gain):    7.2536e+03
# * Relative error (loss):    3.9483e+03
# --------------------------------------------------------------------------------
# [ Epoch 09890 ]
# * Absolute error:           2.6031e-03
# * Relative error:           2.5073e-02
# * Relative error (gain):    7.2542e+03
# * Relative error (loss):    3.9488e+03
# --------------------------------------------------------------------------------
# [ Epoch 09900 ]
# * Absolute error:           2.6062e-03
# * Relative error:           2.5073e-02
# * Relative error (gain):    7.2548e+03
# * Relative error (loss):    3.9493e+03
# --------------------------------------------------------------------------------
# [ Epoch 09910 ]
# * Absolute error:           2.6022e-03
# * Relative error:           2.5047e-02
# * Relative error (gain):    7.2554e+03
# * Relative error (loss):    3.9497e+03
# --------------------------------------------------------------------------------
# [ Epoch 09920 ]
# * Absolute error:           2.6056e-03
# * Relative error:           2.5076e-02
# * Relative error (gain):    7.2559e+03
# * Relative error (loss):    3.9502e+03
# --------------------------------------------------------------------------------
# [ Epoch 09930 ]
# * Absolute error:           2.6054e-03
# * Relative error:           2.5075e-02
# * Relative error (gain):    7.2565e+03
# * Relative error (loss):    3.9506e+03
# --------------------------------------------------------------------------------
# [ Epoch 09940 ]
# * Absolute error:           2.6056e-03
# * Relative error:           2.5066e-02
# * Relative error (gain):    7.2570e+03
# * Relative error (loss):    3.9510e+03
# --------------------------------------------------------------------------------
# [ Epoch 09950 ]
# * Absolute error:           2.5967e-03
# * Relative error:           2.5014e-02
# * Relative error (gain):    7.2575e+03
# * Relative error (loss):    3.9514e+03
# --------------------------------------------------------------------------------
# [ Epoch 09960 ]
# * Absolute error:           2.5988e-03
# * Relative error:           2.5018e-02
# * Relative error (gain):    7.2580e+03
# * Relative error (loss):    3.9518e+03
# --------------------------------------------------------------------------------
# [ Epoch 09970 ]
# * Absolute error:           2.5958e-03
# * Relative error:           2.4985e-02
# * Relative error (gain):    7.2586e+03
# * Relative error (loss):    3.9522e+03
# --------------------------------------------------------------------------------
# [ Epoch 09980 ]
# * Absolute error:           2.6005e-03
# * Relative error:           2.5009e-02
# * Relative error (gain):    7.2593e+03
# * Relative error (loss):    3.9527e+03
# --------------------------------------------------------------------------------
# [ Epoch 09990 ]
# * Absolute error:           2.5966e-03
# * Relative error:           2.4984e-02
# * Relative error (gain):    7.2599e+03
# * Relative error (loss):    3.9532e+03
# --------------------------------------------------------------------------------
# [ Epoch 10000 ]
# * Absolute error:           2.6026e-03
# * Relative error:           2.5012e-02
# * Relative error (gain):    7.2604e+03
# * Relative error (loss):    3.9536e+03
# --------------------------------------------------------------------------------
# FourierLandauLayer()

# %%
idx = torch.randint(0, len(data), (1,)).item()
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
d1 = pred_collision[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
d2 = target_collision[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
d3 = (pred_collision-target_collision)[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
fig.colorbar(axes[0].imshow(d1))
fig.colorbar(axes[1].imshow(d2))
fig.colorbar(axes[2].imshow(np.abs(d3)))
plt.show()

# %%
torch.save(
    obj = specnet.cpu().state_dict(),
    f   = path_data / f"Landau__alpha_{int(VHS_ALPHA)}__res_{RESOLUTION}__specnet__deg_10.pth"
)

# %% [markdown]
# End of file

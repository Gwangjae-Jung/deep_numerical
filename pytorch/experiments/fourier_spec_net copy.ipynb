# %%
from    typing              import  *
from    typing_extensions   import  Self

from    tqdm.notebook       import  tqdm

import  numpy               as  np
import  matplotlib.pyplot   as  plt

import  torch
from    torch.utils.data    import  Dataset, DataLoader


from    pathlib             import  Path
root_dir    = r"/media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE"
path_root   = Path(root_dir)
path_lib    = path_root / "python_deep_numerical"
path_data   = path_root / "datasets"

import  sys
sys.path.append( str(path_lib) )
from    pytorch.layers                  import  FourierBoltzmannLayer
from    pytorch.torch_numerical         import  utils
from    pytorch.utils                   import  initialize_weights


dtype  = torch.float32
dtype_complex = utils.dtype_real_to_complex(dtype)
device = torch.device('cuda:1')
__dtype_str = str(dtype).split(".")[-1]
dtype_and_device = {'dtype': dtype, 'device': device}
print(f"Device for computation\n>>> {device}")
# Out:
# Device for computation
# >>> cuda:1

# %%
DIMENSION:  int     = 2
RESOLUTION: int     = 64
VHS_ALPHA:  float   = 0.0

_file = path_data / f"{__dtype_str}/test__Boltzmann__alpha_{int(VHS_ALPHA)}__res_{RESOLUTION}.npz"
print(f"Loading data from\n>>> {_file}")
file = np.load(_file)

V_MAX:      float   = float(file['v_max'])
DELTA_V:    float   = (2*V_MAX) / RESOLUTION
FFT_NORM:   str     = 'forward'

VHS_COEFF:  float   = file['vhs_coeff']
# Out:
# Loading data from
# >>> /media/junseung/47a90e46-3a9d-467c-bbee-066752b68532/GWANGJAE/datasets/float32/test__Boltzmann__alpha_0__res_64.npz

# %%
class CustomDataset(Dataset):
    def __init__(
            self,
            distr:      torch.Tensor,
            gain_fft:   torch.Tensor,
            loss_fft:   torch.Tensor,
            vhs_alpha:  Optional[torch.Tensor]  = None,
            dim:        Optional[int]           = None,
            squeeze_space: bool = False,
        ) -> Self:
        self.dim:       int                         = dim
        self.distr:     torch.Tensor                = distr
        self.gain_fft:  torch.Tensor                = gain_fft
        self.loss_fft:  torch.Tensor                = loss_fft
        self.vhs_alpha: Optional[torch.Tensor]      = vhs_alpha
        self.__fft_dim: tuple[int] = tuple(range(1+dim, 1+2*dim))
        
        if squeeze_space:
            self.distr      = self.distr.reshape(distr.size(0), *distr.shape[-1-dim:])
            self.gain_fft   = self.gain_fft.reshape(gain_fft.size(0), *gain_fft.shape[-1-dim:])
            self.loss_fft   = self.loss_fft.reshape(loss_fft.size(0), *loss_fft.shape[-1-dim:])
            self.__fft_dim  = tuple(range(1, 1+dim))
            
        return
    
    
    def __getitem__(self, index: int) -> tuple[torch.Tensor]:
        if self.vhs_alpha:
            return self.distr[index], self.gain_fft[index], self.loss_fft[index], self.vhs_alpha[index]
        else:
            return self.distr[index], self.gain_fft[index], self.loss_fft[index]
    
    def __len__(self) -> int:
        return self.distr.size(0)
    
    
    @property
    def fft_dim(self) -> tuple[int]:
        return self.__fft_dim

# %%
dataset  = CustomDataset(
    torch.tensor(file['data'], dtype=dtype),
    torch.tensor(file['gain_fft'], dtype=dtype_complex),
    torch.tensor(file['loss_fft'], dtype=dtype_complex),
    dim=DIMENSION,
    squeeze_space=False,
)
dataloader  = DataLoader(dataset, batch_size=512, shuffle=True)
FFT_DIM = dataset.fft_dim

# %%
specnet     = FourierBoltzmannLayer(DIMENSION, 8, n_channels=1, n_weights=30).to(device)
initialize_weights(specnet, 'xavier uniform')
optimizer   = torch.optim.Adam(specnet.parameters(), lr=5e-4)

print(specnet)
# Out:
# ==============================< FourierBoltzmannLayer >==============================
# [ Subnetworks ]
#
# -------------------------------------------------------------------------------------
# [ Parameters ]
#
# ( params_alpha )
# * Shape:       [16, 16, 1, 30]
# * Data type:   torch.complex64
# ( params_beta )
# * Shape:       [16, 16, 1, 30]
# * Data type:   torch.complex64
# ( params_gamma )
# * Shape:       [16, 16, 1, 30]
# * Data type:   torch.complex64
# ( params_diag )
# * Shape:       [16, 16, 1]
# * Data type:   torch.complex64
# -------------------------------------------------------------------------------------
# Number of parameters: 46592
# =====================================================================================

# %%
NUM_EPOCHS: int = 10000
dv = DELTA_V**DIMENSION
specnet.train()

data:       torch.Tensor
gain_fft:   torch.Tensor
loss_fft:   torch.Tensor

for epoch in tqdm(range(1, 1+NUM_EPOCHS)):
    abs_error:  float = 0.0
    rel_error:  float = 0.0
    
    for data, gain_fft, loss_fft in dataloader:
        data        = data.to(device)
        data_fft:   torch.Tensor = torch.fft.fftn(data, dim=FFT_DIM, norm=FFT_NORM)
        gain_fft    = gain_fft.to(device)
        loss_fft    = loss_fft.to(device)
        target_collision:   torch.Tensor = torch.fft.ifftn(gain_fft-loss_fft, dim=FFT_DIM, norm=FFT_NORM).real

        # pred_gain_fft = sm_object.compute_gain_fft(None, data_fft)
        # pred_loss_fft = sm_object.compute_loss_fft(None, data_fft)
        # pred_gain_fft = specnet.compute_gain_fft(data_fft)
        # pred_loss_fft = specnet.compute_loss_fft(data_fft)
        pred_fft        = specnet.forward(data_fft)
        pred_collision: torch.Tensor = torch.fft.ifftn(pred_fft, dim=FFT_DIM, norm=FFT_NORM).real

        _data_size = len(data)
        _abs_error = utils.absolute_error(pred_collision, target_collision).mean()
        _rel_error = utils.relative_error(pred_collision, target_collision).mean()
        abs_error += _abs_error.item() * _data_size
        rel_error += _rel_error.item() * _data_size
        
        optimizer.zero_grad()
        _rel_error.backward()
        optimizer.step()
        
    __abs_scale = dv/len(dataset)
    __rel_scale = 1.0/len(dataset)
    abs_error       *= __abs_scale
    rel_error       *= __rel_scale
    if epoch%10==0 or epoch==1:
        print(f"[ Epoch {str(epoch).zfill(len(str(NUM_EPOCHS)))} ]")
        print(f"* Absolute error:       {abs_error:.4e}")
        print(f"* Relative error:       {rel_error:.4e}")
        print('-'*80)

specnet.eval()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# [ Epoch 00001 ]
# * Absolute error:       6.2123e-04
# * Relative error:       4.7994e+02
# --------------------------------------------------------------------------------
# [ Epoch 00010 ]
# * Absolute error:       4.9273e-04
# * Relative error:       1.6484e+02
# --------------------------------------------------------------------------------
# [ Epoch 00020 ]
# * Absolute error:       4.6002e-04
# * Relative error:       5.9976e+01
# --------------------------------------------------------------------------------
# [ Epoch 00030 ]
# * Absolute error:       4.5208e-04
# * Relative error:       3.6328e+01
# --------------------------------------------------------------------------------
# [ Epoch 00040 ]
# * Absolute error:       4.4686e-04
# * Relative error:       2.0929e+01
# --------------------------------------------------------------------------------
# [ Epoch 00050 ]
# * Absolute error:       4.4472e-04
# * Relative error:       1.3485e+01
# --------------------------------------------------------------------------------
# [ Epoch 00060 ]
# * Absolute error:       4.4377e-04
# * Relative error:       1.0037e+01
# --------------------------------------------------------------------------------
# [ Epoch 00070 ]
# * Absolute error:       4.4316e-04
# * Relative error:       8.0374e+00
# --------------------------------------------------------------------------------
# [ Epoch 00080 ]
# * Absolute error:       4.4276e-04
# * Relative error:       6.8323e+00
# --------------------------------------------------------------------------------
# [ Epoch 00090 ]
# * Absolute error:       4.4248e-04
# * Relative error:       5.9717e+00
# --------------------------------------------------------------------------------
# [ Epoch 00100 ]
# * Absolute error:       4.4229e-04
# * Relative error:       5.3725e+00
# --------------------------------------------------------------------------------
# [ Epoch 00110 ]
# * Absolute error:       4.4212e-04
# * Relative error:       4.8637e+00
# --------------------------------------------------------------------------------
# [ Epoch 00120 ]
# * Absolute error:       4.4199e-04
# * Relative error:       4.4300e+00
# --------------------------------------------------------------------------------
# [ Epoch 00130 ]
# * Absolute error:       4.4188e-04
# * Relative error:       4.0652e+00
# --------------------------------------------------------------------------------
# [ Epoch 00140 ]
# * Absolute error:       4.4180e-04
# * Relative error:       3.7714e+00
# --------------------------------------------------------------------------------
# [ Epoch 00150 ]
# * Absolute error:       4.4174e-04
# * Relative error:       3.5837e+00
# --------------------------------------------------------------------------------
# [ Epoch 00160 ]
# * Absolute error:       4.4167e-04
# * Relative error:       3.3571e+00
# --------------------------------------------------------------------------------
# [ Epoch 00170 ]
# * Absolute error:       4.4164e-04
# * Relative error:       3.2452e+00
# --------------------------------------------------------------------------------
# [ Epoch 00180 ]
# * Absolute error:       4.4156e-04
# * Relative error:       2.9198e+00
# --------------------------------------------------------------------------------
# [ Epoch 00190 ]
# * Absolute error:       4.4153e-04
# * Relative error:       2.8286e+00
# --------------------------------------------------------------------------------
# [ Epoch 00200 ]
# * Absolute error:       4.4150e-04
# * Relative error:       2.7157e+00
# --------------------------------------------------------------------------------
# [ Epoch 00210 ]
# * Absolute error:       4.4147e-04
# * Relative error:       2.6224e+00
# --------------------------------------------------------------------------------
# [ Epoch 00220 ]
# * Absolute error:       4.4146e-04
# * Relative error:       2.6176e+00
# --------------------------------------------------------------------------------
# [ Epoch 00230 ]
# * Absolute error:       4.4145e-04
# * Relative error:       2.6092e+00
# --------------------------------------------------------------------------------
# [ Epoch 00240 ]
# * Absolute error:       4.4142e-04
# * Relative error:       2.4770e+00
# --------------------------------------------------------------------------------
# [ Epoch 00250 ]
# * Absolute error:       4.4140e-04
# * Relative error:       2.3963e+00
# --------------------------------------------------------------------------------
# [ Epoch 00260 ]
# * Absolute error:       4.4139e-04
# * Relative error:       2.3380e+00
# --------------------------------------------------------------------------------
# [ Epoch 00270 ]
# * Absolute error:       4.4137e-04
# * Relative error:       2.2819e+00
# --------------------------------------------------------------------------------
# [ Epoch 00280 ]
# * Absolute error:       4.4137e-04
# * Relative error:       2.3149e+00
# --------------------------------------------------------------------------------
# [ Epoch 00290 ]
# * Absolute error:       4.4135e-04
# * Relative error:       2.2358e+00
# --------------------------------------------------------------------------------
# [ Epoch 00300 ]
# * Absolute error:       4.4136e-04
# * Relative error:       2.3096e+00
# --------------------------------------------------------------------------------
# [ Epoch 00310 ]
# * Absolute error:       4.4134e-04
# * Relative error:       2.1948e+00
# --------------------------------------------------------------------------------
# [ Epoch 00320 ]
# * Absolute error:       4.4132e-04
# * Relative error:       2.1475e+00
# --------------------------------------------------------------------------------
# [ Epoch 00330 ]
# * Absolute error:       4.4132e-04
# * Relative error:       2.1307e+00
# --------------------------------------------------------------------------------
# [ Epoch 00340 ]
# * Absolute error:       4.4131e-04
# * Relative error:       2.1043e+00
# --------------------------------------------------------------------------------
# [ Epoch 00350 ]
# * Absolute error:       4.4131e-04
# * Relative error:       2.1323e+00
# --------------------------------------------------------------------------------
# [ Epoch 00360 ]
# * Absolute error:       4.4134e-04
# * Relative error:       2.3132e+00
# --------------------------------------------------------------------------------
# [ Epoch 00370 ]
# * Absolute error:       4.4132e-04
# * Relative error:       2.2192e+00
# --------------------------------------------------------------------------------
# [ Epoch 00380 ]
# * Absolute error:       4.4128e-04
# * Relative error:       2.0288e+00
# --------------------------------------------------------------------------------
# [ Epoch 00390 ]
# * Absolute error:       4.4129e-04
# * Relative error:       2.0729e+00
# --------------------------------------------------------------------------------
# [ Epoch 00400 ]
# * Absolute error:       4.4128e-04
# * Relative error:       2.0351e+00
# --------------------------------------------------------------------------------
# [ Epoch 00410 ]
# * Absolute error:       4.4127e-04
# * Relative error:       2.0210e+00
# --------------------------------------------------------------------------------
# [ Epoch 00420 ]
# * Absolute error:       4.4126e-04
# * Relative error:       1.9739e+00
# --------------------------------------------------------------------------------
# [ Epoch 00430 ]
# * Absolute error:       4.4126e-04
# * Relative error:       1.9485e+00
# --------------------------------------------------------------------------------
# [ Epoch 00440 ]
# * Absolute error:       4.4125e-04
# * Relative error:       1.9180e+00
# --------------------------------------------------------------------------------
# [ Epoch 00450 ]
# * Absolute error:       4.4124e-04
# * Relative error:       1.9052e+00
# --------------------------------------------------------------------------------
# [ Epoch 00460 ]
# * Absolute error:       4.4128e-04
# * Relative error:       2.0976e+00
# --------------------------------------------------------------------------------
# [ Epoch 00470 ]
# * Absolute error:       4.4124e-04
# * Relative error:       1.9215e+00
# --------------------------------------------------------------------------------
# [ Epoch 00480 ]
# * Absolute error:       4.4124e-04
# * Relative error:       1.9298e+00
# --------------------------------------------------------------------------------
# [ Epoch 00490 ]
# * Absolute error:       4.4122e-04
# * Relative error:       1.8439e+00
# --------------------------------------------------------------------------------
# [ Epoch 00500 ]
# * Absolute error:       4.4124e-04
# * Relative error:       1.9343e+00
# --------------------------------------------------------------------------------
# [ Epoch 00510 ]
# * Absolute error:       4.4125e-04
# * Relative error:       1.9684e+00
# --------------------------------------------------------------------------------
# [ Epoch 00520 ]
# * Absolute error:       4.4123e-04
# * Relative error:       1.8697e+00
# --------------------------------------------------------------------------------
# [ Epoch 00530 ]
# * Absolute error:       4.4121e-04
# * Relative error:       1.8079e+00
# --------------------------------------------------------------------------------
# [ Epoch 00540 ]
# * Absolute error:       4.4125e-04
# * Relative error:       1.9961e+00
# --------------------------------------------------------------------------------
# [ Epoch 00550 ]
# * Absolute error:       4.4121e-04
# * Relative error:       1.7971e+00
# --------------------------------------------------------------------------------
# [ Epoch 00560 ]
# * Absolute error:       4.4120e-04
# * Relative error:       1.7669e+00
# --------------------------------------------------------------------------------
# [ Epoch 00570 ]
# * Absolute error:       4.4120e-04
# * Relative error:       1.7889e+00
# --------------------------------------------------------------------------------
# [ Epoch 00580 ]
# * Absolute error:       4.4137e-04
# * Relative error:       2.6290e+00
# --------------------------------------------------------------------------------
# [ Epoch 00590 ]
# * Absolute error:       4.4121e-04
# * Relative error:       1.8639e+00
# --------------------------------------------------------------------------------
# [ Epoch 00600 ]
# * Absolute error:       4.4119e-04
# * Relative error:       1.7629e+00
# --------------------------------------------------------------------------------
# [ Epoch 00610 ]
# * Absolute error:       4.4119e-04
# * Relative error:       1.7584e+00
# --------------------------------------------------------------------------------
# [ Epoch 00620 ]
# * Absolute error:       4.4119e-04
# * Relative error:       1.7324e+00
# --------------------------------------------------------------------------------
# [ Epoch 00630 ]
# * Absolute error:       4.4122e-04
# * Relative error:       1.8940e+00
# --------------------------------------------------------------------------------
# [ Epoch 00640 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.6953e+00
# --------------------------------------------------------------------------------
# [ Epoch 00650 ]
# * Absolute error:       4.4119e-04
# * Relative error:       1.7646e+00
# --------------------------------------------------------------------------------
# [ Epoch 00660 ]
# * Absolute error:       4.4132e-04
# * Relative error:       2.4239e+00
# --------------------------------------------------------------------------------
# [ Epoch 00670 ]
# * Absolute error:       4.4119e-04
# * Relative error:       1.7617e+00
# --------------------------------------------------------------------------------
# [ Epoch 00680 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.6726e+00
# --------------------------------------------------------------------------------
# [ Epoch 00690 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.6776e+00
# --------------------------------------------------------------------------------
# [ Epoch 00700 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.7366e+00
# --------------------------------------------------------------------------------
# [ Epoch 00710 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.6826e+00
# --------------------------------------------------------------------------------
# [ Epoch 00720 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.6270e+00
# --------------------------------------------------------------------------------
# [ Epoch 00730 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.6262e+00
# --------------------------------------------------------------------------------
# [ Epoch 00740 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.6633e+00
# --------------------------------------------------------------------------------
# [ Epoch 00750 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.6565e+00
# --------------------------------------------------------------------------------
# [ Epoch 00760 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.6955e+00
# --------------------------------------------------------------------------------
# [ Epoch 00770 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.6139e+00
# --------------------------------------------------------------------------------
# [ Epoch 00780 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.7095e+00
# --------------------------------------------------------------------------------
# [ Epoch 00790 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.7066e+00
# --------------------------------------------------------------------------------
# [ Epoch 00800 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.6351e+00
# --------------------------------------------------------------------------------
# [ Epoch 00810 ]
# * Absolute error:       4.4123e-04
# * Relative error:       1.9860e+00
# --------------------------------------------------------------------------------
# [ Epoch 00820 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.6002e+00
# --------------------------------------------------------------------------------
# [ Epoch 00830 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.5890e+00
# --------------------------------------------------------------------------------
# [ Epoch 00840 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.6296e+00
# --------------------------------------------------------------------------------
# [ Epoch 00850 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.7484e+00
# --------------------------------------------------------------------------------
# [ Epoch 00860 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.7094e+00
# --------------------------------------------------------------------------------
# [ Epoch 00870 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.6780e+00
# --------------------------------------------------------------------------------
# [ Epoch 00880 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.5882e+00
# --------------------------------------------------------------------------------
# [ Epoch 00890 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.6766e+00
# --------------------------------------------------------------------------------
# [ Epoch 00900 ]
# * Absolute error:       4.4124e-04
# * Relative error:       2.1147e+00
# --------------------------------------------------------------------------------
# [ Epoch 00910 ]
# * Absolute error:       4.4125e-04
# * Relative error:       2.1342e+00
# --------------------------------------------------------------------------------
# [ Epoch 00920 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.6159e+00
# --------------------------------------------------------------------------------
# [ Epoch 00930 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5435e+00
# --------------------------------------------------------------------------------
# [ Epoch 00940 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5273e+00
# --------------------------------------------------------------------------------
# [ Epoch 00950 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5376e+00
# --------------------------------------------------------------------------------
# [ Epoch 00960 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5400e+00
# --------------------------------------------------------------------------------
# [ Epoch 00970 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5208e+00
# --------------------------------------------------------------------------------
# [ Epoch 00980 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5225e+00
# --------------------------------------------------------------------------------
# [ Epoch 00990 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5267e+00
# --------------------------------------------------------------------------------
# [ Epoch 01000 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5614e+00
# --------------------------------------------------------------------------------
# [ Epoch 01010 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.5098e+00
# --------------------------------------------------------------------------------
# [ Epoch 01020 ]
# * Absolute error:       4.4126e-04
# * Relative error:       2.2147e+00
# --------------------------------------------------------------------------------
# [ Epoch 01030 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.7519e+00
# --------------------------------------------------------------------------------
# [ Epoch 01040 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.5200e+00
# --------------------------------------------------------------------------------
# [ Epoch 01050 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.6097e+00
# --------------------------------------------------------------------------------
# [ Epoch 01060 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.6801e+00
# --------------------------------------------------------------------------------
# [ Epoch 01070 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.7535e+00
# --------------------------------------------------------------------------------
# [ Epoch 01080 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.5931e+00
# --------------------------------------------------------------------------------
# [ Epoch 01090 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.4811e+00
# --------------------------------------------------------------------------------
# [ Epoch 01100 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5675e+00
# --------------------------------------------------------------------------------
# [ Epoch 01110 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5322e+00
# --------------------------------------------------------------------------------
# [ Epoch 01120 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.5118e+00
# --------------------------------------------------------------------------------
# [ Epoch 01130 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.6358e+00
# --------------------------------------------------------------------------------
# [ Epoch 01140 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.4898e+00
# --------------------------------------------------------------------------------
# [ Epoch 01150 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.5013e+00
# --------------------------------------------------------------------------------
# [ Epoch 01160 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.4728e+00
# --------------------------------------------------------------------------------
# [ Epoch 01170 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.7460e+00
# --------------------------------------------------------------------------------
# [ Epoch 01180 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.6018e+00
# --------------------------------------------------------------------------------
# [ Epoch 01190 ]
# * Absolute error:       4.4122e-04
# * Relative error:       2.0268e+00
# --------------------------------------------------------------------------------
# [ Epoch 01200 ]
# * Absolute error:       4.4120e-04
# * Relative error:       1.9332e+00
# --------------------------------------------------------------------------------
# [ Epoch 01210 ]
# * Absolute error:       4.4122e-04
# * Relative error:       2.0188e+00
# --------------------------------------------------------------------------------
# [ Epoch 01220 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.8434e+00
# --------------------------------------------------------------------------------
# [ Epoch 01230 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4324e+00
# --------------------------------------------------------------------------------
# [ Epoch 01240 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4315e+00
# --------------------------------------------------------------------------------
# [ Epoch 01250 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4138e+00
# --------------------------------------------------------------------------------
# [ Epoch 01260 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.4714e+00
# --------------------------------------------------------------------------------
# [ Epoch 01270 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4498e+00
# --------------------------------------------------------------------------------
# [ Epoch 01280 ]
# * Absolute error:       4.4119e-04
# * Relative error:       1.8836e+00
# --------------------------------------------------------------------------------
# [ Epoch 01290 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4273e+00
# --------------------------------------------------------------------------------
# [ Epoch 01300 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.4760e+00
# --------------------------------------------------------------------------------
# [ Epoch 01310 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.4750e+00
# --------------------------------------------------------------------------------
# [ Epoch 01320 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4260e+00
# --------------------------------------------------------------------------------
# [ Epoch 01330 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.5592e+00
# --------------------------------------------------------------------------------
# [ Epoch 01340 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.7624e+00
# --------------------------------------------------------------------------------
# [ Epoch 01350 ]
# * Absolute error:       4.4122e-04
# * Relative error:       2.0810e+00
# --------------------------------------------------------------------------------
# [ Epoch 01360 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.3888e+00
# --------------------------------------------------------------------------------
# [ Epoch 01370 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.4715e+00
# --------------------------------------------------------------------------------
# [ Epoch 01380 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.5142e+00
# --------------------------------------------------------------------------------
# [ Epoch 01390 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4133e+00
# --------------------------------------------------------------------------------
# [ Epoch 01400 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.8109e+00
# --------------------------------------------------------------------------------
# [ Epoch 01410 ]
# * Absolute error:       4.4120e-04
# * Relative error:       1.9581e+00
# --------------------------------------------------------------------------------
# [ Epoch 01420 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.5917e+00
# --------------------------------------------------------------------------------
# [ Epoch 01430 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.6826e+00
# --------------------------------------------------------------------------------
# [ Epoch 01440 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4681e+00
# --------------------------------------------------------------------------------
# [ Epoch 01450 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.3829e+00
# --------------------------------------------------------------------------------
# [ Epoch 01460 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3669e+00
# --------------------------------------------------------------------------------
# [ Epoch 01470 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3580e+00
# --------------------------------------------------------------------------------
# [ Epoch 01480 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4055e+00
# --------------------------------------------------------------------------------
# [ Epoch 01490 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4248e+00
# --------------------------------------------------------------------------------
# [ Epoch 01500 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4145e+00
# --------------------------------------------------------------------------------
# [ Epoch 01510 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4601e+00
# --------------------------------------------------------------------------------
# [ Epoch 01520 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.8209e+00
# --------------------------------------------------------------------------------
# [ Epoch 01530 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.7904e+00
# --------------------------------------------------------------------------------
# [ Epoch 01540 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4192e+00
# --------------------------------------------------------------------------------
# [ Epoch 01550 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.3893e+00
# --------------------------------------------------------------------------------
# [ Epoch 01560 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4551e+00
# --------------------------------------------------------------------------------
# [ Epoch 01570 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4092e+00
# --------------------------------------------------------------------------------
# [ Epoch 01580 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.7190e+00
# --------------------------------------------------------------------------------
# [ Epoch 01590 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.8874e+00
# --------------------------------------------------------------------------------
# [ Epoch 01600 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4612e+00
# --------------------------------------------------------------------------------
# [ Epoch 01610 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3650e+00
# --------------------------------------------------------------------------------
# [ Epoch 01620 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3900e+00
# --------------------------------------------------------------------------------
# [ Epoch 01630 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4194e+00
# --------------------------------------------------------------------------------
# [ Epoch 01640 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.7911e+00
# --------------------------------------------------------------------------------
# [ Epoch 01650 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.6748e+00
# --------------------------------------------------------------------------------
# [ Epoch 01660 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3761e+00
# --------------------------------------------------------------------------------
# [ Epoch 01670 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3926e+00
# --------------------------------------------------------------------------------
# [ Epoch 01680 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3248e+00
# --------------------------------------------------------------------------------
# [ Epoch 01690 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3522e+00
# --------------------------------------------------------------------------------
# [ Epoch 01700 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.7791e+00
# --------------------------------------------------------------------------------
# [ Epoch 01710 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3380e+00
# --------------------------------------------------------------------------------
# [ Epoch 01720 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3985e+00
# --------------------------------------------------------------------------------
# [ Epoch 01730 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.4683e+00
# --------------------------------------------------------------------------------
# [ Epoch 01740 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.7615e+00
# --------------------------------------------------------------------------------
# [ Epoch 01750 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.5303e+00
# --------------------------------------------------------------------------------
# [ Epoch 01760 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4600e+00
# --------------------------------------------------------------------------------
# [ Epoch 01770 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4493e+00
# --------------------------------------------------------------------------------
# [ Epoch 01780 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3762e+00
# --------------------------------------------------------------------------------
# [ Epoch 01790 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4270e+00
# --------------------------------------------------------------------------------
# [ Epoch 01800 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3612e+00
# --------------------------------------------------------------------------------
# [ Epoch 01810 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4516e+00
# --------------------------------------------------------------------------------
# [ Epoch 01820 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3340e+00
# --------------------------------------------------------------------------------
# [ Epoch 01830 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3372e+00
# --------------------------------------------------------------------------------
# [ Epoch 01840 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3552e+00
# --------------------------------------------------------------------------------
# [ Epoch 01850 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3579e+00
# --------------------------------------------------------------------------------
# [ Epoch 01860 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3297e+00
# --------------------------------------------------------------------------------
# [ Epoch 01870 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3636e+00
# --------------------------------------------------------------------------------
# [ Epoch 01880 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3992e+00
# --------------------------------------------------------------------------------
# [ Epoch 01890 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4011e+00
# --------------------------------------------------------------------------------
# [ Epoch 01900 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3717e+00
# --------------------------------------------------------------------------------
# [ Epoch 01910 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4273e+00
# --------------------------------------------------------------------------------
# [ Epoch 01920 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4572e+00
# --------------------------------------------------------------------------------
# [ Epoch 01930 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.3850e+00
# --------------------------------------------------------------------------------
# [ Epoch 01940 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4080e+00
# --------------------------------------------------------------------------------
# [ Epoch 01950 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.6400e+00
# --------------------------------------------------------------------------------
# [ Epoch 01960 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3571e+00
# --------------------------------------------------------------------------------
# [ Epoch 01970 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.5855e+00
# --------------------------------------------------------------------------------
# [ Epoch 01980 ]
# * Absolute error:       4.4117e-04
# * Relative error:       1.8465e+00
# --------------------------------------------------------------------------------
# [ Epoch 01990 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.9290e+00
# --------------------------------------------------------------------------------
# [ Epoch 02000 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3478e+00
# --------------------------------------------------------------------------------
# [ Epoch 02010 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.2954e+00
# --------------------------------------------------------------------------------
# [ Epoch 02020 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3353e+00
# --------------------------------------------------------------------------------
# [ Epoch 02030 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4183e+00
# --------------------------------------------------------------------------------
# [ Epoch 02040 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3529e+00
# --------------------------------------------------------------------------------
# [ Epoch 02050 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.6292e+00
# --------------------------------------------------------------------------------
# [ Epoch 02060 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4001e+00
# --------------------------------------------------------------------------------
# [ Epoch 02070 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3465e+00
# --------------------------------------------------------------------------------
# [ Epoch 02080 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4717e+00
# --------------------------------------------------------------------------------
# [ Epoch 02090 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4389e+00
# --------------------------------------------------------------------------------
# [ Epoch 02100 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.6776e+00
# --------------------------------------------------------------------------------
# [ Epoch 02110 ]
# * Absolute error:       4.4118e-04
# * Relative error:       1.9287e+00
# --------------------------------------------------------------------------------
# [ Epoch 02120 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3297e+00
# --------------------------------------------------------------------------------
# [ Epoch 02130 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3051e+00
# --------------------------------------------------------------------------------
# [ Epoch 02140 ]
# * Absolute error:       4.4116e-04
# * Relative error:       1.8360e+00
# --------------------------------------------------------------------------------
# [ Epoch 02150 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.7098e+00
# --------------------------------------------------------------------------------
# [ Epoch 02160 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.5947e+00
# --------------------------------------------------------------------------------
# [ Epoch 02170 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3230e+00
# --------------------------------------------------------------------------------
# [ Epoch 02180 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3218e+00
# --------------------------------------------------------------------------------
# [ Epoch 02190 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3445e+00
# --------------------------------------------------------------------------------
# [ Epoch 02200 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3934e+00
# --------------------------------------------------------------------------------
# [ Epoch 02210 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3245e+00
# --------------------------------------------------------------------------------
# [ Epoch 02220 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3885e+00
# --------------------------------------------------------------------------------
# [ Epoch 02230 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.5474e+00
# --------------------------------------------------------------------------------
# [ Epoch 02240 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4325e+00
# --------------------------------------------------------------------------------
# [ Epoch 02250 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4725e+00
# --------------------------------------------------------------------------------
# [ Epoch 02260 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3479e+00
# --------------------------------------------------------------------------------
# [ Epoch 02270 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4172e+00
# --------------------------------------------------------------------------------
# [ Epoch 02280 ]
# * Absolute error:       4.4133e-04
# * Relative error:       2.6724e+00
# --------------------------------------------------------------------------------
# [ Epoch 02290 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3134e+00
# --------------------------------------------------------------------------------
# [ Epoch 02300 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3000e+00
# --------------------------------------------------------------------------------
# [ Epoch 02310 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3623e+00
# --------------------------------------------------------------------------------
# [ Epoch 02320 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3366e+00
# --------------------------------------------------------------------------------
# [ Epoch 02330 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.2938e+00
# --------------------------------------------------------------------------------
# [ Epoch 02340 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3156e+00
# --------------------------------------------------------------------------------
# [ Epoch 02350 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3257e+00
# --------------------------------------------------------------------------------
# [ Epoch 02360 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3210e+00
# --------------------------------------------------------------------------------
# [ Epoch 02370 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3575e+00
# --------------------------------------------------------------------------------
# [ Epoch 02380 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3856e+00
# --------------------------------------------------------------------------------
# [ Epoch 02390 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3517e+00
# --------------------------------------------------------------------------------
# [ Epoch 02400 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4188e+00
# --------------------------------------------------------------------------------
# [ Epoch 02410 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.8118e+00
# --------------------------------------------------------------------------------
# [ Epoch 02420 ]
# * Absolute error:       4.4115e-04
# * Relative error:       1.7716e+00
# --------------------------------------------------------------------------------
# [ Epoch 02430 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.4886e+00
# --------------------------------------------------------------------------------
# [ Epoch 02440 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.2822e+00
# --------------------------------------------------------------------------------
# [ Epoch 02450 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3797e+00
# --------------------------------------------------------------------------------
# [ Epoch 02460 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4320e+00
# --------------------------------------------------------------------------------
# [ Epoch 02470 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.2928e+00
# --------------------------------------------------------------------------------
# [ Epoch 02480 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.3894e+00
# --------------------------------------------------------------------------------
# [ Epoch 02490 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.5940e+00
# --------------------------------------------------------------------------------
# [ Epoch 02500 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2532e+00
# --------------------------------------------------------------------------------
# [ Epoch 02510 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3220e+00
# --------------------------------------------------------------------------------
# [ Epoch 02520 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.6283e+00
# --------------------------------------------------------------------------------
# [ Epoch 02530 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3250e+00
# --------------------------------------------------------------------------------
# [ Epoch 02540 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3813e+00
# --------------------------------------------------------------------------------
# [ Epoch 02550 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.5032e+00
# --------------------------------------------------------------------------------
# [ Epoch 02560 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3060e+00
# --------------------------------------------------------------------------------
# [ Epoch 02570 ]
# * Absolute error:       4.4114e-04
# * Relative error:       1.7595e+00
# --------------------------------------------------------------------------------
# [ Epoch 02580 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.4180e+00
# --------------------------------------------------------------------------------
# [ Epoch 02590 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.5531e+00
# --------------------------------------------------------------------------------
# [ Epoch 02600 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2748e+00
# --------------------------------------------------------------------------------
# [ Epoch 02610 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3544e+00
# --------------------------------------------------------------------------------
# [ Epoch 02620 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.5198e+00
# --------------------------------------------------------------------------------
# [ Epoch 02630 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2812e+00
# --------------------------------------------------------------------------------
# [ Epoch 02640 ]
# * Absolute error:       4.4111e-04
# * Relative error:       1.5975e+00
# --------------------------------------------------------------------------------
# [ Epoch 02650 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.4238e+00
# --------------------------------------------------------------------------------
# [ Epoch 02660 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2778e+00
# --------------------------------------------------------------------------------
# [ Epoch 02670 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2917e+00
# --------------------------------------------------------------------------------
# [ Epoch 02680 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3217e+00
# --------------------------------------------------------------------------------
# [ Epoch 02690 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.3795e+00
# --------------------------------------------------------------------------------
# [ Epoch 02700 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.2936e+00
# --------------------------------------------------------------------------------
# [ Epoch 02710 ]
# * Absolute error:       4.4113e-04
# * Relative error:       1.7286e+00
# --------------------------------------------------------------------------------
# [ Epoch 02720 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3233e+00
# --------------------------------------------------------------------------------
# [ Epoch 02730 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.6916e+00
# --------------------------------------------------------------------------------
# [ Epoch 02740 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3453e+00
# --------------------------------------------------------------------------------
# [ Epoch 02750 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2940e+00
# --------------------------------------------------------------------------------
# [ Epoch 02760 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2667e+00
# --------------------------------------------------------------------------------
# [ Epoch 02770 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2825e+00
# --------------------------------------------------------------------------------
# [ Epoch 02780 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2831e+00
# --------------------------------------------------------------------------------
# [ Epoch 02790 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2597e+00
# --------------------------------------------------------------------------------
# [ Epoch 02800 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3520e+00
# --------------------------------------------------------------------------------
# [ Epoch 02810 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.4884e+00
# --------------------------------------------------------------------------------
# [ Epoch 02820 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2653e+00
# --------------------------------------------------------------------------------
# [ Epoch 02830 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2866e+00
# --------------------------------------------------------------------------------
# [ Epoch 02840 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.2775e+00
# --------------------------------------------------------------------------------
# [ Epoch 02850 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.3057e+00
# --------------------------------------------------------------------------------
# [ Epoch 02860 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.2421e+00
# --------------------------------------------------------------------------------
# [ Epoch 02870 ]
# ...
# * Relative error:       1.3863e+00
# --------------------------------------------------------------------------------
# [ Epoch 04230 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5538e+00
# --------------------------------------------------------------------------------
# [ Epoch 04240 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.6543e+00
# --------------------------------------------------------------------------------
# [ Epoch 04250 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4633e+00
# --------------------------------------------------------------------------------
# [ Epoch 04260 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.4842e+00
# --------------------------------------------------------------------------------
# [ Epoch 04270 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.3938e+00
# --------------------------------------------------------------------------------
# [ Epoch 04280 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2160e+00
# --------------------------------------------------------------------------------
# [ Epoch 04290 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2272e+00
# --------------------------------------------------------------------------------
# [ Epoch 04300 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2107e+00
# --------------------------------------------------------------------------------
# [ Epoch 04310 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2092e+00
# --------------------------------------------------------------------------------
# [ Epoch 04320 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2147e+00
# --------------------------------------------------------------------------------
# [ Epoch 04330 ]
# * Absolute error:       4.4102e-04
# * Relative error:       1.2795e+00
# --------------------------------------------------------------------------------
# [ Epoch 04340 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.3782e+00
# --------------------------------------------------------------------------------
# [ Epoch 04350 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.6876e+00
# --------------------------------------------------------------------------------
# [ Epoch 04360 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.1807e+00
# --------------------------------------------------------------------------------
# [ Epoch 04370 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2339e+00
# --------------------------------------------------------------------------------
# [ Epoch 04380 ]
# * Absolute error:       4.4109e-04
# * Relative error:       1.6214e+00
# --------------------------------------------------------------------------------
# [ Epoch 04390 ]
# * Absolute error:       4.4102e-04
# * Relative error:       1.2784e+00
# --------------------------------------------------------------------------------
# [ Epoch 04400 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.7708e+00
# --------------------------------------------------------------------------------
# [ Epoch 04410 ]
# * Absolute error:       4.4102e-04
# * Relative error:       1.3117e+00
# --------------------------------------------------------------------------------
# [ Epoch 04420 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4466e+00
# --------------------------------------------------------------------------------
# [ Epoch 04430 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.5751e+00
# --------------------------------------------------------------------------------
# [ Epoch 04440 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.1729e+00
# --------------------------------------------------------------------------------
# [ Epoch 04450 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.3937e+00
# --------------------------------------------------------------------------------
# [ Epoch 04460 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3214e+00
# --------------------------------------------------------------------------------
# [ Epoch 04470 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2201e+00
# --------------------------------------------------------------------------------
# [ Epoch 04480 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2027e+00
# --------------------------------------------------------------------------------
# [ Epoch 04490 ]
# * Absolute error:       4.4112e-04
# * Relative error:       1.7807e+00
# --------------------------------------------------------------------------------
# [ Epoch 04500 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.6842e+00
# --------------------------------------------------------------------------------
# [ Epoch 04510 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.4088e+00
# --------------------------------------------------------------------------------
# [ Epoch 04520 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3237e+00
# --------------------------------------------------------------------------------
# [ Epoch 04530 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3538e+00
# --------------------------------------------------------------------------------
# [ Epoch 04540 ]
# * Absolute error:       4.4102e-04
# * Relative error:       1.3041e+00
# --------------------------------------------------------------------------------
# [ Epoch 04550 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3345e+00
# --------------------------------------------------------------------------------
# [ Epoch 04560 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2203e+00
# --------------------------------------------------------------------------------
# [ Epoch 04570 ]
# * Absolute error:       4.4110e-04
# * Relative error:       1.7086e+00
# --------------------------------------------------------------------------------
# [ Epoch 04580 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.6171e+00
# --------------------------------------------------------------------------------
# [ Epoch 04590 ]
# * Absolute error:       4.4102e-04
# * Relative error:       1.3023e+00
# --------------------------------------------------------------------------------
# [ Epoch 04600 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2182e+00
# --------------------------------------------------------------------------------
# [ Epoch 04610 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.5706e+00
# --------------------------------------------------------------------------------
# [ Epoch 04620 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3395e+00
# --------------------------------------------------------------------------------
# [ Epoch 04630 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4687e+00
# --------------------------------------------------------------------------------
# [ Epoch 04640 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5079e+00
# --------------------------------------------------------------------------------
# [ Epoch 04650 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4407e+00
# --------------------------------------------------------------------------------
# [ Epoch 04660 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5728e+00
# --------------------------------------------------------------------------------
# [ Epoch 04670 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2626e+00
# --------------------------------------------------------------------------------
# [ Epoch 04680 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2463e+00
# --------------------------------------------------------------------------------
# [ Epoch 04690 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2541e+00
# --------------------------------------------------------------------------------
# [ Epoch 04700 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5313e+00
# --------------------------------------------------------------------------------
# [ Epoch 04710 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4571e+00
# --------------------------------------------------------------------------------
# [ Epoch 04720 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4595e+00
# --------------------------------------------------------------------------------
# [ Epoch 04730 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5461e+00
# --------------------------------------------------------------------------------
# [ Epoch 04740 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2225e+00
# --------------------------------------------------------------------------------
# [ Epoch 04750 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2311e+00
# --------------------------------------------------------------------------------
# [ Epoch 04760 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5714e+00
# --------------------------------------------------------------------------------
# [ Epoch 04770 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4514e+00
# --------------------------------------------------------------------------------
# [ Epoch 04780 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2298e+00
# --------------------------------------------------------------------------------
# [ Epoch 04790 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5493e+00
# --------------------------------------------------------------------------------
# [ Epoch 04800 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5440e+00
# --------------------------------------------------------------------------------
# [ Epoch 04810 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4619e+00
# --------------------------------------------------------------------------------
# [ Epoch 04820 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3836e+00
# --------------------------------------------------------------------------------
# [ Epoch 04830 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2830e+00
# --------------------------------------------------------------------------------
# [ Epoch 04840 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2700e+00
# --------------------------------------------------------------------------------
# [ Epoch 04850 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2230e+00
# --------------------------------------------------------------------------------
# [ Epoch 04860 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5481e+00
# --------------------------------------------------------------------------------
# [ Epoch 04870 ]
# * Absolute error:       4.4101e-04
# * Relative error:       1.2707e+00
# --------------------------------------------------------------------------------
# [ Epoch 04880 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5515e+00
# --------------------------------------------------------------------------------
# [ Epoch 04890 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5170e+00
# --------------------------------------------------------------------------------
# [ Epoch 04900 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5416e+00
# --------------------------------------------------------------------------------
# [ Epoch 04910 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5329e+00
# --------------------------------------------------------------------------------
# [ Epoch 04920 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4758e+00
# --------------------------------------------------------------------------------
# [ Epoch 04930 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4903e+00
# --------------------------------------------------------------------------------
# [ Epoch 04940 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5640e+00
# --------------------------------------------------------------------------------
# [ Epoch 04950 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1615e+00
# --------------------------------------------------------------------------------
# [ Epoch 04960 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1857e+00
# --------------------------------------------------------------------------------
# [ Epoch 04970 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4917e+00
# --------------------------------------------------------------------------------
# [ Epoch 04980 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.1918e+00
# --------------------------------------------------------------------------------
# [ Epoch 04990 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5199e+00
# --------------------------------------------------------------------------------
# [ Epoch 05000 ]
# * Absolute error:       4.4102e-04
# * Relative error:       1.3270e+00
# --------------------------------------------------------------------------------
# [ Epoch 05010 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5736e+00
# --------------------------------------------------------------------------------
# [ Epoch 05020 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.4172e+00
# --------------------------------------------------------------------------------
# [ Epoch 05030 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2346e+00
# --------------------------------------------------------------------------------
# [ Epoch 05040 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1768e+00
# --------------------------------------------------------------------------------
# [ Epoch 05050 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2019e+00
# --------------------------------------------------------------------------------
# [ Epoch 05060 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5486e+00
# --------------------------------------------------------------------------------
# [ Epoch 05070 ]
# * Absolute error:       4.4107e-04
# * Relative error:       1.5991e+00
# --------------------------------------------------------------------------------
# [ Epoch 05080 ]
# * Absolute error:       4.4105e-04
# * Relative error:       1.4572e+00
# --------------------------------------------------------------------------------
# [ Epoch 05090 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1852e+00
# --------------------------------------------------------------------------------
# [ Epoch 05100 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1827e+00
# --------------------------------------------------------------------------------
# [ Epoch 05110 ]
# * Absolute error:       4.4103e-04
# * Relative error:       1.3546e+00
# --------------------------------------------------------------------------------
# [ Epoch 05120 ]
# * Absolute error:       4.4104e-04
# * Relative error:       1.3986e+00
# --------------------------------------------------------------------------------
# [ Epoch 05130 ]
# * Absolute error:       4.4108e-04
# * Relative error:       1.6427e+00
# --------------------------------------------------------------------------------
# [ Epoch 05140 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1949e+00
# --------------------------------------------------------------------------------
# [ Epoch 05150 ]
# * Absolute error:       4.4106e-04
# * Relative error:       1.5183e+00
# --------------------------------------------------------------------------------
# [ Epoch 05160 ]
# * Absolute error:       4.4099e-04
# * Relative error:       1.1919e+00
# --------------------------------------------------------------------------------
# [ Epoch 05170 ]
# * Absolute error:       4.4100e-04
# * Relative error:       1.2077e+00
# --------------------------------------------------------------------------------

# %%
idx = torch.randint(0, len(data), (1,)).item()
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
d1 = pred_collision[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
d2 = target_collision[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
d3 = (pred_collision-target_collision)[idx].reshape(RESOLUTION, RESOLUTION).detach().cpu().numpy()
fig.colorbar(axes[0].imshow(d1))
fig.colorbar(axes[1].imshow(d2))
fig.colorbar(axes[2].imshow(np.abs(d3)))
plt.show()

# %% [markdown]
# End of file
